# %%
#Mô tả dữ liệu

import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import mean_squared_error, r2_score
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense

# Đọc dữ liệu từ tệp CSV
df = pd.read_csv('Dataa_Service.csv')
print(df.head())
print(df.describe())
# Kiểm tra giá trị thiếu trong dữ liệu
print('Giá trị bị thiếu')
print(df.isnull().sum())
# Out:
#    Month  Year   GDP   CPI  USD/VND  Temperature  Service
# 0      1  2010  4.23  1.36    18474        21.28    11302
# 1      2  2010  4.23  1.96    19050        23.00    11253
# 2      3  2010  4.23  0.75    19090        23.38    10776
# 3      4  2010  3.81  0.14    18975        25.92    11472
# 4      5  2010  3.81  0.27    18875        28.00    11656
#             Month         Year         GDP         CPI       USD/VND  \
# count  171.000000   171.000000  171.000000  171.000000    171.000000
# mean     6.438596  2016.666667    5.200117    0.409415  22175.245614
# std      3.464191     4.164274    2.335468    0.622585   1387.721899
# min      1.000000  2010.000000   -6.170000   -1.540000  18474.000000
# 25%      3.000000  2013.000000    4.140000    0.065000  21067.500000
# 50%      6.000000  2017.000000    5.330000    0.270000  22688.000000
# 75%      9.000000  2020.000000    6.410000    0.615000  23194.000000
# max     12.000000  2024.000000   13.670000    3.320000  25330.000000
#
#        Temperature       Service
# count   171.000000    171.000000
# mean     23.901462  34089.403509
# std       6.671246  13788.150854
# min       8.660000  10776.000000
# 25%      19.790000  22086.500000
# 50%      24.390000  33981.000000
# 75%      27.440000  45058.500000
# max      40.700000  65375.000000
# Giá trị bị thiếu
# Month          0
# Year           0
# GDP            0
# CPI            0
# USD/VND        0
# Temperature    0
# Service        0
# dtype: int64

# %%
#Mô hình hồi quy
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error
from sklearn.metrics import mean_absolute_error, r2_score
from sklearn.linear_model import Ridge
from sklearn.linear_model import Lasso
from sklearn.tree import DecisionTreeRegressor
import time

# Đọc dữ liệu từ tệp CSV
df = pd.read_csv('Dataa_Service.csv')

# Tách biến đầu vào và biến mục tiêu
X = df[['Month', 'Year', 'CPI','GDP','Temperature','USD/VND']]
y = df['Service']

# Chia dữ liệu thành tập huấn luyện và tập kiểm tra
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=20)

# Chuẩn hóa dữ liệu
scaler = StandardScaler()
X_train = scaler.fit_transform(X_train)
X_test = scaler.transform(X_test)

#MODEL1 Xây dựng mô hình ( Linear Regression )
start_time = time.time()
model = LinearRegression()
model.fit(X_train, y_train)
y_pred = model.predict(X_test)
end_time = time.time()
linear_regression_time = end_time - start_time

#MODEL2 Xây dựng mô hình ( Ridge Regression )
start_time = time.time()
ridge_model = Ridge(alpha=1.0)
ridge_model.fit(X_train, y_train)
ridge_y_pred = ridge_model.predict(X_test)
end_time = time.time()
ridge_regression_time = end_time - start_time

#MODEL3 Xây dựng mô hình (Lasso Regression)
start_time = time.time()
lasso_model = Lasso(alpha=1.0)
lasso_model.fit(X_train, y_train)
lasso_y_pred = lasso_model.predict(X_test)
end_time = time.time()
lasso_regression_time = end_time - start_time

#MODEL4 Xây dựng mô hình Decision Tree Regression
start_time = time.time()
tree_model = DecisionTreeRegressor(random_state=20)
tree_model.fit(X_train, y_train)
tree_y_pred = tree_model.predict(X_test)
end_time = time.time()
tree_regression_time = end_time - start_time



#Đánh giá mô hình bằng 4 chỉ số hồi quy
mae = mean_absolute_error(y_test, y_pred)
r2 = r2_score(y_test, y_pred)
rmse = np.sqrt(mean_squared_error(y_test, y_pred))
mpae = np.mean(np.abs((y_test - y_pred) / y_test)) * 100

ridge_mae = mean_absolute_error(y_test, ridge_y_pred)
ridge_r2 = r2_score(y_test, ridge_y_pred)
ridge_rmse = np.sqrt(mean_squared_error(y_test, ridge_y_pred))
ridge_mpae = np.mean(np.abs((y_test - ridge_y_pred) / y_test)) * 100

lasso_mae = mean_absolute_error(y_test, lasso_y_pred)
lasso_r2 = r2_score(y_test, lasso_y_pred)
lasso_rmse = np.sqrt(mean_squared_error(y_test, lasso_y_pred))
lasso_mpae = np.mean(np.abs((y_test - lasso_y_pred) / y_test)) * 100

tree_mae = mean_absolute_error(y_test, tree_y_pred)
tree_r2 = r2_score(y_test, tree_y_pred)
tree_rmse = np.sqrt(mean_squared_error(y_test, tree_y_pred))
tree_mpae = np.mean(np.abs((y_test - tree_y_pred) / y_test)) * 100

print("Linear Regression:")
print("Mean Absolute Error (MAE):", mae)
print("R-squared (R2):", r2)
print("Root Mean Squared Error (RMSE):", rmse)
print("Mean Percentage Absolute Error (MPAE):", mpae)
print("Time taken (seconds):", linear_regression_time)

print("\nRidge Regression:")
print("Mean Absolute Error (MAE):", ridge_mae)
print("R-squared (R2):", ridge_r2)
print("Root Mean Squared Error (RMSE):", ridge_rmse)
print("Mean Percentage Absolute Error (MPAE):", ridge_mpae)
print("Time taken (seconds):", ridge_regression_time)

print("\nLasso Regression:")
print("Mean Absolute Error (MAE):", lasso_mae)
print("R-squared (R2):", lasso_r2)
print("Root Mean Squared Error (RMSE):", lasso_rmse)
print("Mean Percentage Absolute Error (MPAE):", lasso_mpae)
print("Time taken (seconds):", lasso_regression_time)

print("\nDecision Tree Regression:")
print("Mean Absolute Error (MAE):", tree_mae)
print("R-squared (R2):", tree_r2)
print("Root Mean Squared Error (RMSE):", tree_rmse)
print("Mean Percentage Absolute Error (MPAE):", tree_mpae)
print("Time taken (seconds):", tree_regression_time)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-1-7f4dcb7f6022> in <cell line: 15>()
#      13
#      14 # Đọc dữ liệu từ tệp CSV
# ---> 15 df = pd.read_csv('Dataa_Service.csv')
#      16
#      17 # Tách biến đầu vào và biến mục tiêu
#
# /usr/local/lib/python3.10/dist-packages/pandas/io/parsers/readers.py in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#     910     kwds.update(kwds_defaults)
#     911
# --> 912     return _read(filepath_or_buffer, kwds)
#     913
#     914
#
# /usr/local/lib/python3.10/dist-packages/pandas/io/parsers/readers.py in _read(filepath_or_buffer, kwds)
#     575
#     576     # Create the parser.
# --> 577     parser = TextFileReader(filepath_or_buffer, **kwds)
#     578
#     579     if chunksize or iterator:
#
# /usr/local/lib/python3.10/dist-packages/pandas/io/parsers/readers.py in __init__(self, f, engine, **kwds)
#    1405
#    1406         self.handles: IOHandles | None = None
# -> 1407         self._engine = self._make_engine(f, self.engine)
#    1408
#    1409     def close(self) -> None:
#
# /usr/local/lib/python3.10/dist-packages/pandas/io/parsers/readers.py in _make_engine(self, f, engine)
#    1659                 if "b" not in mode:
#    1660                     mode += "b"
# -> 1661             self.handles = get_handle(
#    1662                 f,
#    1663                 mode,
#
# /usr/local/lib/python3.10/dist-packages/pandas/io/common.py in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     857         if ioargs.encoding and "b" not in ioargs.mode:
#     858             # Encoding
# --> 859             handle = open(
#     860                 handle,
#     861                 ioargs.mode,
#
# FileNotFoundError: [Errno 2] No such file or directory: 'Dataa_Service.csv'

# %%
#Mạng Nowrron nhiều lớp
import pandas as pd
import numpy as np
import time
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_absolute_error, r2_score, mean_absolute_percentage_error
from keras.models import Sequential
from keras.layers import Dense

# Đọc dữ liệu từ tệp CSV
df = pd.read_csv('Dataa_Service.csv')

# Chọn các cột đầu vào và đầu ra
X = df[['Month', 'Year', 'CPI', 'GDP', 'Temperature', 'USD/VND']]
y = df['Service']

# Chuẩn hóa dữ liệu
scaler_X = MinMaxScaler()
scaler_y = MinMaxScaler()
X_scaled = scaler_X.fit_transform(X)
y_scaled = scaler_y.fit_transform(y.values.reshape(-1, 1))

# Chia dữ liệu thành tập huấn luyện và kiểm tra
X_train, X_test, y_train, y_test = train_test_split(X_scaled, y_scaled, test_size=0.2, random_state=42)

# Xây dựng mô hình mạng nơron
model = Sequential()
model.add(Dense(64, input_dim=X_train.shape[1], activation='relu'))
model.add(Dense(32, activation='relu'))
model.add(Dense(16, activation='relu'))
model.add(Dense(1))

# Biên dịch mô hình
model.compile(loss='mean_squared_error', optimizer='adam')

# Đo thời gian bắt đầu huấn luyện
start_time = time.time()

# Huấn luyện mô hình
model.fit(X_train, y_train, epochs=500, batch_size=10, verbose=2)

# Đo thời gian kết thúc huấn luyện
end_time = time.time()

# Dự báo trên tập kiểm tra
y_pred_scaled = model.predict(X_test)

# Chuyển đổi lại dữ liệu về dạng ban đầu
y_pred = scaler_y.inverse_transform(y_pred_scaled)
y_test = scaler_y.inverse_transform(y_test)

# Tính toán các chỉ số đánh giá
mse = np.mean((y_pred - y_test) ** 2)
rmse = np.sqrt(mse)
mae = mean_absolute_error(y_test, y_pred)
r2 = r2_score(y_test, y_pred)
mape = mean_absolute_percentage_error(y_test, y_pred)
adjusted_r2 = 1 - (1 - r2) * ((len(y_test) - 1) / (len(y_test) - X_test.shape[1] - 1))

# In các chỉ số đánh giá
print(f'Test RMSE: {rmse:.2f}')
print(f'Test MAE: {mae:.2f}')
print(f'Test R^2: {r2:.2f}')
print(f'Test MAPE: {mape:.2f}')
print(f'Test Adjusted R^2: {adjusted_r2:.2f}')

# In thời gian huấn luyện
print(f'Training Time: {end_time - start_time:.2f} seconds')
# Out:
# Epoch 1/500
# 14/14 - 1s - loss: 0.1168 - 837ms/epoch - 60ms/step
# Epoch 2/500
# 14/14 - 0s - loss: 0.0355 - 28ms/epoch - 2ms/step
# Epoch 3/500
# 14/14 - 0s - loss: 0.0191 - 28ms/epoch - 2ms/step
# Epoch 4/500
# 14/14 - 0s - loss: 0.0114 - 26ms/epoch - 2ms/step
# Epoch 5/500
# 14/14 - 0s - loss: 0.0076 - 29ms/epoch - 2ms/step
# Epoch 6/500
# 14/14 - 0s - loss: 0.0063 - 29ms/epoch - 2ms/step
# Epoch 7/500
# 14/14 - 0s - loss: 0.0060 - 29ms/epoch - 2ms/step
# Epoch 8/500
# 14/14 - 0s - loss: 0.0059 - 28ms/epoch - 2ms/step
# Epoch 9/500
# 14/14 - 0s - loss: 0.0055 - 26ms/epoch - 2ms/step
# Epoch 10/500
# 14/14 - 0s - loss: 0.0054 - 30ms/epoch - 2ms/step
# Epoch 11/500
# 14/14 - 0s - loss: 0.0054 - 35ms/epoch - 2ms/step
# Epoch 12/500
# 14/14 - 0s - loss: 0.0054 - 26ms/epoch - 2ms/step
# Epoch 13/500
# 14/14 - 0s - loss: 0.0055 - 30ms/epoch - 2ms/step
# Epoch 14/500
# 14/14 - 0s - loss: 0.0054 - 26ms/epoch - 2ms/step
# Epoch 15/500
# 14/14 - 0s - loss: 0.0049 - 28ms/epoch - 2ms/step
# Epoch 16/500
# 14/14 - 0s - loss: 0.0052 - 30ms/epoch - 2ms/step
# Epoch 17/500
# 14/14 - 0s - loss: 0.0048 - 28ms/epoch - 2ms/step
# Epoch 18/500
# 14/14 - 0s - loss: 0.0046 - 27ms/epoch - 2ms/step
# Epoch 19/500
# 14/14 - 0s - loss: 0.0045 - 34ms/epoch - 2ms/step
# Epoch 20/500
# 14/14 - 0s - loss: 0.0043 - 27ms/epoch - 2ms/step
# Epoch 21/500
# 14/14 - 0s - loss: 0.0042 - 27ms/epoch - 2ms/step
# Epoch 22/500
# 14/14 - 0s - loss: 0.0041 - 26ms/epoch - 2ms/step
# Epoch 23/500
# 14/14 - 0s - loss: 0.0044 - 28ms/epoch - 2ms/step
# Epoch 24/500
# 14/14 - 0s - loss: 0.0037 - 27ms/epoch - 2ms/step
# Epoch 25/500
# 14/14 - 0s - loss: 0.0038 - 26ms/epoch - 2ms/step
# Epoch 26/500
# 14/14 - 0s - loss: 0.0036 - 32ms/epoch - 2ms/step
# Epoch 27/500
# 14/14 - 0s - loss: 0.0036 - 28ms/epoch - 2ms/step
# Epoch 28/500
# 14/14 - 0s - loss: 0.0044 - 28ms/epoch - 2ms/step
# Epoch 29/500
# 14/14 - 0s - loss: 0.0036 - 28ms/epoch - 2ms/step
# Epoch 30/500
# 14/14 - 0s - loss: 0.0037 - 28ms/epoch - 2ms/step
# Epoch 31/500
# 14/14 - 0s - loss: 0.0033 - 29ms/epoch - 2ms/step
# Epoch 32/500
# 14/14 - 0s - loss: 0.0033 - 30ms/epoch - 2ms/step
# Epoch 33/500
# 14/14 - 0s - loss: 0.0033 - 25ms/epoch - 2ms/step
# Epoch 34/500
# 14/14 - 0s - loss: 0.0031 - 31ms/epoch - 2ms/step
# Epoch 35/500
# 14/14 - 0s - loss: 0.0031 - 27ms/epoch - 2ms/step
# Epoch 36/500
# 14/14 - 0s - loss: 0.0029 - 30ms/epoch - 2ms/step
# Epoch 37/500
# 14/14 - 0s - loss: 0.0029 - 29ms/epoch - 2ms/step
# Epoch 38/500
# 14/14 - 0s - loss: 0.0031 - 32ms/epoch - 2ms/step
# Epoch 39/500
# 14/14 - 0s - loss: 0.0032 - 27ms/epoch - 2ms/step
# Epoch 40/500
# 14/14 - 0s - loss: 0.0033 - 28ms/epoch - 2ms/step
# Epoch 41/500
# 14/14 - 0s - loss: 0.0026 - 28ms/epoch - 2ms/step
# Epoch 42/500
# 14/14 - 0s - loss: 0.0028 - 29ms/epoch - 2ms/step
# Epoch 43/500
# 14/14 - 0s - loss: 0.0033 - 34ms/epoch - 2ms/step
# Epoch 44/500
# 14/14 - 0s - loss: 0.0031 - 40ms/epoch - 3ms/step
# Epoch 45/500
# 14/14 - 0s - loss: 0.0026 - 27ms/epoch - 2ms/step
# Epoch 46/500
# 14/14 - 0s - loss: 0.0025 - 27ms/epoch - 2ms/step
# Epoch 47/500
# 14/14 - 0s - loss: 0.0024 - 27ms/epoch - 2ms/step
# Epoch 48/500
# 14/14 - 0s - loss: 0.0027 - 28ms/epoch - 2ms/step
# Epoch 49/500
# 14/14 - 0s - loss: 0.0031 - 31ms/epoch - 2ms/step
# Epoch 50/500
# 14/14 - 0s - loss: 0.0026 - 27ms/epoch - 2ms/step
# Epoch 51/500
# 14/14 - 0s - loss: 0.0028 - 28ms/epoch - 2ms/step
# Epoch 52/500
# 14/14 - 0s - loss: 0.0025 - 27ms/epoch - 2ms/step
# Epoch 53/500
# 14/14 - 0s - loss: 0.0024 - 26ms/epoch - 2ms/step
# Epoch 54/500
# 14/14 - 0s - loss: 0.0022 - 29ms/epoch - 2ms/step
# Epoch 55/500
# 14/14 - 0s - loss: 0.0023 - 27ms/epoch - 2ms/step
# Epoch 56/500
# 14/14 - 0s - loss: 0.0023 - 26ms/epoch - 2ms/step
# Epoch 57/500
# 14/14 - 0s - loss: 0.0022 - 28ms/epoch - 2ms/step
# Epoch 58/500
# 14/14 - 0s - loss: 0.0024 - 28ms/epoch - 2ms/step
# Epoch 59/500
# 14/14 - 0s - loss: 0.0023 - 27ms/epoch - 2ms/step
# Epoch 60/500
# 14/14 - 0s - loss: 0.0022 - 27ms/epoch - 2ms/step
# Epoch 61/500
# 14/14 - 0s - loss: 0.0022 - 28ms/epoch - 2ms/step
# Epoch 62/500
# 14/14 - 0s - loss: 0.0024 - 28ms/epoch - 2ms/step
# Epoch 63/500
# 14/14 - 0s - loss: 0.0024 - 33ms/epoch - 2ms/step
# Epoch 64/500
# 14/14 - 0s - loss: 0.0023 - 26ms/epoch - 2ms/step
# Epoch 65/500
# 14/14 - 0s - loss: 0.0021 - 35ms/epoch - 2ms/step
# Epoch 66/500
# 14/14 - 0s - loss: 0.0024 - 28ms/epoch - 2ms/step
# Epoch 67/500
# 14/14 - 0s - loss: 0.0020 - 26ms/epoch - 2ms/step
# Epoch 68/500
# 14/14 - 0s - loss: 0.0019 - 30ms/epoch - 2ms/step
# Epoch 69/500
# 14/14 - 0s - loss: 0.0020 - 25ms/epoch - 2ms/step
# Epoch 70/500
# 14/14 - 0s - loss: 0.0019 - 27ms/epoch - 2ms/step
# Epoch 71/500
# 14/14 - 0s - loss: 0.0019 - 27ms/epoch - 2ms/step
# Epoch 72/500
# 14/14 - 0s - loss: 0.0020 - 28ms/epoch - 2ms/step
# Epoch 73/500
# 14/14 - 0s - loss: 0.0020 - 31ms/epoch - 2ms/step
# Epoch 74/500
# 14/14 - 0s - loss: 0.0019 - 35ms/epoch - 2ms/step
# Epoch 75/500
# 14/14 - 0s - loss: 0.0021 - 36ms/epoch - 3ms/step
# Epoch 76/500
# 14/14 - 0s - loss: 0.0019 - 41ms/epoch - 3ms/step
# Epoch 77/500
# 14/14 - 0s - loss: 0.0018 - 28ms/epoch - 2ms/step
# Epoch 78/500
# 14/14 - 0s - loss: 0.0022 - 33ms/epoch - 2ms/step
# Epoch 79/500
# 14/14 - 0s - loss: 0.0021 - 30ms/epoch - 2ms/step
# Epoch 80/500
# 14/14 - 0s - loss: 0.0019 - 28ms/epoch - 2ms/step
# Epoch 81/500
# 14/14 - 0s - loss: 0.0019 - 26ms/epoch - 2ms/step
# Epoch 82/500
# 14/14 - 0s - loss: 0.0020 - 29ms/epoch - 2ms/step
# Epoch 83/500
# 14/14 - 0s - loss: 0.0020 - 29ms/epoch - 2ms/step
# Epoch 84/500
# 14/14 - 0s - loss: 0.0019 - 28ms/epoch - 2ms/step
# Epoch 85/500
# 14/14 - 0s - loss: 0.0019 - 29ms/epoch - 2ms/step
# Epoch 86/500
# 14/14 - 0s - loss: 0.0019 - 28ms/epoch - 2ms/step
# Epoch 87/500
# 14/14 - 0s - loss: 0.0018 - 29ms/epoch - 2ms/step
# Epoch 88/500
# 14/14 - 0s - loss: 0.0018 - 31ms/epoch - 2ms/step
# Epoch 89/500
# 14/14 - 0s - loss: 0.0018 - 27ms/epoch - 2ms/step
# Epoch 90/500
# 14/14 - 0s - loss: 0.0020 - 27ms/epoch - 2ms/step
# Epoch 91/500
# 14/14 - 0s - loss: 0.0019 - 32ms/epoch - 2ms/step
# Epoch 92/500
# 14/14 - 0s - loss: 0.0021 - 27ms/epoch - 2ms/step
# Epoch 93/500
# 14/14 - 0s - loss: 0.0020 - 28ms/epoch - 2ms/step
# Epoch 94/500
# 14/14 - 0s - loss: 0.0018 - 29ms/epoch - 2ms/step
# Epoch 95/500
# 14/14 - 0s - loss: 0.0018 - 27ms/epoch - 2ms/step
# Epoch 96/500
# 14/14 - 0s - loss: 0.0021 - 29ms/epoch - 2ms/step
# Epoch 97/500
# 14/14 - 0s - loss: 0.0017 - 28ms/epoch - 2ms/step
# Epoch 98/500
# 14/14 - 0s - loss: 0.0019 - 28ms/epoch - 2ms/step
# Epoch 99/500
# 14/14 - 0s - loss: 0.0017 - 30ms/epoch - 2ms/step
# Epoch 100/500
# 14/14 - 0s - loss: 0.0017 - 26ms/epoch - 2ms/step
# Epoch 101/500
# 14/14 - 0s - loss: 0.0017 - 27ms/epoch - 2ms/step
# Epoch 102/500
# 14/14 - 0s - loss: 0.0018 - 28ms/epoch - 2ms/step
# Epoch 103/500
# 14/14 - 0s - loss: 0.0020 - 27ms/epoch - 2ms/step
# Epoch 104/500
# 14/14 - 0s - loss: 0.0020 - 30ms/epoch - 2ms/step
# Epoch 105/500
# 14/14 - 0s - loss: 0.0023 - 26ms/epoch - 2ms/step
# Epoch 106/500
# 14/14 - 0s - loss: 0.0018 - 26ms/epoch - 2ms/step
# Epoch 107/500
# 14/14 - 0s - loss: 0.0017 - 27ms/epoch - 2ms/step
# Epoch 108/500
# 14/14 - 0s - loss: 0.0019 - 34ms/epoch - 2ms/step
# Epoch 109/500
# 14/14 - 0s - loss: 0.0023 - 33ms/epoch - 2ms/step
# Epoch 110/500
# 14/14 - 0s - loss: 0.0020 - 29ms/epoch - 2ms/step
# Epoch 111/500
# 14/14 - 0s - loss: 0.0019 - 31ms/epoch - 2ms/step
# Epoch 112/500
# 14/14 - 0s - loss: 0.0016 - 28ms/epoch - 2ms/step
# Epoch 113/500
# 14/14 - 0s - loss: 0.0015 - 31ms/epoch - 2ms/step
# Epoch 114/500
# 14/14 - 0s - loss: 0.0016 - 29ms/epoch - 2ms/step
# Epoch 115/500
# 14/14 - 0s - loss: 0.0016 - 27ms/epoch - 2ms/step
# Epoch 116/500
# 14/14 - 0s - loss: 0.0015 - 28ms/epoch - 2ms/step
# Epoch 117/500
# 14/14 - 0s - loss: 0.0017 - 28ms/epoch - 2ms/step
# Epoch 118/500
# 14/14 - 0s - loss: 0.0016 - 27ms/epoch - 2ms/step
# Epoch 119/500
# 14/14 - 0s - loss: 0.0015 - 29ms/epoch - 2ms/step
# Epoch 120/500
# 14/14 - 0s - loss: 0.0016 - 29ms/epoch - 2ms/step
# Epoch 121/500
# 14/14 - 0s - loss: 0.0016 - 30ms/epoch - 2ms/step
# Epoch 122/500
# 14/14 - 0s - loss: 0.0017 - 29ms/epoch - 2ms/step
# Epoch 123/500
# 14/14 - 0s - loss: 0.0019 - 28ms/epoch - 2ms/step
# Epoch 124/500
# 14/14 - 0s - loss: 0.0021 - 28ms/epoch - 2ms/step
# Epoch 125/500
# 14/14 - 0s - loss: 0.0016 - 27ms/epoch - 2ms/step
# Epoch 126/500
# 14/14 - 0s - loss: 0.0017 - 30ms/epoch - 2ms/step
# Epoch 127/500
# 14/14 - 0s - loss: 0.0017 - 29ms/epoch - 2ms/step
# Epoch 128/500
# 14/14 - 0s - loss: 0.0015 - 26ms/epoch - 2ms/step
# Epoch 129/500
# 14/14 - 0s - loss: 0.0017 - 31ms/epoch - 2ms/step
# Epoch 130/500
# 14/14 - 0s - loss: 0.0019 - 26ms/epoch - 2ms/step
# Epoch 131/500
# 14/14 - 0s - loss: 0.0016 - 31ms/epoch - 2ms/step
# Epoch 132/500
# 14/14 - 0s - loss: 0.0015 - 29ms/epoch - 2ms/step
# Epoch 133/500
# 14/14 - 0s - loss: 0.0018 - 26ms/epoch - 2ms/step
# Epoch 134/500
# 14/14 - 0s - loss: 0.0016 - 27ms/epoch - 2ms/step
# Epoch 135/500
# 14/14 - 0s - loss: 0.0016 - 30ms/epoch - 2ms/step
# Epoch 136/500
# 14/14 - 0s - loss: 0.0021 - 28ms/epoch - 2ms/step
# Epoch 137/500
# 14/14 - 0s - loss: 0.0020 - 28ms/epoch - 2ms/step
# Epoch 138/500
# 14/14 - 0s - loss: 0.0015 - 27ms/epoch - 2ms/step
# Epoch 139/500
# 14/14 - 0s - loss: 0.0014 - 29ms/epoch - 2ms/step
# Epoch 140/500
# 14/14 - 0s - loss: 0.0014 - 33ms/epoch - 2ms/step
# Epoch 141/500
# 14/14 - 0s - loss: 0.0022 - 32ms/epoch - 2ms/step
# Epoch 142/500
# 14/14 - 0s - loss: 0.0015 - 28ms/epoch - 2ms/step
# Epoch 143/500
# 14/14 - 0s - loss: 0.0014 - 28ms/epoch - 2ms/step
# Epoch 144/500
# 14/14 - 0s - loss: 0.0014 - 27ms/epoch - 2ms/step
# Epoch 145/500
# 14/14 - 0s - loss: 0.0013 - 28ms/epoch - 2ms/step
# Epoch 146/500
# 14/14 - 0s - loss: 0.0013 - 26ms/epoch - 2ms/step
# Epoch 147/500
# 14/14 - 0s - loss: 0.0013 - 27ms/epoch - 2ms/step
# Epoch 148/500
# 14/14 - 0s - loss: 0.0014 - 38ms/epoch - 3ms/step
# Epoch 149/500
# 14/14 - 0s - loss: 0.0014 - 31ms/epoch - 2ms/step
# Epoch 150/500
# 14/14 - 0s - loss: 0.0013 - 43ms/epoch - 3ms/step
# Epoch 151/500
# 14/14 - 0s - loss: 0.0018 - 27ms/epoch - 2ms/step
# Epoch 152/500
# 14/14 - 0s - loss: 0.0019 - 28ms/epoch - 2ms/step
# Epoch 153/500
# 14/14 - 0s - loss: 0.0013 - 29ms/epoch - 2ms/step
# Epoch 154/500
# 14/14 - 0s - loss: 0.0017 - 28ms/epoch - 2ms/step
# Epoch 155/500
# 14/14 - 0s - loss: 0.0020 - 31ms/epoch - 2ms/step
# Epoch 156/500
# 14/14 - 0s - loss: 0.0021 - 28ms/epoch - 2ms/step
# Epoch 157/500
# 14/14 - 0s - loss: 0.0016 - 29ms/epoch - 2ms/step
# Epoch 158/500
# 14/14 - 0s - loss: 0.0012 - 27ms/epoch - 2ms/step
# Epoch 159/500
# 14/14 - 0s - loss: 0.0012 - 27ms/epoch - 2ms/step
# Epoch 160/500
# 14/14 - 0s - loss: 0.0012 - 27ms/epoch - 2ms/step
# Epoch 161/500
# 14/14 - 0s - loss: 0.0013 - 29ms/epoch - 2ms/step
# Epoch 162/500
# 14/14 - 0s - loss: 0.0011 - 28ms/epoch - 2ms/step
# Epoch 163/500
# 14/14 - 0s - loss: 0.0014 - 27ms/epoch - 2ms/step
# Epoch 164/500
# 14/14 - 0s - loss: 0.0012 - 29ms/epoch - 2ms/step
# Epoch 165/500
# 14/14 - 0s - loss: 0.0013 - 28ms/epoch - 2ms/step
# Epoch 166/500
# 14/14 - 0s - loss: 0.0011 - 29ms/epoch - 2ms/step
# Epoch 167/500
# 14/14 - 0s - loss: 0.0011 - 34ms/epoch - 2ms/step
# Epoch 168/500
# 14/14 - 0s - loss: 0.0011 - 34ms/epoch - 2ms/step
# Epoch 169/500
# 14/14 - 0s - loss: 0.0012 - 30ms/epoch - 2ms/step
# Epoch 170/500
# 14/14 - 0s - loss: 0.0012 - 27ms/epoch - 2ms/step
# Epoch 171/500
# 14/14 - 0s - loss: 0.0012 - 27ms/epoch - 2ms/step
# Epoch 172/500
# 14/14 - 0s - loss: 0.0012 - 26ms/epoch - 2ms/step
# Epoch 173/500
# 14/14 - 0s - loss: 0.0014 - 40ms/epoch - 3ms/step
# Epoch 174/500
# 14/14 - 0s - loss: 0.0012 - 30ms/epoch - 2ms/step
# Epoch 175/500
# 14/14 - 0s - loss: 0.0013 - 30ms/epoch - 2ms/step
# Epoch 176/500
# 14/14 - 0s - loss: 0.0015 - 28ms/epoch - 2ms/step
# Epoch 177/500
# 14/14 - 0s - loss: 0.0011 - 28ms/epoch - 2ms/step
# Epoch 178/500
# 14/14 - 0s - loss: 0.0012 - 31ms/epoch - 2ms/step
# Epoch 179/500
# 14/14 - 0s - loss: 0.0011 - 29ms/epoch - 2ms/step
# Epoch 180/500
# 14/14 - 0s - loss: 0.0018 - 29ms/epoch - 2ms/step
# Epoch 181/500
# 14/14 - 0s - loss: 0.0017 - 28ms/epoch - 2ms/step
# Epoch 182/500
# 14/14 - 0s - loss: 0.0020 - 30ms/epoch - 2ms/step
# Epoch 183/500
# 14/14 - 0s - loss: 0.0013 - 38ms/epoch - 3ms/step
# Epoch 184/500
# 14/14 - 0s - loss: 0.0013 - 29ms/epoch - 2ms/step
# Epoch 185/500
# 14/14 - 0s - loss: 0.0015 - 28ms/epoch - 2ms/step
# Epoch 186/500
# 14/14 - 0s - loss: 0.0013 - 31ms/epoch - 2ms/step
# Epoch 187/500
# 14/14 - 0s - loss: 0.0011 - 31ms/epoch - 2ms/step
# Epoch 188/500
# 14/14 - 0s - loss: 0.0011 - 30ms/epoch - 2ms/step
# Epoch 189/500
# 14/14 - 0s - loss: 9.7275e-04 - 43ms/epoch - 3ms/step
# Epoch 190/500
# 14/14 - 0s - loss: 0.0011 - 38ms/epoch - 3ms/step
# Epoch 191/500
# 14/14 - 0s - loss: 0.0012 - 29ms/epoch - 2ms/step
# Epoch 192/500
# 14/14 - 0s - loss: 0.0013 - 31ms/epoch - 2ms/step
# Epoch 193/500
# 14/14 - 0s - loss: 0.0014 - 31ms/epoch - 2ms/step
# Epoch 194/500
# 14/14 - 0s - loss: 0.0011 - 28ms/epoch - 2ms/step
# Epoch 195/500
# 14/14 - 0s - loss: 0.0010 - 28ms/epoch - 2ms/step
# Epoch 196/500
# 14/14 - 0s - loss: 0.0010 - 34ms/epoch - 2ms/step
# Epoch 197/500
# 14/14 - 0s - loss: 0.0010 - 32ms/epoch - 2ms/step
# Epoch 198/500
# 14/14 - 0s - loss: 9.4218e-04 - 29ms/epoch - 2ms/step
# Epoch 199/500
# 14/14 - 0s - loss: 0.0010 - 28ms/epoch - 2ms/step
# Epoch 200/500
# 14/14 - 0s - loss: 8.6174e-04 - 29ms/epoch - 2ms/step
# Epoch 201/500
# 14/14 - 0s - loss: 8.7638e-04 - 29ms/epoch - 2ms/step
# Epoch 202/500
# 14/14 - 0s - loss: 0.0011 - 27ms/epoch - 2ms/step
# Epoch 203/500
# 14/14 - 0s - loss: 0.0015 - 45ms/epoch - 3ms/step
# Epoch 204/500
# 14/14 - 0s - loss: 0.0012 - 27ms/epoch - 2ms/step
# Epoch 205/500
# 14/14 - 0s - loss: 0.0012 - 29ms/epoch - 2ms/step
# Epoch 206/500
# 14/14 - 0s - loss: 0.0014 - 27ms/epoch - 2ms/step
# Epoch 207/500
# 14/14 - 0s - loss: 0.0013 - 30ms/epoch - 2ms/step
# Epoch 208/500
# 14/14 - 0s - loss: 0.0012 - 27ms/epoch - 2ms/step
# Epoch 209/500
# 14/14 - 0s - loss: 0.0010 - 28ms/epoch - 2ms/step
# Epoch 210/500
# 14/14 - 0s - loss: 9.3619e-04 - 28ms/epoch - 2ms/step
# Epoch 211/500
# 14/14 - 0s - loss: 8.7624e-04 - 28ms/epoch - 2ms/step
# Epoch 212/500
# 14/14 - 0s - loss: 9.0977e-04 - 29ms/epoch - 2ms/step
# Epoch 213/500
# 14/14 - 0s - loss: 8.5942e-04 - 30ms/epoch - 2ms/step
# Epoch 214/500
# 14/14 - 0s - loss: 0.0010 - 29ms/epoch - 2ms/step
# Epoch 215/500
# 14/14 - 0s - loss: 0.0010 - 28ms/epoch - 2ms/step
# Epoch 216/500
# 14/14 - 0s - loss: 9.9670e-04 - 33ms/epoch - 2ms/step
# Epoch 217/500
# 14/14 - 0s - loss: 9.1764e-04 - 28ms/epoch - 2ms/step
# Epoch 218/500
# 14/14 - 0s - loss: 8.4592e-04 - 27ms/epoch - 2ms/step
# Epoch 219/500
# 14/14 - 0s - loss: 8.2786e-04 - 27ms/epoch - 2ms/step
# Epoch 220/500
# 14/14 - 0s - loss: 7.8370e-04 - 27ms/epoch - 2ms/step
# Epoch 221/500
# 14/14 - 0s - loss: 9.1623e-04 - 30ms/epoch - 2ms/step
# Epoch 222/500
# 14/14 - 0s - loss: 8.4925e-04 - 30ms/epoch - 2ms/step
# Epoch 223/500
# 14/14 - 0s - loss: 9.0290e-04 - 29ms/epoch - 2ms/step
# Epoch 224/500
# 14/14 - 0s - loss: 9.5284e-04 - 34ms/epoch - 2ms/step
# Epoch 225/500
# 14/14 - 0s - loss: 7.0275e-04 - 27ms/epoch - 2ms/step
# Epoch 226/500
# 14/14 - 0s - loss: 7.4350e-04 - 35ms/epoch - 2ms/step
# Epoch 227/500
# 14/14 - 0s - loss: 8.1774e-04 - 32ms/epoch - 2ms/step
# Epoch 228/500
# 14/14 - 0s - loss: 8.7587e-04 - 30ms/epoch - 2ms/step
# Epoch 229/500
# 14/14 - 0s - loss: 0.0014 - 32ms/epoch - 2ms/step
# Epoch 230/500
# 14/14 - 0s - loss: 0.0012 - 31ms/epoch - 2ms/step
# Epoch 231/500
# 14/14 - 0s - loss: 9.3985e-04 - 33ms/epoch - 2ms/step
# Epoch 232/500
# 14/14 - 0s - loss: 7.0871e-04 - 29ms/epoch - 2ms/step
# Epoch 233/500
# 14/14 - 0s - loss: 8.1233e-04 - 30ms/epoch - 2ms/step
# Epoch 234/500
# 14/14 - 0s - loss: 8.3827e-04 - 37ms/epoch - 3ms/step
# Epoch 235/500
# 14/14 - 0s - loss: 7.4252e-04 - 26ms/epoch - 2ms/step
# Epoch 236/500
# 14/14 - 0s - loss: 7.1619e-04 - 28ms/epoch - 2ms/step
# Epoch 237/500
# 14/14 - 0s - loss: 7.6016e-04 - 29ms/epoch - 2ms/step
# Epoch 238/500
# 14/14 - 0s - loss: 7.7792e-04 - 39ms/epoch - 3ms/step
# Epoch 239/500
# 14/14 - 0s - loss: 9.7962e-04 - 28ms/epoch - 2ms/step
# Epoch 240/500
# 14/14 - 0s - loss: 7.1758e-04 - 29ms/epoch - 2ms/step
# Epoch 241/500
# 14/14 - 0s - loss: 7.7477e-04 - 28ms/epoch - 2ms/step
# Epoch 242/500
# 14/14 - 0s - loss: 7.1923e-04 - 29ms/epoch - 2ms/step
# Epoch 243/500
# 14/14 - 0s - loss: 7.7069e-04 - 28ms/epoch - 2ms/step
# Epoch 244/500
# 14/14 - 0s - loss: 6.9243e-04 - 28ms/epoch - 2ms/step
# Epoch 245/500
# 14/14 - 0s - loss: 6.1899e-04 - 28ms/epoch - 2ms/step
# Epoch 246/500
# 14/14 - 0s - loss: 6.7375e-04 - 31ms/epoch - 2ms/step
# Epoch 247/500
# 14/14 - 0s - loss: 6.9053e-04 - 28ms/epoch - 2ms/step
# Epoch 248/500
# 14/14 - 0s - loss: 8.0233e-04 - 27ms/epoch - 2ms/step
# Epoch 249/500
# 14/14 - 0s - loss: 8.7212e-04 - 27ms/epoch - 2ms/step
# Epoch 250/500
# 14/14 - 0s - loss: 0.0010 - 27ms/epoch - 2ms/step
# Epoch 251/500
# 14/14 - 0s - loss: 9.4056e-04 - 27ms/epoch - 2ms/step
# Epoch 252/500
# 14/14 - 0s - loss: 9.7132e-04 - 37ms/epoch - 3ms/step
# Epoch 253/500
# 14/14 - 0s - loss: 6.5157e-04 - 37ms/epoch - 3ms/step
# Epoch 254/500
# 14/14 - 0s - loss: 9.0613e-04 - 38ms/epoch - 3ms/step
# Epoch 255/500
# 14/14 - 0s - loss: 7.9212e-04 - 44ms/epoch - 3ms/step
# Epoch 256/500
# 14/14 - 0s - loss: 7.6536e-04 - 43ms/epoch - 3ms/step
# Epoch 257/500
# 14/14 - 0s - loss: 8.1844e-04 - 46ms/epoch - 3ms/step
# Epoch 258/500
# 14/14 - 0s - loss: 7.7485e-04 - 34ms/epoch - 2ms/step
# Epoch 259/500
# 14/14 - 0s - loss: 9.4297e-04 - 32ms/epoch - 2ms/step
# Epoch 260/500
# 14/14 - 0s - loss: 7.9214e-04 - 34ms/epoch - 2ms/step
# Epoch 261/500
# 14/14 - 0s - loss: 6.7579e-04 - 45ms/epoch - 3ms/step
# Epoch 262/500
# 14/14 - 0s - loss: 7.8675e-04 - 44ms/epoch - 3ms/step
# Epoch 263/500
# 14/14 - 0s - loss: 7.3396e-04 - 42ms/epoch - 3ms/step
# Epoch 264/500
# 14/14 - 0s - loss: 6.7375e-04 - 38ms/epoch - 3ms/step
# Epoch 265/500
# 14/14 - 0s - loss: 7.8595e-04 - 33ms/epoch - 2ms/step
# Epoch 266/500
# 14/14 - 0s - loss: 5.5442e-04 - 39ms/epoch - 3ms/step
# Epoch 267/500
# 14/14 - 0s - loss: 5.3925e-04 - 35ms/epoch - 2ms/step
# Epoch 268/500
# 14/14 - 0s - loss: 7.3618e-04 - 35ms/epoch - 3ms/step
# Epoch 269/500
# 14/14 - 0s - loss: 6.0965e-04 - 37ms/epoch - 3ms/step
# Epoch 270/500
# 14/14 - 0s - loss: 6.2233e-04 - 35ms/epoch - 2ms/step
# Epoch 271/500
# 14/14 - 0s - loss: 6.3327e-04 - 40ms/epoch - 3ms/step
# Epoch 272/500
# 14/14 - 0s - loss: 8.6802e-04 - 35ms/epoch - 2ms/step
# Epoch 273/500
# 14/14 - 0s - loss: 8.2546e-04 - 40ms/epoch - 3ms/step
# Epoch 274/500
# 14/14 - 0s - loss: 6.0642e-04 - 41ms/epoch - 3ms/step
# Epoch 275/500
# 14/14 - 0s - loss: 5.5806e-04 - 38ms/epoch - 3ms/step
# Epoch 276/500
# 14/14 - 0s - loss: 5.9196e-04 - 36ms/epoch - 3ms/step
# Epoch 277/500
# 14/14 - 0s - loss: 6.2446e-04 - 42ms/epoch - 3ms/step
# Epoch 278/500
# 14/14 - 0s - loss: 0.0011 - 34ms/epoch - 2ms/step
# Epoch 279/500
# 14/14 - 0s - loss: 8.1682e-04 - 38ms/epoch - 3ms/step
# Epoch 280/500
# 14/14 - 0s - loss: 6.7419e-04 - 42ms/epoch - 3ms/step
# Epoch 281/500
# 14/14 - 0s - loss: 5.4989e-04 - 34ms/epoch - 2ms/step
# Epoch 282/500
# 14/14 - 0s - loss: 8.0170e-04 - 33ms/epoch - 2ms/step
# Epoch 283/500
# 14/14 - 0s - loss: 6.6365e-04 - 34ms/epoch - 2ms/step
# Epoch 284/500
# 14/14 - 0s - loss: 5.0924e-04 - 35ms/epoch - 2ms/step
# Epoch 285/500
# 14/14 - 0s - loss: 5.8577e-04 - 44ms/epoch - 3ms/step
# Epoch 286/500
# 14/14 - 0s - loss: 5.1611e-04 - 48ms/epoch - 3ms/step
# Epoch 287/500
# 14/14 - 0s - loss: 4.4492e-04 - 37ms/epoch - 3ms/step
# Epoch 288/500
# 14/14 - 0s - loss: 4.6952e-04 - 49ms/epoch - 3ms/step
# Epoch 289/500
# 14/14 - 0s - loss: 5.1643e-04 - 49ms/epoch - 4ms/step
# Epoch 290/500
# 14/14 - 0s - loss: 5.3980e-04 - 43ms/epoch - 3ms/step
# Epoch 291/500
# 14/14 - 0s - loss: 5.0960e-04 - 35ms/epoch - 3ms/step
# Epoch 292/500
# 14/14 - 0s - loss: 6.5488e-04 - 36ms/epoch - 3ms/step
# Epoch 293/500
# 14/14 - 0s - loss: 4.1429e-04 - 38ms/epoch - 3ms/step
# Epoch 294/500
# 14/14 - 0s - loss: 4.7636e-04 - 39ms/epoch - 3ms/step
# Epoch 295/500
# 14/14 - 0s - loss: 5.3614e-04 - 34ms/epoch - 2ms/step
# Epoch 296/500
# 14/14 - 0s - loss: 5.4016e-04 - 34ms/epoch - 2ms/step
# Epoch 297/500
# 14/14 - 0s - loss: 5.8467e-04 - 34ms/epoch - 2ms/step
# Epoch 298/500
# 14/14 - 0s - loss: 4.8666e-04 - 36ms/epoch - 3ms/step
# Epoch 299/500
# 14/14 - 0s - loss: 7.0327e-04 - 36ms/epoch - 3ms/step
# Epoch 300/500
# 14/14 - 0s - loss: 6.8044e-04 - 37ms/epoch - 3ms/step
# Epoch 301/500
# 14/14 - 0s - loss: 6.1454e-04 - 40ms/epoch - 3ms/step
# Epoch 302/500
# 14/14 - 0s - loss: 6.8473e-04 - 36ms/epoch - 3ms/step
# Epoch 303/500
# 14/14 - 0s - loss: 6.9064e-04 - 37ms/epoch - 3ms/step
# Epoch 304/500
# 14/14 - 0s - loss: 5.1977e-04 - 39ms/epoch - 3ms/step
# Epoch 305/500
# 14/14 - 0s - loss: 5.2881e-04 - 35ms/epoch - 3ms/step
# Epoch 306/500
# 14/14 - 0s - loss: 4.3019e-04 - 35ms/epoch - 3ms/step
# Epoch 307/500
# 14/14 - 0s - loss: 4.6193e-04 - 49ms/epoch - 3ms/step
# Epoch 308/500
# 14/14 - 0s - loss: 4.2696e-04 - 46ms/epoch - 3ms/step
# Epoch 309/500
# 14/14 - 0s - loss: 4.5676e-04 - 46ms/epoch - 3ms/step
# Epoch 310/500
# 14/14 - 0s - loss: 4.1613e-04 - 42ms/epoch - 3ms/step
# Epoch 311/500
# 14/14 - 0s - loss: 5.0208e-04 - 44ms/epoch - 3ms/step
# Epoch 312/500
# 14/14 - 0s - loss: 5.3398e-04 - 43ms/epoch - 3ms/step
# Epoch 313/500
# 14/14 - 0s - loss: 4.3739e-04 - 55ms/epoch - 4ms/step
# Epoch 314/500
# 14/14 - 0s - loss: 4.6469e-04 - 45ms/epoch - 3ms/step
# Epoch 315/500
# 14/14 - 0s - loss: 3.8483e-04 - 41ms/epoch - 3ms/step
# Epoch 316/500
# 14/14 - 0s - loss: 3.6514e-04 - 40ms/epoch - 3ms/step
# Epoch 317/500
# 14/14 - 0s - loss: 3.3474e-04 - 40ms/epoch - 3ms/step
# Epoch 318/500
# 14/14 - 0s - loss: 4.1917e-04 - 41ms/epoch - 3ms/step
# Epoch 319/500
# 14/14 - 0s - loss: 4.2135e-04 - 40ms/epoch - 3ms/step
# Epoch 320/500
# 14/14 - 0s - loss: 4.1310e-04 - 43ms/epoch - 3ms/step
# Epoch 321/500
# 14/14 - 0s - loss: 5.2901e-04 - 52ms/epoch - 4ms/step
# Epoch 322/500
# 14/14 - 0s - loss: 4.5354e-04 - 46ms/epoch - 3ms/step
# Epoch 323/500
# 14/14 - 0s - loss: 4.3657e-04 - 39ms/epoch - 3ms/step
# Epoch 324/500
# 14/14 - 0s - loss: 4.7270e-04 - 39ms/epoch - 3ms/step
# Epoch 325/500
# 14/14 - 0s - loss: 5.5447e-04 - 40ms/epoch - 3ms/step
# Epoch 326/500
# 14/14 - 0s - loss: 4.3060e-04 - 63ms/epoch - 4ms/step
# Epoch 327/500
# 14/14 - 0s - loss: 5.2207e-04 - 44ms/epoch - 3ms/step
# Epoch 328/500
# 14/14 - 0s - loss: 4.9009e-04 - 34ms/epoch - 2ms/step
# Epoch 329/500
# 14/14 - 0s - loss: 4.4843e-04 - 40ms/epoch - 3ms/step
# Epoch 330/500
# 14/14 - 0s - loss: 4.7590e-04 - 47ms/epoch - 3ms/step
# Epoch 331/500
# 14/14 - 0s - loss: 4.1660e-04 - 40ms/epoch - 3ms/step
# Epoch 332/500
# 14/14 - 0s - loss: 6.6167e-04 - 39ms/epoch - 3ms/step
# Epoch 333/500
# 14/14 - 0s - loss: 4.4136e-04 - 44ms/epoch - 3ms/step
# Epoch 334/500
# 14/14 - 0s - loss: 4.1984e-04 - 45ms/epoch - 3ms/step
# Epoch 335/500
# 14/14 - 0s - loss: 3.3851e-04 - 45ms/epoch - 3ms/step
# Epoch 336/500
# 14/14 - 0s - loss: 3.4990e-04 - 50ms/epoch - 4ms/step
# Epoch 337/500
# 14/14 - 0s - loss: 3.5044e-04 - 42ms/epoch - 3ms/step
# Epoch 338/500
# 14/14 - 0s - loss: 3.1041e-04 - 51ms/epoch - 4ms/step
# Epoch 339/500
# 14/14 - 0s - loss: 3.3057e-04 - 47ms/epoch - 3ms/step
# Epoch 340/500
# 14/14 - 0s - loss: 4.1934e-04 - 39ms/epoch - 3ms/step
# Epoch 341/500
# 14/14 - 0s - loss: 3.9417e-04 - 36ms/epoch - 3ms/step
# Epoch 342/500
# 14/14 - 0s - loss: 4.2549e-04 - 41ms/epoch - 3ms/step
# Epoch 343/500
# 14/14 - 0s - loss: 3.7886e-04 - 41ms/epoch - 3ms/step
# Epoch 344/500
# 14/14 - 0s - loss: 3.7712e-04 - 40ms/epoch - 3ms/step
# Epoch 345/500
# 14/14 - 0s - loss: 4.7172e-04 - 48ms/epoch - 3ms/step
# Epoch 346/500
# 14/14 - 0s - loss: 5.8122e-04 - 39ms/epoch - 3ms/step
# Epoch 347/500
# 14/14 - 0s - loss: 9.9001e-04 - 47ms/epoch - 3ms/step
# Epoch 348/500
# 14/14 - 0s - loss: 6.8749e-04 - 42ms/epoch - 3ms/step
# Epoch 349/500
# 14/14 - 0s - loss: 4.4785e-04 - 44ms/epoch - 3ms/step
# Epoch 350/500
# 14/14 - 0s - loss: 4.5504e-04 - 45ms/epoch - 3ms/step
# Epoch 351/500
# 14/14 - 0s - loss: 3.9067e-04 - 36ms/epoch - 3ms/step
# Epoch 352/500
# 14/14 - 0s - loss: 5.1863e-04 - 47ms/epoch - 3ms/step
# Epoch 353/500
# 14/14 - 0s - loss: 5.4359e-04 - 43ms/epoch - 3ms/step
# Epoch 354/500
# 14/14 - 0s - loss: 5.0214e-04 - 38ms/epoch - 3ms/step
# Epoch 355/500
# 14/14 - 0s - loss: 3.7338e-04 - 39ms/epoch - 3ms/step
# Epoch 356/500
# 14/14 - 0s - loss: 2.8627e-04 - 37ms/epoch - 3ms/step
# Epoch 357/500
# 14/14 - 0s - loss: 3.5319e-04 - 41ms/epoch - 3ms/step
# Epoch 358/500
# 14/14 - 0s - loss: 2.9320e-04 - 33ms/epoch - 2ms/step
# Epoch 359/500
# 14/14 - 0s - loss: 2.7828e-04 - 37ms/epoch - 3ms/step
# Epoch 360/500
# 14/14 - 0s - loss: 2.3864e-04 - 34ms/epoch - 2ms/step
# Epoch 361/500
# 14/14 - 0s - loss: 3.1718e-04 - 27ms/epoch - 2ms/step
# Epoch 362/500
# 14/14 - 0s - loss: 4.1159e-04 - 30ms/epoch - 2ms/step
# Epoch 363/500
# 14/14 - 0s - loss: 2.7739e-04 - 32ms/epoch - 2ms/step
# Epoch 364/500
# 14/14 - 0s - loss: 3.2270e-04 - 32ms/epoch - 2ms/step
# Epoch 365/500
# 14/14 - 0s - loss: 4.4572e-04 - 31ms/epoch - 2ms/step
# Epoch 366/500
# 14/14 - 0s - loss: 4.6390e-04 - 27ms/epoch - 2ms/step
# Epoch 367/500
# 14/14 - 0s - loss: 4.5361e-04 - 27ms/epoch - 2ms/step
# Epoch 368/500
# 14/14 - 0s - loss: 4.0575e-04 - 35ms/epoch - 2ms/step
# Epoch 369/500
# 14/14 - 0s - loss: 3.7070e-04 - 28ms/epoch - 2ms/step
# Epoch 370/500
# 14/14 - 0s - loss: 2.7374e-04 - 29ms/epoch - 2ms/step
# Epoch 371/500
# 14/14 - 0s - loss: 3.6878e-04 - 28ms/epoch - 2ms/step
# Epoch 372/500
# 14/14 - 0s - loss: 3.6311e-04 - 30ms/epoch - 2ms/step
# Epoch 373/500
# 14/14 - 0s - loss: 4.9361e-04 - 30ms/epoch - 2ms/step
# Epoch 374/500
# 14/14 - 0s - loss: 6.2829e-04 - 28ms/epoch - 2ms/step
# Epoch 375/500
# 14/14 - 0s - loss: 3.1402e-04 - 28ms/epoch - 2ms/step
# Epoch 376/500
# 14/14 - 0s - loss: 3.0786e-04 - 30ms/epoch - 2ms/step
# Epoch 377/500
# 14/14 - 0s - loss: 3.5195e-04 - 29ms/epoch - 2ms/step
# Epoch 378/500
# 14/14 - 0s - loss: 3.0786e-04 - 27ms/epoch - 2ms/step
# Epoch 379/500
# 14/14 - 0s - loss: 3.8335e-04 - 33ms/epoch - 2ms/step
# Epoch 380/500
# 14/14 - 0s - loss: 3.2602e-04 - 27ms/epoch - 2ms/step
# Epoch 381/500
# 14/14 - 0s - loss: 3.4332e-04 - 30ms/epoch - 2ms/step
# Epoch 382/500
# 14/14 - 0s - loss: 2.7757e-04 - 30ms/epoch - 2ms/step
# Epoch 383/500
# 14/14 - 0s - loss: 2.7553e-04 - 28ms/epoch - 2ms/step
# Epoch 384/500
# 14/14 - 0s - loss: 2.3536e-04 - 29ms/epoch - 2ms/step
# Epoch 385/500
# 14/14 - 0s - loss: 2.6756e-04 - 25ms/epoch - 2ms/step
# Epoch 386/500
# 14/14 - 0s - loss: 2.8219e-04 - 31ms/epoch - 2ms/step
# Epoch 387/500
# 14/14 - 0s - loss: 2.9535e-04 - 27ms/epoch - 2ms/step
# Epoch 388/500
# 14/14 - 0s - loss: 2.7644e-04 - 30ms/epoch - 2ms/step
# Epoch 389/500
# 14/14 - 0s - loss: 4.2782e-04 - 30ms/epoch - 2ms/step
# Epoch 390/500
# 14/14 - 0s - loss: 3.4100e-04 - 36ms/epoch - 3ms/step
# Epoch 391/500
# 14/14 - 0s - loss: 2.7893e-04 - 30ms/epoch - 2ms/step
# Epoch 392/500
# 14/14 - 0s - loss: 2.7203e-04 - 31ms/epoch - 2ms/step
# Epoch 393/500
# 14/14 - 0s - loss: 2.7529e-04 - 26ms/epoch - 2ms/step
# Epoch 394/500
# 14/14 - 0s - loss: 3.2370e-04 - 27ms/epoch - 2ms/step
# Epoch 395/500
# 14/14 - 0s - loss: 6.8942e-04 - 27ms/epoch - 2ms/step
# Epoch 396/500
# 14/14 - 0s - loss: 9.8599e-04 - 30ms/epoch - 2ms/step
# Epoch 397/500
# 14/14 - 0s - loss: 5.0196e-04 - 29ms/epoch - 2ms/step
# Epoch 398/500
# 14/14 - 0s - loss: 3.4716e-04 - 27ms/epoch - 2ms/step
# Epoch 399/500
# 14/14 - 0s - loss: 2.8650e-04 - 27ms/epoch - 2ms/step
# Epoch 400/500
# 14/14 - 0s - loss: 3.1118e-04 - 29ms/epoch - 2ms/step
# Epoch 401/500
# 14/14 - 0s - loss: 3.1470e-04 - 30ms/epoch - 2ms/step
# Epoch 402/500
# 14/14 - 0s - loss: 2.4839e-04 - 30ms/epoch - 2ms/step
# Epoch 403/500
# 14/14 - 0s - loss: 2.8970e-04 - 26ms/epoch - 2ms/step
# Epoch 404/500
# 14/14 - 0s - loss: 2.4522e-04 - 37ms/epoch - 3ms/step
# Epoch 405/500
# 14/14 - 0s - loss: 2.3463e-04 - 26ms/epoch - 2ms/step
# Epoch 406/500
# 14/14 - 0s - loss: 2.2360e-04 - 29ms/epoch - 2ms/step
# Epoch 407/500
# 14/14 - 0s - loss: 2.9173e-04 - 27ms/epoch - 2ms/step
# Epoch 408/500
# 14/14 - 0s - loss: 3.0590e-04 - 29ms/epoch - 2ms/step
# Epoch 409/500
# 14/14 - 0s - loss: 2.3886e-04 - 29ms/epoch - 2ms/step
# Epoch 410/500
# 14/14 - 0s - loss: 2.8026e-04 - 28ms/epoch - 2ms/step
# Epoch 411/500
# 14/14 - 0s - loss: 2.7824e-04 - 28ms/epoch - 2ms/step
# Epoch 412/500
# 14/14 - 0s - loss: 3.8536e-04 - 30ms/epoch - 2ms/step
# Epoch 413/500
# 14/14 - 0s - loss: 2.5169e-04 - 27ms/epoch - 2ms/step
# Epoch 414/500
# 14/14 - 0s - loss: 2.5816e-04 - 28ms/epoch - 2ms/step
# Epoch 415/500
# 14/14 - 0s - loss: 2.7381e-04 - 29ms/epoch - 2ms/step
# Epoch 416/500
# 14/14 - 0s - loss: 3.5279e-04 - 28ms/epoch - 2ms/step
# Epoch 417/500
# 14/14 - 0s - loss: 3.0404e-04 - 27ms/epoch - 2ms/step
# Epoch 418/500
# 14/14 - 0s - loss: 2.4385e-04 - 31ms/epoch - 2ms/step
# Epoch 419/500
# 14/14 - 0s - loss: 3.5935e-04 - 29ms/epoch - 2ms/step
# Epoch 420/500
# 14/14 - 0s - loss: 4.7766e-04 - 32ms/epoch - 2ms/step
# Epoch 421/500
# 14/14 - 0s - loss: 2.5506e-04 - 34ms/epoch - 2ms/step
# Epoch 422/500
# 14/14 - 0s - loss: 2.8469e-04 - 31ms/epoch - 2ms/step
# Epoch 423/500
# 14/14 - 0s - loss: 2.6906e-04 - 26ms/epoch - 2ms/step
# Epoch 424/500
# 14/14 - 0s - loss: 4.0449e-04 - 30ms/epoch - 2ms/step
# Epoch 425/500
# 14/14 - 0s - loss: 3.1135e-04 - 26ms/epoch - 2ms/step
# Epoch 426/500
# 14/14 - 0s - loss: 5.1704e-04 - 30ms/epoch - 2ms/step
# Epoch 427/500
# 14/14 - 0s - loss: 4.0470e-04 - 27ms/epoch - 2ms/step
# Epoch 428/500
# 14/14 - 0s - loss: 3.5702e-04 - 27ms/epoch - 2ms/step
# Epoch 429/500
# 14/14 - 0s - loss: 4.8816e-04 - 28ms/epoch - 2ms/step
# Epoch 430/500
# 14/14 - 0s - loss: 3.4587e-04 - 28ms/epoch - 2ms/step
# Epoch 431/500
# 14/14 - 0s - loss: 2.7087e-04 - 27ms/epoch - 2ms/step
# Epoch 432/500
# 14/14 - 0s - loss: 3.0079e-04 - 32ms/epoch - 2ms/step
# Epoch 433/500
# 14/14 - 0s - loss: 2.7119e-04 - 28ms/epoch - 2ms/step
# Epoch 434/500
# 14/14 - 0s - loss: 2.2200e-04 - 27ms/epoch - 2ms/step
# Epoch 435/500
# 14/14 - 0s - loss: 2.8251e-04 - 31ms/epoch - 2ms/step
# Epoch 436/500
# 14/14 - 0s - loss: 2.8294e-04 - 28ms/epoch - 2ms/step
# Epoch 437/500
# 14/14 - 0s - loss: 2.7031e-04 - 26ms/epoch - 2ms/step
# Epoch 438/500
# 14/14 - 0s - loss: 2.8321e-04 - 28ms/epoch - 2ms/step
# Epoch 439/500
# 14/14 - 0s - loss: 2.7297e-04 - 28ms/epoch - 2ms/step
# Epoch 440/500
# 14/14 - 0s - loss: 2.5915e-04 - 27ms/epoch - 2ms/step
# Epoch 441/500
# 14/14 - 0s - loss: 2.5754e-04 - 29ms/epoch - 2ms/step
# Epoch 442/500
# 14/14 - 0s - loss: 3.0432e-04 - 28ms/epoch - 2ms/step
# Epoch 443/500
# 14/14 - 0s - loss: 1.9805e-04 - 28ms/epoch - 2ms/step
# Epoch 444/500
# 14/14 - 0s - loss: 2.0604e-04 - 30ms/epoch - 2ms/step
# Epoch 445/500
# 14/14 - 0s - loss: 2.0403e-04 - 27ms/epoch - 2ms/step
# Epoch 446/500
# 14/14 - 0s - loss: 2.0589e-04 - 27ms/epoch - 2ms/step
# Epoch 447/500
# 14/14 - 0s - loss: 2.3471e-04 - 29ms/epoch - 2ms/step
# Epoch 448/500
# 14/14 - 0s - loss: 1.8311e-04 - 27ms/epoch - 2ms/step
# Epoch 449/500
# 14/14 - 0s - loss: 2.8008e-04 - 26ms/epoch - 2ms/step
# Epoch 450/500
# 14/14 - 0s - loss: 2.0696e-04 - 31ms/epoch - 2ms/step
# Epoch 451/500
# 14/14 - 0s - loss: 2.4768e-04 - 33ms/epoch - 2ms/step
# Epoch 452/500
# 14/14 - 0s - loss: 2.4288e-04 - 27ms/epoch - 2ms/step
# Epoch 453/500
# 14/14 - 0s - loss: 3.8757e-04 - 29ms/epoch - 2ms/step
# Epoch 454/500
# 14/14 - 0s - loss: 3.9089e-04 - 36ms/epoch - 3ms/step
# Epoch 455/500
# 14/14 - 0s - loss: 3.7695e-04 - 30ms/epoch - 2ms/step
# Epoch 456/500
# 14/14 - 0s - loss: 3.3723e-04 - 29ms/epoch - 2ms/step
# Epoch 457/500
# 14/14 - 0s - loss: 4.0411e-04 - 26ms/epoch - 2ms/step
# Epoch 458/500
# 14/14 - 0s - loss: 2.7548e-04 - 31ms/epoch - 2ms/step
# Epoch 459/500
# 14/14 - 0s - loss: 2.8771e-04 - 29ms/epoch - 2ms/step
# Epoch 460/500
# 14/14 - 0s - loss: 2.6802e-04 - 29ms/epoch - 2ms/step
# Epoch 461/500
# 14/14 - 0s - loss: 1.6598e-04 - 29ms/epoch - 2ms/step
# Epoch 462/500
# 14/14 - 0s - loss: 1.9283e-04 - 27ms/epoch - 2ms/step
# Epoch 463/500
# 14/14 - 0s - loss: 1.7933e-04 - 30ms/epoch - 2ms/step
# Epoch 464/500
# 14/14 - 0s - loss: 1.5848e-04 - 25ms/epoch - 2ms/step
# Epoch 465/500
# 14/14 - 0s - loss: 1.6892e-04 - 27ms/epoch - 2ms/step
# Epoch 466/500
# 14/14 - 0s - loss: 2.0829e-04 - 29ms/epoch - 2ms/step
# Epoch 467/500
# 14/14 - 0s - loss: 1.7094e-04 - 33ms/epoch - 2ms/step
# Epoch 468/500
# 14/14 - 0s - loss: 1.3445e-04 - 33ms/epoch - 2ms/step
# Epoch 469/500
# 14/14 - 0s - loss: 1.8839e-04 - 28ms/epoch - 2ms/step
# Epoch 470/500
# 14/14 - 0s - loss: 2.2578e-04 - 27ms/epoch - 2ms/step
# Epoch 471/500
# 14/14 - 0s - loss: 2.1775e-04 - 28ms/epoch - 2ms/step
# Epoch 472/500
# 14/14 - 0s - loss: 2.0616e-04 - 32ms/epoch - 2ms/step
# Epoch 473/500
# 14/14 - 0s - loss: 1.9176e-04 - 27ms/epoch - 2ms/step
# Epoch 474/500
# 14/14 - 0s - loss: 1.5617e-04 - 31ms/epoch - 2ms/step
# Epoch 475/500
# 14/14 - 0s - loss: 2.2295e-04 - 30ms/epoch - 2ms/step
# Epoch 476/500
# 14/14 - 0s - loss: 2.5347e-04 - 32ms/epoch - 2ms/step
# Epoch 477/500
# 14/14 - 0s - loss: 2.0123e-04 - 28ms/epoch - 2ms/step
# Epoch 478/500
# 14/14 - 0s - loss: 1.6835e-04 - 29ms/epoch - 2ms/step
# Epoch 479/500
# 14/14 - 0s - loss: 1.5012e-04 - 28ms/epoch - 2ms/step
# Epoch 480/500
# 14/14 - 0s - loss: 1.5226e-04 - 37ms/epoch - 3ms/step
# Epoch 481/500
# 14/14 - 0s - loss: 1.6147e-04 - 28ms/epoch - 2ms/step
# Epoch 482/500
# 14/14 - 0s - loss: 2.0802e-04 - 28ms/epoch - 2ms/step
# Epoch 483/500
# 14/14 - 0s - loss: 1.3966e-04 - 28ms/epoch - 2ms/step
# Epoch 484/500
# 14/14 - 0s - loss: 1.8120e-04 - 28ms/epoch - 2ms/step
# Epoch 485/500
# 14/14 - 0s - loss: 1.5573e-04 - 31ms/epoch - 2ms/step
# Epoch 486/500
# 14/14 - 0s - loss: 1.7163e-04 - 41ms/epoch - 3ms/step
# Epoch 487/500
# 14/14 - 0s - loss: 1.3228e-04 - 31ms/epoch - 2ms/step
# Epoch 488/500
# 14/14 - 0s - loss: 1.1512e-04 - 27ms/epoch - 2ms/step
# Epoch 489/500
# 14/14 - 0s - loss: 2.0382e-04 - 28ms/epoch - 2ms/step
# Epoch 490/500
# 14/14 - 0s - loss: 4.0671e-04 - 28ms/epoch - 2ms/step
# Epoch 491/500
# 14/14 - 0s - loss: 2.9977e-04 - 34ms/epoch - 2ms/step
# Epoch 492/500
# 14/14 - 0s - loss: 3.5220e-04 - 28ms/epoch - 2ms/step
# Epoch 493/500
# 14/14 - 0s - loss: 2.8296e-04 - 32ms/epoch - 2ms/step
# Epoch 494/500
# 14/14 - 0s - loss: 2.0114e-04 - 33ms/epoch - 2ms/step
# Epoch 495/500
# 14/14 - 0s - loss: 2.3218e-04 - 30ms/epoch - 2ms/step
# Epoch 496/500
# 14/14 - 0s - loss: 3.5552e-04 - 37ms/epoch - 3ms/step
# Epoch 497/500
# 14/14 - 0s - loss: 6.5891e-04 - 30ms/epoch - 2ms/step
# Epoch 498/500
# 14/14 - 0s - loss: 6.3795e-04 - 27ms/epoch - 2ms/step
# Epoch 499/500
# 14/14 - 0s - loss: 4.6653e-04 - 28ms/epoch - 2ms/step
# Epoch 500/500
# 14/14 - 0s - loss: 3.3306e-04 - 27ms/epoch - 2ms/step
# 2/2 [==============================] - 0s 5ms/step
# Test RMSE: 3290.33
# Test MAE: 2030.02
# Test R^2: 0.94
# Test MAPE: 0.07
# Test Adjusted R^2: 0.92
# Training Time: 21.35 seconds

# %%
#Với Dropout để tránh overfitting

import pandas as pd
import numpy as np
import time
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_absolute_error, r2_score, mean_absolute_percentage_error
from keras.models import Sequential
from keras.layers import Dense, Dropout

# Đọc dữ liệu từ tệp CSV
df = pd.read_csv('Dataa_Service.csv')

# Chọn các cột đầu vào và đầu ra
X = df[['Month', 'Year', 'CPI', 'GDP', 'Temperature', 'USD/VND']]
y = df['Service']

# Chuẩn hóa dữ liệu
scaler_X = MinMaxScaler()
scaler_y = MinMaxScaler()
X_scaled = scaler_X.fit_transform(X)
y_scaled = scaler_y.fit_transform(y.values.reshape(-1, 1))

# Chia dữ liệu thành tập huấn luyện và kiểm tra
X_train, X_test, y_train, y_test = train_test_split(X_scaled, y_scaled, test_size=0.2, random_state=42)

# Xây dựng mô hình mạng nơron với Dropout
model2 = Sequential()
model2.add(Dense(128, input_dim=X_train.shape[1], activation='relu'))
model2.add(Dropout(0.5))
model2.add(Dense(64, activation='relu'))
model2.add(Dropout(0.5))
model2.add(Dense(32, activation='relu'))
model2.add(Dense(1))

# Biên dịch mô hình
model2.compile(loss='mean_squared_error', optimizer='adam')

# Đo thời gian bắt đầu huấn luyện
start_time = time.time()

# Huấn luyện mô hình
model2.fit(X_train, y_train, epochs=100, batch_size=10, verbose=2)

# Đo thời gian kết thúc huấn luyện
end_time = time.time()

# Dự báo trên tập kiểm tra
y_pred2_scaled = model2.predict(X_test)

# Chuyển đổi lại dữ liệu về dạng ban đầu
y_pred2 = scaler_y.inverse_transform(y_pred2_scaled)
y_test_inverse = scaler_y.inverse_transform(y_test)

# Tính toán các chỉ số đánh giá
mse2 = np.mean((y_pred2 - y_test_inverse) ** 2)
rmse2 = np.sqrt(mse2)
mae2 = mean_absolute_error(y_test_inverse, y_pred2)
r22 = r2_score(y_test_inverse, y_pred2)
mape2 = mean_absolute_percentage_error(y_test_inverse, y_pred2)
adjusted_r22 = 1 - (1 - r22) * ((len(y_test_inverse) - 1) / (len(y_test_inverse) - X_test.shape[1] - 1))

# In các chỉ số đánh giá
print(f'Model 2 - Test RMSE: {rmse2:.2f}')
print(f'Model 2 - Test MAE: {mae2:.2f}')
print(f'Model 2 - Test R^2: {r22:.2f}')
print(f'Model 2 - Test MAPE: {mape2:.2f}')
print(f'Model 2 - Test Adjusted R^2: {adjusted_r22:.2f}')
print(f'Model 2 - Training Time: {end_time - start_time:.2f} seconds')
# Out:
# Epoch 1/100
# 14/14 - 2s - loss: 0.3476 - 2s/epoch - 131ms/step
# Epoch 2/100
# 14/14 - 0s - loss: 0.1078 - 77ms/epoch - 6ms/step
# Epoch 3/100
# 14/14 - 0s - loss: 0.0889 - 41ms/epoch - 3ms/step
# Epoch 4/100
# 14/14 - 0s - loss: 0.0676 - 39ms/epoch - 3ms/step
# Epoch 5/100
# 14/14 - 0s - loss: 0.0562 - 44ms/epoch - 3ms/step
# Epoch 6/100
# 14/14 - 0s - loss: 0.0523 - 43ms/epoch - 3ms/step
# Epoch 7/100
# 14/14 - 0s - loss: 0.0424 - 45ms/epoch - 3ms/step
# Epoch 8/100
# 14/14 - 0s - loss: 0.0348 - 43ms/epoch - 3ms/step
# Epoch 9/100
# 14/14 - 0s - loss: 0.0412 - 45ms/epoch - 3ms/step
# Epoch 10/100
# 14/14 - 0s - loss: 0.0280 - 49ms/epoch - 4ms/step
# Epoch 11/100
# 14/14 - 0s - loss: 0.0325 - 46ms/epoch - 3ms/step
# Epoch 12/100
# 14/14 - 0s - loss: 0.0232 - 43ms/epoch - 3ms/step
# Epoch 13/100
# 14/14 - 0s - loss: 0.0271 - 46ms/epoch - 3ms/step
# Epoch 14/100
# 14/14 - 0s - loss: 0.0248 - 42ms/epoch - 3ms/step
# Epoch 15/100
# 14/14 - 0s - loss: 0.0261 - 40ms/epoch - 3ms/step
# Epoch 16/100
# 14/14 - 0s - loss: 0.0243 - 43ms/epoch - 3ms/step
# Epoch 17/100
# 14/14 - 0s - loss: 0.0268 - 46ms/epoch - 3ms/step
# Epoch 18/100
# 14/14 - 0s - loss: 0.0219 - 46ms/epoch - 3ms/step
# Epoch 19/100
# 14/14 - 0s - loss: 0.0224 - 41ms/epoch - 3ms/step
# Epoch 20/100
# 14/14 - 0s - loss: 0.0268 - 48ms/epoch - 3ms/step
# Epoch 21/100
# 14/14 - 0s - loss: 0.0211 - 51ms/epoch - 4ms/step
# Epoch 22/100
# 14/14 - 0s - loss: 0.0155 - 40ms/epoch - 3ms/step
# Epoch 23/100
# 14/14 - 0s - loss: 0.0196 - 39ms/epoch - 3ms/step
# Epoch 24/100
# 14/14 - 0s - loss: 0.0227 - 40ms/epoch - 3ms/step
# Epoch 25/100
# 14/14 - 0s - loss: 0.0205 - 37ms/epoch - 3ms/step
# Epoch 26/100
# 14/14 - 0s - loss: 0.0187 - 37ms/epoch - 3ms/step
# Epoch 27/100
# 14/14 - 0s - loss: 0.0203 - 39ms/epoch - 3ms/step
# Epoch 28/100
# 14/14 - 0s - loss: 0.0193 - 40ms/epoch - 3ms/step
# Epoch 29/100
# 14/14 - 0s - loss: 0.0229 - 41ms/epoch - 3ms/step
# Epoch 30/100
# 14/14 - 0s - loss: 0.0233 - 38ms/epoch - 3ms/step
# Epoch 31/100
# 14/14 - 0s - loss: 0.0221 - 40ms/epoch - 3ms/step
# Epoch 32/100
# 14/14 - 0s - loss: 0.0181 - 37ms/epoch - 3ms/step
# Epoch 33/100
# 14/14 - 0s - loss: 0.0174 - 40ms/epoch - 3ms/step
# Epoch 34/100
# 14/14 - 0s - loss: 0.0176 - 38ms/epoch - 3ms/step
# Epoch 35/100
# 14/14 - 0s - loss: 0.0150 - 42ms/epoch - 3ms/step
# Epoch 36/100
# 14/14 - 0s - loss: 0.0166 - 41ms/epoch - 3ms/step
# Epoch 37/100
# 14/14 - 0s - loss: 0.0206 - 45ms/epoch - 3ms/step
# Epoch 38/100
# 14/14 - 0s - loss: 0.0157 - 35ms/epoch - 2ms/step
# Epoch 39/100
# 14/14 - 0s - loss: 0.0183 - 36ms/epoch - 3ms/step
# Epoch 40/100
# 14/14 - 0s - loss: 0.0196 - 39ms/epoch - 3ms/step
# Epoch 41/100
# 14/14 - 0s - loss: 0.0152 - 44ms/epoch - 3ms/step
# Epoch 42/100
# 14/14 - 0s - loss: 0.0165 - 40ms/epoch - 3ms/step
# Epoch 43/100
# 14/14 - 0s - loss: 0.0171 - 35ms/epoch - 2ms/step
# Epoch 44/100
# 14/14 - 0s - loss: 0.0185 - 34ms/epoch - 2ms/step
# Epoch 45/100
# 14/14 - 0s - loss: 0.0198 - 46ms/epoch - 3ms/step
# Epoch 46/100
# 14/14 - 0s - loss: 0.0168 - 32ms/epoch - 2ms/step
# Epoch 47/100
# 14/14 - 0s - loss: 0.0153 - 34ms/epoch - 2ms/step
# Epoch 48/100
# 14/14 - 0s - loss: 0.0152 - 31ms/epoch - 2ms/step
# Epoch 49/100
# 14/14 - 0s - loss: 0.0145 - 39ms/epoch - 3ms/step
# Epoch 50/100
# 14/14 - 0s - loss: 0.0163 - 30ms/epoch - 2ms/step
# Epoch 51/100
# 14/14 - 0s - loss: 0.0137 - 34ms/epoch - 2ms/step
# Epoch 52/100
# 14/14 - 0s - loss: 0.0143 - 31ms/epoch - 2ms/step
# Epoch 53/100
# 14/14 - 0s - loss: 0.0148 - 31ms/epoch - 2ms/step
# Epoch 54/100
# 14/14 - 0s - loss: 0.0122 - 30ms/epoch - 2ms/step
# Epoch 55/100
# 14/14 - 0s - loss: 0.0102 - 30ms/epoch - 2ms/step
# Epoch 56/100
# 14/14 - 0s - loss: 0.0118 - 32ms/epoch - 2ms/step
# Epoch 57/100
# 14/14 - 0s - loss: 0.0173 - 31ms/epoch - 2ms/step
# Epoch 58/100
# 14/14 - 0s - loss: 0.0130 - 28ms/epoch - 2ms/step
# Epoch 59/100
# 14/14 - 0s - loss: 0.0125 - 38ms/epoch - 3ms/step
# Epoch 60/100
# 14/14 - 0s - loss: 0.0106 - 38ms/epoch - 3ms/step
# Epoch 61/100
# 14/14 - 0s - loss: 0.0147 - 50ms/epoch - 4ms/step
# Epoch 62/100
# 14/14 - 0s - loss: 0.0100 - 40ms/epoch - 3ms/step
# Epoch 63/100
# 14/14 - 0s - loss: 0.0163 - 32ms/epoch - 2ms/step
# Epoch 64/100
# 14/14 - 0s - loss: 0.0097 - 35ms/epoch - 3ms/step
# Epoch 65/100
# 14/14 - 0s - loss: 0.0106 - 31ms/epoch - 2ms/step
# Epoch 66/100
# 14/14 - 0s - loss: 0.0106 - 30ms/epoch - 2ms/step
# Epoch 67/100
# 14/14 - 0s - loss: 0.0120 - 38ms/epoch - 3ms/step
# Epoch 68/100
# 14/14 - 0s - loss: 0.0116 - 30ms/epoch - 2ms/step
# Epoch 69/100
# 14/14 - 0s - loss: 0.0120 - 31ms/epoch - 2ms/step
# Epoch 70/100
# 14/14 - 0s - loss: 0.0130 - 32ms/epoch - 2ms/step
# Epoch 71/100
# 14/14 - 0s - loss: 0.0105 - 30ms/epoch - 2ms/step
# Epoch 72/100
# 14/14 - 0s - loss: 0.0125 - 32ms/epoch - 2ms/step
# Epoch 73/100
# 14/14 - 0s - loss: 0.0132 - 44ms/epoch - 3ms/step
# Epoch 74/100
# 14/14 - 0s - loss: 0.0116 - 32ms/epoch - 2ms/step
# Epoch 75/100
# 14/14 - 0s - loss: 0.0126 - 29ms/epoch - 2ms/step
# Epoch 76/100
# 14/14 - 0s - loss: 0.0089 - 28ms/epoch - 2ms/step
# Epoch 77/100
# 14/14 - 0s - loss: 0.0108 - 29ms/epoch - 2ms/step
# Epoch 78/100
# 14/14 - 0s - loss: 0.0115 - 29ms/epoch - 2ms/step
# Epoch 79/100
# 14/14 - 0s - loss: 0.0106 - 31ms/epoch - 2ms/step
# Epoch 80/100
# 14/14 - 0s - loss: 0.0097 - 31ms/epoch - 2ms/step
# Epoch 81/100
# 14/14 - 0s - loss: 0.0110 - 30ms/epoch - 2ms/step
# Epoch 82/100
# 14/14 - 0s - loss: 0.0118 - 31ms/epoch - 2ms/step
# Epoch 83/100
# 14/14 - 0s - loss: 0.0118 - 30ms/epoch - 2ms/step
# Epoch 84/100
# 14/14 - 0s - loss: 0.0117 - 30ms/epoch - 2ms/step
# Epoch 85/100
# 14/14 - 0s - loss: 0.0104 - 35ms/epoch - 3ms/step
# Epoch 86/100
# 14/14 - 0s - loss: 0.0100 - 34ms/epoch - 2ms/step
# Epoch 87/100
# 14/14 - 0s - loss: 0.0097 - 27ms/epoch - 2ms/step
# Epoch 88/100
# 14/14 - 0s - loss: 0.0102 - 28ms/epoch - 2ms/step
# Epoch 89/100
# 14/14 - 0s - loss: 0.0099 - 29ms/epoch - 2ms/step
# Epoch 90/100
# 14/14 - 0s - loss: 0.0100 - 31ms/epoch - 2ms/step
# Epoch 91/100
# 14/14 - 0s - loss: 0.0097 - 31ms/epoch - 2ms/step
# Epoch 92/100
# 14/14 - 0s - loss: 0.0090 - 28ms/epoch - 2ms/step
# Epoch 93/100
# 14/14 - 0s - loss: 0.0073 - 29ms/epoch - 2ms/step
# Epoch 94/100
# 14/14 - 0s - loss: 0.0108 - 35ms/epoch - 2ms/step
# Epoch 95/100
# 14/14 - 0s - loss: 0.0096 - 28ms/epoch - 2ms/step
# Epoch 96/100
# 14/14 - 0s - loss: 0.0077 - 30ms/epoch - 2ms/step
# Epoch 97/100
# 14/14 - 0s - loss: 0.0086 - 28ms/epoch - 2ms/step
# Epoch 98/100
# 14/14 - 0s - loss: 0.0096 - 32ms/epoch - 2ms/step
# Epoch 99/100
# 14/14 - 0s - loss: 0.0108 - 29ms/epoch - 2ms/step
# Epoch 100/100
# 14/14 - 0s - loss: 0.0100 - 32ms/epoch - 2ms/step
# 2/2 [==============================] - 0s 5ms/step
# Model 2 - Test RMSE: 5349.58
# Model 2 - Test MAE: 3973.82
# Model 2 - Test R^2: 0.83
# Model 2 - Test MAPE: 0.15
# Model 2 - Test Adjusted R^2: 0.80
# Model 2 - Training Time: 6.93 seconds

# %%
#Mô hình với Batch Normalization
import pandas as pd
import numpy as np
import time
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_absolute_error, r2_score, mean_absolute_percentage_error
from keras.models import Sequential
from keras.layers import Dense, BatchNormalization

# Đọc dữ liệu từ tệp CSV
df = pd.read_csv('Dataa_Service.csv')

# Chọn các cột đầu vào và đầu ra
X = df[['Month', 'Year', 'CPI', 'GDP', 'Temperature', 'USD/VND']]
y = df['Service']

# Chuẩn hóa dữ liệu
scaler_X = MinMaxScaler()
scaler_y = MinMaxScaler()
X_scaled = scaler_X.fit_transform(X)
y_scaled = scaler_y.fit_transform(y.values.reshape(-1, 1))

# Chia dữ liệu thành tập huấn luyện và kiểm tra
X_train, X_test, y_train, y_test = train_test_split(X_scaled, y_scaled, test_size=0.2, random_state=42)

# Xây dựng mô hình mạng nơron với Batch Normalization
model5 = Sequential()
model5.add(Dense(128, input_dim=X_train.shape[1], activation='relu'))
model5.add(BatchNormalization())
model5.add(Dense(64, activation='relu'))
model5.add(BatchNormalization())
model5.add(Dense(32, activation='relu'))
model5.add(BatchNormalization())
model5.add(Dense(1))

# Biên dịch mô hình
model5.compile(loss='mean_squared_error', optimizer='adam')

# Đo thời gian bắt đầu huấn luyện
start_time = time.time()

# Huấn luyện mô hình
model5.fit(X_train, y_train, epochs=100, batch_size=10, verbose=2)

# Đo thời gian kết thúc huấn luyện
end_time = time.time()

# Dự báo trên tập kiểm tra
y_pred5_scaled = model5.predict(X_test)

# Chuyển đổi lại dữ liệu về dạng ban đầu
y_pred5 = scaler_y.inverse_transform(y_pred5_scaled)
y_test_inverse = scaler_y.inverse_transform(y_test)

# Tính toán các chỉ số đánh giá
mse5 = np.mean((y_pred5 - y_test_inverse) ** 2)
rmse5 = np.sqrt(mse5)
mae5 = mean_absolute_error(y_test_inverse, y_pred5)
r25 = r2_score(y_test_inverse, y_pred5)
mape5 = mean_absolute_percentage_error(y_test_inverse, y_pred5)
adjusted_r25 = 1 - (1 - r25) * ((len(y_test_inverse) - 1) / (len(y_test_inverse) - X_test.shape[1] - 1))

# In các chỉ số đánh giá
print(f'Model 5 - Test RMSE: {rmse5:.2f}')
print(f'Model 5 - Test MAE: {mae5:.2f}')
print(f'Model 5 - Test R^2: {r25:.2f}')
print(f'Model 5 - Test MAPE: {mape5:.2f}')
print(f'Model 5 - Test Adjusted R^2: {adjusted_r25:.2f}')
print(f'Model 5 - Training Time: {end_time - start_time:.2f} seconds')
# Out:
# Epoch 1/100
# 14/14 - 2s - loss: 1.3700 - 2s/epoch - 123ms/step
# Epoch 2/100
# 14/14 - 0s - loss: 0.5726 - 40ms/epoch - 3ms/step
# Epoch 3/100
# 14/14 - 0s - loss: 0.4103 - 49ms/epoch - 4ms/step
# Epoch 4/100
# 14/14 - 0s - loss: 0.3488 - 48ms/epoch - 3ms/step
# Epoch 5/100
# 14/14 - 0s - loss: 0.2392 - 42ms/epoch - 3ms/step
# Epoch 6/100
# 14/14 - 0s - loss: 0.2852 - 36ms/epoch - 3ms/step
# Epoch 7/100
# 14/14 - 0s - loss: 0.1709 - 36ms/epoch - 3ms/step
# Epoch 8/100
# 14/14 - 0s - loss: 0.1464 - 42ms/epoch - 3ms/step
# Epoch 9/100
# 14/14 - 0s - loss: 0.1406 - 35ms/epoch - 2ms/step
# Epoch 10/100
# 14/14 - 0s - loss: 0.1484 - 38ms/epoch - 3ms/step
# Epoch 11/100
# 14/14 - 0s - loss: 0.1274 - 38ms/epoch - 3ms/step
# Epoch 12/100
# 14/14 - 0s - loss: 0.1214 - 41ms/epoch - 3ms/step
# Epoch 13/100
# 14/14 - 0s - loss: 0.1015 - 36ms/epoch - 3ms/step
# Epoch 14/100
# 14/14 - 0s - loss: 0.0993 - 41ms/epoch - 3ms/step
# Epoch 15/100
# 14/14 - 0s - loss: 0.0946 - 35ms/epoch - 2ms/step
# Epoch 16/100
# 14/14 - 0s - loss: 0.0941 - 39ms/epoch - 3ms/step
# Epoch 17/100
# 14/14 - 0s - loss: 0.0881 - 35ms/epoch - 3ms/step
# Epoch 18/100
# 14/14 - 0s - loss: 0.0710 - 37ms/epoch - 3ms/step
# Epoch 19/100
# 14/14 - 0s - loss: 0.0830 - 39ms/epoch - 3ms/step
# Epoch 20/100
# 14/14 - 0s - loss: 0.0669 - 39ms/epoch - 3ms/step
# Epoch 21/100
# 14/14 - 0s - loss: 0.0832 - 43ms/epoch - 3ms/step
# Epoch 22/100
# 14/14 - 0s - loss: 0.0791 - 49ms/epoch - 4ms/step
# Epoch 23/100
# 14/14 - 0s - loss: 0.0702 - 43ms/epoch - 3ms/step
# Epoch 24/100
# 14/14 - 0s - loss: 0.0557 - 35ms/epoch - 2ms/step
# Epoch 25/100
# 14/14 - 0s - loss: 0.0593 - 36ms/epoch - 3ms/step
# Epoch 26/100
# 14/14 - 0s - loss: 0.0636 - 37ms/epoch - 3ms/step
# Epoch 27/100
# 14/14 - 0s - loss: 0.0481 - 34ms/epoch - 2ms/step
# Epoch 28/100
# 14/14 - 0s - loss: 0.0614 - 38ms/epoch - 3ms/step
# Epoch 29/100
# 14/14 - 0s - loss: 0.0655 - 37ms/epoch - 3ms/step
# Epoch 30/100
# 14/14 - 0s - loss: 0.0488 - 34ms/epoch - 2ms/step
# Epoch 31/100
# 14/14 - 0s - loss: 0.0513 - 35ms/epoch - 2ms/step
# Epoch 32/100
# 14/14 - 0s - loss: 0.0379 - 34ms/epoch - 2ms/step
# Epoch 33/100
# 14/14 - 0s - loss: 0.0361 - 40ms/epoch - 3ms/step
# Epoch 34/100
# 14/14 - 0s - loss: 0.0382 - 39ms/epoch - 3ms/step
# Epoch 35/100
# 14/14 - 0s - loss: 0.0406 - 43ms/epoch - 3ms/step
# Epoch 36/100
# 14/14 - 0s - loss: 0.0452 - 38ms/epoch - 3ms/step
# Epoch 37/100
# 14/14 - 0s - loss: 0.0460 - 42ms/epoch - 3ms/step
# Epoch 38/100
# 14/14 - 0s - loss: 0.0450 - 37ms/epoch - 3ms/step
# Epoch 39/100
# 14/14 - 0s - loss: 0.0435 - 36ms/epoch - 3ms/step
# Epoch 40/100
# 14/14 - 0s - loss: 0.0348 - 39ms/epoch - 3ms/step
# Epoch 41/100
# 14/14 - 0s - loss: 0.0376 - 39ms/epoch - 3ms/step
# Epoch 42/100
# 14/14 - 0s - loss: 0.0340 - 38ms/epoch - 3ms/step
# Epoch 43/100
# 14/14 - 0s - loss: 0.0377 - 37ms/epoch - 3ms/step
# Epoch 44/100
# 14/14 - 0s - loss: 0.0318 - 38ms/epoch - 3ms/step
# Epoch 45/100
# 14/14 - 0s - loss: 0.0522 - 38ms/epoch - 3ms/step
# Epoch 46/100
# 14/14 - 0s - loss: 0.0306 - 40ms/epoch - 3ms/step
# Epoch 47/100
# 14/14 - 0s - loss: 0.0328 - 39ms/epoch - 3ms/step
# Epoch 48/100
# 14/14 - 0s - loss: 0.0293 - 45ms/epoch - 3ms/step
# Epoch 49/100
# 14/14 - 0s - loss: 0.0286 - 33ms/epoch - 2ms/step
# Epoch 50/100
# 14/14 - 0s - loss: 0.0270 - 35ms/epoch - 3ms/step
# Epoch 51/100
# 14/14 - 0s - loss: 0.0339 - 35ms/epoch - 3ms/step
# Epoch 52/100
# 14/14 - 0s - loss: 0.0450 - 40ms/epoch - 3ms/step
# Epoch 53/100
# 14/14 - 0s - loss: 0.0260 - 39ms/epoch - 3ms/step
# Epoch 54/100
# 14/14 - 0s - loss: 0.0288 - 35ms/epoch - 2ms/step
# Epoch 55/100
# 14/14 - 0s - loss: 0.0258 - 36ms/epoch - 3ms/step
# Epoch 56/100
# 14/14 - 0s - loss: 0.0275 - 33ms/epoch - 2ms/step
# Epoch 57/100
# 14/14 - 0s - loss: 0.0268 - 34ms/epoch - 2ms/step
# Epoch 58/100
# 14/14 - 0s - loss: 0.0284 - 35ms/epoch - 3ms/step
# Epoch 59/100
# 14/14 - 0s - loss: 0.0269 - 43ms/epoch - 3ms/step
# Epoch 60/100
# 14/14 - 0s - loss: 0.0175 - 34ms/epoch - 2ms/step
# Epoch 61/100
# 14/14 - 0s - loss: 0.0271 - 33ms/epoch - 2ms/step
# Epoch 62/100
# 14/14 - 0s - loss: 0.0304 - 34ms/epoch - 2ms/step
# Epoch 63/100
# 14/14 - 0s - loss: 0.0254 - 36ms/epoch - 3ms/step
# Epoch 64/100
# 14/14 - 0s - loss: 0.0227 - 34ms/epoch - 2ms/step
# Epoch 65/100
# 14/14 - 0s - loss: 0.0274 - 36ms/epoch - 3ms/step
# Epoch 66/100
# 14/14 - 0s - loss: 0.0195 - 34ms/epoch - 2ms/step
# Epoch 67/100
# 14/14 - 0s - loss: 0.0276 - 36ms/epoch - 3ms/step
# Epoch 68/100
# 14/14 - 0s - loss: 0.0199 - 33ms/epoch - 2ms/step
# Epoch 69/100
# 14/14 - 0s - loss: 0.0290 - 39ms/epoch - 3ms/step
# Epoch 70/100
# 14/14 - 0s - loss: 0.0232 - 40ms/epoch - 3ms/step
# Epoch 71/100
# 14/14 - 0s - loss: 0.0206 - 35ms/epoch - 2ms/step
# Epoch 72/100
# 14/14 - 0s - loss: 0.0181 - 34ms/epoch - 2ms/step
# Epoch 73/100
# 14/14 - 0s - loss: 0.0252 - 44ms/epoch - 3ms/step
# Epoch 74/100
# 14/14 - 0s - loss: 0.0262 - 52ms/epoch - 4ms/step
# Epoch 75/100
# 14/14 - 0s - loss: 0.0171 - 39ms/epoch - 3ms/step
# Epoch 76/100
# 14/14 - 0s - loss: 0.0127 - 36ms/epoch - 3ms/step
# Epoch 77/100
# 14/14 - 0s - loss: 0.0207 - 37ms/epoch - 3ms/step
# Epoch 78/100
# 14/14 - 0s - loss: 0.0270 - 37ms/epoch - 3ms/step
# Epoch 79/100
# 14/14 - 0s - loss: 0.0258 - 35ms/epoch - 3ms/step
# Epoch 80/100
# 14/14 - 0s - loss: 0.0206 - 37ms/epoch - 3ms/step
# Epoch 81/100
# 14/14 - 0s - loss: 0.0131 - 36ms/epoch - 3ms/step
# Epoch 82/100
# 14/14 - 0s - loss: 0.0165 - 35ms/epoch - 2ms/step
# Epoch 83/100
# 14/14 - 0s - loss: 0.0237 - 38ms/epoch - 3ms/step
# Epoch 84/100
# 14/14 - 0s - loss: 0.0217 - 39ms/epoch - 3ms/step
# Epoch 85/100
# 14/14 - 0s - loss: 0.0152 - 37ms/epoch - 3ms/step
# Epoch 86/100
# 14/14 - 0s - loss: 0.0213 - 35ms/epoch - 3ms/step
# Epoch 87/100
# 14/14 - 0s - loss: 0.0200 - 41ms/epoch - 3ms/step
# Epoch 88/100
# 14/14 - 0s - loss: 0.0179 - 36ms/epoch - 3ms/step
# Epoch 89/100
# 14/14 - 0s - loss: 0.0187 - 43ms/epoch - 3ms/step
# Epoch 90/100
# 14/14 - 0s - loss: 0.0176 - 38ms/epoch - 3ms/step
# Epoch 91/100
# 14/14 - 0s - loss: 0.0180 - 38ms/epoch - 3ms/step
# Epoch 92/100
# 14/14 - 0s - loss: 0.0209 - 36ms/epoch - 3ms/step
# Epoch 93/100
# 14/14 - 0s - loss: 0.0172 - 35ms/epoch - 2ms/step
# Epoch 94/100
# 14/14 - 0s - loss: 0.0266 - 39ms/epoch - 3ms/step
# Epoch 95/100
# 14/14 - 0s - loss: 0.0228 - 38ms/epoch - 3ms/step
# Epoch 96/100
# 14/14 - 0s - loss: 0.0184 - 36ms/epoch - 3ms/step
# Epoch 97/100
# 14/14 - 0s - loss: 0.0161 - 35ms/epoch - 3ms/step
# Epoch 98/100
# 14/14 - 0s - loss: 0.0218 - 34ms/epoch - 2ms/step
# Epoch 99/100
# 14/14 - 0s - loss: 0.0177 - 49ms/epoch - 4ms/step
# Epoch 100/100
# 14/14 - 0s - loss: 0.0195 - 35ms/epoch - 2ms/step
# 2/2 [==============================] - 0s 5ms/step
# Model 5 - Test RMSE: 6786.20
# Model 5 - Test MAE: 5058.14
# Model 5 - Test R^2: 0.73
# Model 5 - Test MAPE: 0.20
# Model 5 - Test Adjusted R^2: 0.67
# Model 5 - Training Time: 6.85 seconds

# %%
### Mô hình SVM
import pandas as pd
import time
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_absolute_error, r2_score, mean_absolute_percentage_error
from sklearn.svm import SVR

# Đọc dữ liệu từ tệp CSV
df = pd.read_csv('Dataa_Service.csv')

# Chọn các cột đầu vào và đầu ra
X = df[['Month', 'Year', 'CPI', 'GDP', 'Temperature', 'USD/VND']]
y = df['Service']

# Chuẩn hóa dữ liệu
scaler_X = MinMaxScaler()
scaler_y = MinMaxScaler()
X_scaled = scaler_X.fit_transform(X)
y_scaled = scaler_y.fit_transform(y.values.reshape(-1, 1))

# Chia dữ liệu thành tập huấn luyện và tập kiểm tra
X_train, X_test, y_train, y_test = train_test_split(X_scaled, y_scaled, test_size=0.2, random_state=42)

# Xây dựng mô hình SVM với kernel RBF
svm_model = SVR(kernel='rbf')

# Đo thời gian bắt đầu huấn luyện
start_time = time.time()

# Huấn luyện mô hình
svm_model.fit(X_train, y_train.ravel())

# Đo thời gian kết thúc huấn luyện
end_time = time.time()

# Dự đoán trên tập kiểm tra
y_pred = svm_model.predict(X_test)

# Chuyển đổi lại dữ liệu về dạng ban đầu
y_pred = scaler_y.inverse_transform(y_pred.reshape(-1, 1))
y_test_inverse = scaler_y.inverse_transform(y_test)

# Tính toán các chỉ số đánh giá
mse = np.mean((y_pred - y_test_inverse) ** 2)
rmse = np.sqrt(mse)
mae = mean_absolute_error(y_test_inverse, y_pred)
r2 = r2_score(y_test_inverse, y_pred)
mape = mean_absolute_percentage_error(y_test_inverse, y_pred)
adjusted_r2 = 1 - (1 - r2) * ((len(y_test_inverse) - 1) / (len(y_test_inverse) - X_test.shape[1] - 1))

# Xây dựng mô hình SVM với kernel đa thức
svr_poly = SVR(kernel='poly', degree=3)

# Đo thời gian bắt đầu huấn luyện
start_time_poly = time.time()

# Huấn luyện mô hình
svr_poly.fit(X_train, y_train.ravel())

# Đo thời gian kết thúc huấn luyện
end_time_poly = time.time()

# Dự báo trên tập kiểm tra
y_pred_poly = svr_poly.predict(X_test)

# Chuyển đổi lại dữ liệu về dạng ban đầu
y_pred_poly = scaler_y.inverse_transform(y_pred_poly.reshape(-1, 1))
y_test_inverse = scaler_y.inverse_transform(y_test)

# Tính toán các chỉ số đánh giá
mse_poly = np.mean((y_pred_poly - y_test_inverse) ** 2)
rmse_poly = np.sqrt(mse_poly)
mae_poly = mean_absolute_error(y_test_inverse, y_pred_poly)
r2_poly = r2_score(y_test_inverse, y_pred_poly)
mape_poly = mean_absolute_percentage_error(y_test_inverse, y_pred_poly)
adjusted_r2_poly = 1 - (1 - r2_poly) * ((len(y_test_inverse) - 1) / (len(y_test_inverse) - X_test.shape[1] - 1))

# Xây dựng mô hình SVM với kernel tuyến tính (linear)
svr_linear = SVR(kernel='linear')

# Đo thời gian bắt đầu huấn luyện
start_time_linear = time.time()

# Huấn luyện mô hình
svr_linear.fit(X_train, y_train.ravel())

# Đo thời gian kết thúc huấn luyện
end_time_linear = time.time()

# Dự báo trên tập kiểm tra
y_pred_linear = svr_linear.predict(X_test)

# Chuyển đổi lại dữ liệu về dạng ban đầu
y_pred_linear = scaler_y.inverse_transform(y_pred_linear.reshape(-1, 1))
y_test_inverse = scaler_y.inverse_transform(y_test)

# Tính toán các chỉ số đánh giá
mse_linear = np.mean((y_pred_linear - y_test_inverse) ** 2)
rmse_linear = np.sqrt(mse_linear)
mae_linear = mean_absolute_error(y_test_inverse, y_pred_linear)
r2_linear = r2_score(y_test_inverse, y_pred_linear)
mape_linear = mean_absolute_percentage_error(y_test_inverse, y_pred_linear)
adjusted_r2_linear = 1 - (1 - r2_linear) * ((len(y_test_inverse) - 1) / (len(y_test_inverse) - X_test.shape[1] - 1))

# In các chỉ số đánh giá
print("Model with RBF kernel")
print("Training time:", end_time - start_time)
print("RMSE:", rmse)
print("MAE:", mae)
print("R2:", r2)
print("Adjusted R2:", adjusted_r2)
print("MAPE:", mape)

print("\nModel with Polynomial kernel")
print("Training time:", end_time_poly - start_time_poly)
print("RMSE:", rmse_poly)
print("MAE:", mae_poly)
print("R2:", r2_poly)
print("Adjusted R2:", adjusted_r2_poly)
print("MAPE:", mape_poly)

print("\nModel with Linear kernel")
print("Training time:", end_time_linear - start_time_linear)
print("RMSE:", rmse_linear)
print("MAE:", mae_linear)
print("R2:", r2_linear)
print("Adjusted R2:", adjusted_r2_linear)
print("MAPE:", mape_linear)
# Out:
# Model with RBF kernel
# Training time: 0.001377105712890625
# RMSE: 4641.65454130658
# MAE: 3402.715573909871
# R2: 0.8731258268107525
# Adjusted R2: 0.8459385039844851
# MAPE: 0.14279487316427172
#
# Model with Polynomial kernel
# Training time: 0.015676021575927734
# RMSE: 4322.9239463923695
# MAE: 3290.3553430598913
# R2: 0.889951839927325
# Adjusted R2: 0.8663700913403232
# MAPE: 0.13337649269268945
#
# Model with Linear kernel
# Training time: 0.0013625621795654297
# RMSE: 6367.077066689655
# MAE: 4022.8102624198254
# R2: 0.7612695542437602
# Adjusted R2: 0.7101130301531374
# MAPE: 0.16346613359307047

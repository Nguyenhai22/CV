# %%
#Mô tả dữ liệu

import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import mean_squared_error, r2_score
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense

# Đọc dữ liệu từ tệp CSV
df = pd.read_csv('Dataa_Service.csv')
print(df.head())
print(df.describe())
# Kiểm tra giá trị thiếu trong dữ liệu
print('Giá trị bị thiếu')
print(df.isnull().sum())
# Out:
#    Month  Year   GDP   CPI  USD/VND  Temperature  Service
# 0      1  2010  4.23  1.36    18474        21.28    11302
# 1      2  2010  4.23  1.96    19050        23.00    11253
# 2      3  2010  4.23  0.75    19090        23.38    10776
# 3      4  2010  3.81  0.14    18975        25.92    11472
# 4      5  2010  3.81  0.27    18875        28.00    11656
#             Month         Year         GDP         CPI       USD/VND  \
# count  171.000000   171.000000  171.000000  171.000000    171.000000
# mean     6.438596  2016.666667    5.200117    0.409415  22175.245614
# std      3.464191     4.164274    2.335468    0.622585   1387.721899
# min      1.000000  2010.000000   -6.170000   -1.540000  18474.000000
# 25%      3.000000  2013.000000    4.140000    0.065000  21067.500000
# 50%      6.000000  2017.000000    5.330000    0.270000  22688.000000
# 75%      9.000000  2020.000000    6.410000    0.615000  23194.000000
# max     12.000000  2024.000000   13.670000    3.320000  25330.000000
#
#        Temperature       Service
# count   171.000000    171.000000
# mean     23.901462  34089.403509
# std       6.671246  13788.150854
# min       8.660000  10776.000000
# 25%      19.790000  22086.500000
# 50%      24.390000  33981.000000
# 75%      27.440000  45058.500000
# max      40.700000  65375.000000
# Giá trị bị thiếu
# Month          0
# Year           0
# GDP            0
# CPI            0
# USD/VND        0
# Temperature    0
# Service        0
# dtype: int64

# %%
#Mô hình hồi quy
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error
from sklearn.metrics import mean_absolute_error, r2_score
from sklearn.linear_model import Ridge
from sklearn.linear_model import Lasso
from sklearn.tree import DecisionTreeRegressor
import time

# Đọc dữ liệu từ tệp CSV
df = pd.read_csv('Dataa_Service.csv')

# Tách biến đầu vào và biến mục tiêu
X = df[['Month', 'Year', 'CPI','GDP','Temperature','USD/VND']]
y = df['Service']

# Chia dữ liệu thành tập huấn luyện và tập kiểm tra
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=20)

# Chuẩn hóa dữ liệu
scaler = StandardScaler()
X_train = scaler.fit_transform(X_train)
X_test = scaler.transform(X_test)

#MODEL1 Xây dựng mô hình ( Linear Regression )
start_time = time.time()
model = LinearRegression()
model.fit(X_train, y_train)
y_pred = model.predict(X_test)
end_time = time.time()
linear_regression_time = end_time - start_time

#MODEL2 Xây dựng mô hình ( Ridge Regression )
start_time = time.time()
ridge_model = Ridge(alpha=1.0)
ridge_model.fit(X_train, y_train)
ridge_y_pred = ridge_model.predict(X_test)
end_time = time.time()
ridge_regression_time = end_time - start_time

#MODEL3 Xây dựng mô hình (Lasso Regression)
start_time = time.time()
lasso_model = Lasso(alpha=1.0)
lasso_model.fit(X_train, y_train)
lasso_y_pred = lasso_model.predict(X_test)
end_time = time.time()
lasso_regression_time = end_time - start_time

#MODEL4 Xây dựng mô hình Decision Tree Regression
start_time = time.time()
tree_model = DecisionTreeRegressor(random_state=20)
tree_model.fit(X_train, y_train)
tree_y_pred = tree_model.predict(X_test)
end_time = time.time()
tree_regression_time = end_time - start_time

#Đánh giá mô hình bằng 4 chỉ số hồi quy
mae = mean_absolute_error(y_test, y_pred)
r2 = r2_score(y_test, y_pred)
rmse = np.sqrt(mean_squared_error(y_test, y_pred))
mpae = np.mean(np.abs((y_test - y_pred) / y_test)) * 100

ridge_mae = mean_absolute_error(y_test, ridge_y_pred)
ridge_r2 = r2_score(y_test, ridge_y_pred)
ridge_rmse = np.sqrt(mean_squared_error(y_test, ridge_y_pred))
ridge_mpae = np.mean(np.abs((y_test - ridge_y_pred) / y_test)) * 100

lasso_mae = mean_absolute_error(y_test, lasso_y_pred)
lasso_r2 = r2_score(y_test, lasso_y_pred)
lasso_rmse = np.sqrt(mean_squared_error(y_test, lasso_y_pred))
lasso_mpae = np.mean(np.abs((y_test - lasso_y_pred) / y_test)) * 100

tree_mae = mean_absolute_error(y_test, tree_y_pred)
tree_r2 = r2_score(y_test, tree_y_pred)
tree_rmse = np.sqrt(mean_squared_error(y_test, tree_y_pred))
tree_mpae = np.mean(np.abs((y_test - tree_y_pred) / y_test)) * 100

print("Mean Absolute Error (MAE):", mae)
print("R-squared (R2):", r2)
print("Root Mean Squared Error (RMSE):", rmse)
print("Mean Percentage Absolute Error (MPAE):", mpae)
print("Time taken (seconds):", linear_regression_time)

print("Mean Absolute Error (MAE):", ridge_mae)
print("R-squared (R2):", ridge_r2)
print("Root Mean Squared Error (RMSE):", ridge_rmse)
print("Mean Percentage Absolute Error (MPAE):", ridge_mpae)
print("Time taken (seconds):", ridge_regression_time)

print("Mean Absolute Error (MAE):", lasso_mae)
print("R-squared (R2):", lasso_r2)
print("Root Mean Squared Error (RMSE):", lasso_rmse)
print("Mean Percentage Absolute Error (MPAE):", lasso_mpae)
print("Time taken (seconds):", lasso_regression_time)

print("Mean Absolute Error (MAE):", tree_mae)
print("R-squared (R2):", tree_r2)
print("Root Mean Squared Error (RMSE):", tree_rmse)
print("Mean Percentage Absolute Error (MPAE):", tree_mpae)
print("Time taken (seconds):", tree_regression_time)
# Out:
# Linear Regression:
# Mean Absolute Error (MAE): 3515.788297088993
# R-squared (R2): 0.8672153238155861
# Root Mean Squared Error (RMSE): 4763.73932353498
# Mean Percentage Absolute Error (MPAE): 9.595776815695087
# Time taken (seconds): 0.03905630111694336
#
# Ridge Regression:
# Mean Absolute Error (MAE): 3515.0285383228497
# R-squared (R2): 0.8669096150031655
# Root Mean Squared Error (RMSE): 4769.219925215118
# Mean Percentage Absolute Error (MPAE): 9.596182860236649
# Time taken (seconds): 0.009611129760742188
#
# Lasso Regression:
# Mean Absolute Error (MAE): 3515.45265300677
# R-squared (R2): 0.8671966852241485
# Root Mean Squared Error (RMSE): 4764.0736477882
# Mean Percentage Absolute Error (MPAE): 9.59391772825771
# Time taken (seconds): 0.004912376403808594
#
# Decision Tree Regression:
# Mean Absolute Error (MAE): 2128.1714285714284
# R-squared (R2): 0.9224305285427636
# Root Mean Squared Error (RMSE): 3640.9894887438027
# Mean Percentage Absolute Error (MPAE): 5.466659217168114
# Time taken (seconds): 0.0027327537536621094

# %%
#Mạng Nowrron nhiều lớp
import pandas as pd
import numpy as np
import time
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_absolute_error, r2_score, mean_absolute_percentage_error
from keras.models import Sequential
from keras.layers import Dense

# Đọc dữ liệu từ tệp CSV
df = pd.read_csv('Dataa_Service.csv')

# Chọn các cột đầu vào và đầu ra
X = df[['Month', 'Year', 'CPI', 'GDP', 'Temperature', 'USD/VND']]
y = df['Service']

# Chuẩn hóa dữ liệu
scaler_X = MinMaxScaler()
scaler_y = MinMaxScaler()
X_scaled = scaler_X.fit_transform(X)
y_scaled = scaler_y.fit_transform(y.values.reshape(-1, 1))

# Chia dữ liệu thành tập huấn luyện và kiểm tra
X_train, X_test, y_train, y_test = train_test_split(X_scaled, y_scaled, test_size=0.2, random_state=42)

# Xây dựng mô hình mạng nơron
model = Sequential()
model.add(Dense(64, input_dim=X_train.shape[1], activation='relu'))
model.add(Dense(32, activation='relu'))
model.add(Dense(16, activation='relu'))
model.add(Dense(1))

# Biên dịch mô hình
model.compile(loss='mean_squared_error', optimizer='adam')

# Đo thời gian bắt đầu huấn luyện
start_time = time.time()

# Huấn luyện mô hình
model.fit(X_train, y_train, epochs=5000, batch_size=10, verbose=2)

# Đo thời gian kết thúc huấn luyện
end_time = time.time()

# Dự báo trên tập kiểm tra
y_pred_scaled = model.predict(X_test)

# Chuyển đổi lại dữ liệu về dạng ban đầu
y_pred = scaler_y.inverse_transform(y_pred_scaled)
y_test = scaler_y.inverse_transform(y_test)

# Tính toán các chỉ số đánh giá
mse = np.mean((y_pred - y_test) ** 2)
rmse = np.sqrt(mse)
mae = mean_absolute_error(y_test, y_pred)
r2 = r2_score(y_test, y_pred)
mape = mean_absolute_percentage_error(y_test, y_pred)
adjusted_r2 = 1 - (1 - r2) * ((len(y_test) - 1) / (len(y_test) - X_test.shape[1] - 1))

# In các chỉ số đánh giá
print(f'Test RMSE: {rmse:.2f}')
print(f'Test MAE: {mae:.2f}')
print(f'Test R^2: {r2:.2f}')
print(f'Test MAPE: {mape:.2f}')
print(f'Test Adjusted R^2: {adjusted_r2:.2f}')

# In thời gian huấn luyện
print(f'Training Time: {end_time - start_time:.2f} seconds')
# Out:
# Streaming output truncated to the last 5000 lines.
# 14/14 - 0s - loss: 6.8131e-05 - 38ms/epoch - 3ms/step
# Epoch 2505/5000
# 14/14 - 0s - loss: 7.3203e-05 - 39ms/epoch - 3ms/step
# Epoch 2506/5000
# 14/14 - 0s - loss: 5.8340e-05 - 42ms/epoch - 3ms/step
# Epoch 2507/5000
# 14/14 - 0s - loss: 4.8822e-05 - 61ms/epoch - 4ms/step
# Epoch 2508/5000
# 14/14 - 0s - loss: 3.6861e-05 - 43ms/epoch - 3ms/step
# Epoch 2509/5000
# 14/14 - 0s - loss: 4.4630e-05 - 56ms/epoch - 4ms/step
# Epoch 2510/5000
# 14/14 - 0s - loss: 3.1176e-05 - 36ms/epoch - 3ms/step
# Epoch 2511/5000
# 14/14 - 0s - loss: 2.8423e-05 - 48ms/epoch - 3ms/step
# Epoch 2512/5000
# 14/14 - 0s - loss: 2.2555e-05 - 37ms/epoch - 3ms/step
# Epoch 2513/5000
# 14/14 - 0s - loss: 2.7999e-05 - 38ms/epoch - 3ms/step
# Epoch 2514/5000
# 14/14 - 0s - loss: 3.8506e-05 - 39ms/epoch - 3ms/step
# Epoch 2515/5000
# 14/14 - 0s - loss: 2.1307e-05 - 37ms/epoch - 3ms/step
# Epoch 2516/5000
# 14/14 - 0s - loss: 1.7003e-05 - 41ms/epoch - 3ms/step
# Epoch 2517/5000
# 14/14 - 0s - loss: 1.2503e-05 - 56ms/epoch - 4ms/step
# Epoch 2518/5000
# 14/14 - 0s - loss: 1.4620e-05 - 41ms/epoch - 3ms/step
# Epoch 2519/5000
# 14/14 - 0s - loss: 2.6564e-05 - 43ms/epoch - 3ms/step
# Epoch 2520/5000
# 14/14 - 0s - loss: 1.8872e-05 - 43ms/epoch - 3ms/step
# Epoch 2521/5000
# 14/14 - 0s - loss: 2.1522e-05 - 35ms/epoch - 2ms/step
# Epoch 2522/5000
# 14/14 - 0s - loss: 2.2595e-05 - 41ms/epoch - 3ms/step
# Epoch 2523/5000
# 14/14 - 0s - loss: 2.1213e-05 - 41ms/epoch - 3ms/step
# Epoch 2524/5000
# 14/14 - 0s - loss: 1.5811e-05 - 42ms/epoch - 3ms/step
# Epoch 2525/5000
# 14/14 - 0s - loss: 1.8450e-05 - 40ms/epoch - 3ms/step
# Epoch 2526/5000
# 14/14 - 0s - loss: 2.1482e-05 - 38ms/epoch - 3ms/step
# Epoch 2527/5000
# 14/14 - 0s - loss: 3.2009e-05 - 63ms/epoch - 5ms/step
# Epoch 2528/5000
# 14/14 - 0s - loss: 2.8790e-05 - 47ms/epoch - 3ms/step
# Epoch 2529/5000
# 14/14 - 0s - loss: 4.4063e-05 - 46ms/epoch - 3ms/step
# Epoch 2530/5000
# 14/14 - 0s - loss: 7.7173e-05 - 34ms/epoch - 2ms/step
# Epoch 2531/5000
# 14/14 - 0s - loss: 6.1951e-05 - 42ms/epoch - 3ms/step
# Epoch 2532/5000
# 14/14 - 0s - loss: 2.8372e-05 - 41ms/epoch - 3ms/step
# Epoch 2533/5000
# 14/14 - 0s - loss: 1.9796e-05 - 41ms/epoch - 3ms/step
# Epoch 2534/5000
# 14/14 - 0s - loss: 2.9072e-05 - 38ms/epoch - 3ms/step
# Epoch 2535/5000
# 14/14 - 0s - loss: 4.3314e-05 - 42ms/epoch - 3ms/step
# Epoch 2536/5000
# 14/14 - 0s - loss: 5.0282e-05 - 40ms/epoch - 3ms/step
# Epoch 2537/5000
# 14/14 - 0s - loss: 5.0805e-05 - 40ms/epoch - 3ms/step
# Epoch 2538/5000
# 14/14 - 0s - loss: 5.2012e-05 - 48ms/epoch - 3ms/step
# Epoch 2539/5000
# 14/14 - 0s - loss: 4.4684e-05 - 38ms/epoch - 3ms/step
# Epoch 2540/5000
# 14/14 - 0s - loss: 4.1067e-05 - 36ms/epoch - 3ms/step
# Epoch 2541/5000
# 14/14 - 0s - loss: 5.9984e-05 - 37ms/epoch - 3ms/step
# Epoch 2542/5000
# 14/14 - 0s - loss: 1.3070e-04 - 45ms/epoch - 3ms/step
# Epoch 2543/5000
# 14/14 - 0s - loss: 9.9532e-05 - 81ms/epoch - 6ms/step
# Epoch 2544/5000
# 14/14 - 0s - loss: 9.6356e-05 - 93ms/epoch - 7ms/step
# Epoch 2545/5000
# 14/14 - 0s - loss: 1.3536e-04 - 81ms/epoch - 6ms/step
# Epoch 2546/5000
# 14/14 - 0s - loss: 1.6793e-04 - 89ms/epoch - 6ms/step
# Epoch 2547/5000
# 14/14 - 0s - loss: 2.0200e-04 - 78ms/epoch - 6ms/step
# Epoch 2548/5000
# 14/14 - 0s - loss: 2.6669e-04 - 52ms/epoch - 4ms/step
# Epoch 2549/5000
# 14/14 - 0s - loss: 3.1204e-04 - 63ms/epoch - 4ms/step
# Epoch 2550/5000
# 14/14 - 0s - loss: 3.2693e-04 - 40ms/epoch - 3ms/step
# Epoch 2551/5000
# 14/14 - 0s - loss: 4.0645e-04 - 53ms/epoch - 4ms/step
# Epoch 2552/5000
# 14/14 - 0s - loss: 5.9437e-04 - 49ms/epoch - 3ms/step
# Epoch 2553/5000
# 14/14 - 0s - loss: 4.8920e-04 - 36ms/epoch - 3ms/step
# Epoch 2554/5000
# 14/14 - 0s - loss: 4.2455e-04 - 44ms/epoch - 3ms/step
# Epoch 2555/5000
# 14/14 - 0s - loss: 3.2133e-04 - 50ms/epoch - 4ms/step
# Epoch 2556/5000
# 14/14 - 0s - loss: 3.0825e-04 - 41ms/epoch - 3ms/step
# Epoch 2557/5000
# 14/14 - 0s - loss: 2.5063e-04 - 42ms/epoch - 3ms/step
# Epoch 2558/5000
# 14/14 - 0s - loss: 2.2458e-04 - 41ms/epoch - 3ms/step
# Epoch 2559/5000
# 14/14 - 0s - loss: 2.3225e-04 - 43ms/epoch - 3ms/step
# Epoch 2560/5000
# 14/14 - 0s - loss: 1.5908e-04 - 37ms/epoch - 3ms/step
# Epoch 2561/5000
# 14/14 - 0s - loss: 1.5063e-04 - 54ms/epoch - 4ms/step
# Epoch 2562/5000
# 14/14 - 0s - loss: 1.9483e-04 - 47ms/epoch - 3ms/step
# Epoch 2563/5000
# 14/14 - 0s - loss: 1.3422e-04 - 44ms/epoch - 3ms/step
# Epoch 2564/5000
# 14/14 - 0s - loss: 1.0194e-04 - 355ms/epoch - 25ms/step
# Epoch 2565/5000
# 14/14 - 0s - loss: 5.5957e-05 - 353ms/epoch - 25ms/step
# Epoch 2566/5000
# 14/14 - 0s - loss: 5.4679e-05 - 176ms/epoch - 13ms/step
# Epoch 2567/5000
# 14/14 - 0s - loss: 4.4491e-05 - 152ms/epoch - 11ms/step
# Epoch 2568/5000
# 14/14 - 0s - loss: 7.0489e-05 - 154ms/epoch - 11ms/step
# Epoch 2569/5000
# 14/14 - 0s - loss: 4.0009e-05 - 54ms/epoch - 4ms/step
# Epoch 2570/5000
# 14/14 - 0s - loss: 4.2703e-05 - 45ms/epoch - 3ms/step
# Epoch 2571/5000
# 14/14 - 0s - loss: 3.3258e-05 - 48ms/epoch - 3ms/step
# Epoch 2572/5000
# 14/14 - 0s - loss: 3.8303e-05 - 42ms/epoch - 3ms/step
# Epoch 2573/5000
# 14/14 - 0s - loss: 3.5015e-05 - 41ms/epoch - 3ms/step
# Epoch 2574/5000
# 14/14 - 0s - loss: 2.4804e-05 - 42ms/epoch - 3ms/step
# Epoch 2575/5000
# 14/14 - 0s - loss: 2.1048e-05 - 54ms/epoch - 4ms/step
# Epoch 2576/5000
# 14/14 - 0s - loss: 2.9347e-05 - 77ms/epoch - 5ms/step
# Epoch 2577/5000
# 14/14 - 0s - loss: 2.7407e-05 - 213ms/epoch - 15ms/step
# Epoch 2578/5000
# 14/14 - 0s - loss: 2.3291e-05 - 300ms/epoch - 21ms/step
# Epoch 2579/5000
# 14/14 - 0s - loss: 3.0411e-05 - 297ms/epoch - 21ms/step
# Epoch 2580/5000
# 14/14 - 0s - loss: 2.1852e-05 - 160ms/epoch - 11ms/step
# Epoch 2581/5000
# 14/14 - 0s - loss: 2.3253e-05 - 113ms/epoch - 8ms/step
# Epoch 2582/5000
# 14/14 - 0s - loss: 2.4773e-05 - 55ms/epoch - 4ms/step
# Epoch 2583/5000
# 14/14 - 0s - loss: 2.4056e-05 - 47ms/epoch - 3ms/step
# Epoch 2584/5000
# 14/14 - 0s - loss: 3.0123e-05 - 44ms/epoch - 3ms/step
# Epoch 2585/5000
# 14/14 - 0s - loss: 2.9533e-05 - 45ms/epoch - 3ms/step
# Epoch 2586/5000
# 14/14 - 0s - loss: 2.2597e-05 - 42ms/epoch - 3ms/step
# Epoch 2587/5000
# 14/14 - 0s - loss: 1.9046e-05 - 47ms/epoch - 3ms/step
# Epoch 2588/5000
# 14/14 - 0s - loss: 1.6952e-05 - 49ms/epoch - 3ms/step
# Epoch 2589/5000
# 14/14 - 0s - loss: 1.5925e-05 - 38ms/epoch - 3ms/step
# Epoch 2590/5000
# 14/14 - 0s - loss: 3.1358e-05 - 38ms/epoch - 3ms/step
# Epoch 2591/5000
# 14/14 - 0s - loss: 5.1455e-05 - 43ms/epoch - 3ms/step
# Epoch 2592/5000
# 14/14 - 0s - loss: 2.5547e-05 - 44ms/epoch - 3ms/step
# Epoch 2593/5000
# 14/14 - 0s - loss: 2.1628e-05 - 46ms/epoch - 3ms/step
# Epoch 2594/5000
# 14/14 - 0s - loss: 1.7867e-05 - 41ms/epoch - 3ms/step
# Epoch 2595/5000
# 14/14 - 0s - loss: 2.0477e-05 - 39ms/epoch - 3ms/step
# Epoch 2596/5000
# 14/14 - 0s - loss: 2.5795e-05 - 44ms/epoch - 3ms/step
# Epoch 2597/5000
# 14/14 - 0s - loss: 1.6290e-05 - 74ms/epoch - 5ms/step
# Epoch 2598/5000
# 14/14 - 0s - loss: 1.2952e-05 - 61ms/epoch - 4ms/step
# Epoch 2599/5000
# 14/14 - 0s - loss: 1.2352e-05 - 42ms/epoch - 3ms/step
# Epoch 2600/5000
# 14/14 - 0s - loss: 1.3854e-05 - 35ms/epoch - 3ms/step
# Epoch 2601/5000
# 14/14 - 0s - loss: 2.3371e-05 - 50ms/epoch - 4ms/step
# Epoch 2602/5000
# 14/14 - 0s - loss: 1.6622e-05 - 59ms/epoch - 4ms/step
# Epoch 2603/5000
# 14/14 - 0s - loss: 2.1682e-05 - 47ms/epoch - 3ms/step
# Epoch 2604/5000
# 14/14 - 0s - loss: 3.0786e-05 - 72ms/epoch - 5ms/step
# Epoch 2605/5000
# 14/14 - 0s - loss: 2.4516e-05 - 71ms/epoch - 5ms/step
# Epoch 2606/5000
# 14/14 - 0s - loss: 2.8649e-05 - 65ms/epoch - 5ms/step
# Epoch 2607/5000
# 14/14 - 0s - loss: 1.7959e-05 - 69ms/epoch - 5ms/step
# Epoch 2608/5000
# 14/14 - 0s - loss: 2.0641e-05 - 72ms/epoch - 5ms/step
# Epoch 2609/5000
# 14/14 - 0s - loss: 2.9616e-05 - 58ms/epoch - 4ms/step
# Epoch 2610/5000
# 14/14 - 0s - loss: 2.8604e-05 - 61ms/epoch - 4ms/step
# Epoch 2611/5000
# 14/14 - 0s - loss: 2.3642e-05 - 65ms/epoch - 5ms/step
# Epoch 2612/5000
# 14/14 - 0s - loss: 2.7246e-05 - 57ms/epoch - 4ms/step
# Epoch 2613/5000
# 14/14 - 0s - loss: 1.4615e-05 - 51ms/epoch - 4ms/step
# Epoch 2614/5000
# 14/14 - 0s - loss: 1.4433e-05 - 46ms/epoch - 3ms/step
# Epoch 2615/5000
# 14/14 - 0s - loss: 1.0636e-05 - 46ms/epoch - 3ms/step
# Epoch 2616/5000
# 14/14 - 0s - loss: 1.1025e-05 - 53ms/epoch - 4ms/step
# Epoch 2617/5000
# 14/14 - 0s - loss: 1.1341e-05 - 47ms/epoch - 3ms/step
# Epoch 2618/5000
# 14/14 - 0s - loss: 1.0619e-05 - 50ms/epoch - 4ms/step
# Epoch 2619/5000
# 14/14 - 0s - loss: 1.1164e-05 - 52ms/epoch - 4ms/step
# Epoch 2620/5000
# 14/14 - 0s - loss: 1.0308e-05 - 55ms/epoch - 4ms/step
# Epoch 2621/5000
# 14/14 - 0s - loss: 1.2197e-05 - 61ms/epoch - 4ms/step
# Epoch 2622/5000
# 14/14 - 0s - loss: 1.3031e-05 - 63ms/epoch - 4ms/step
# Epoch 2623/5000
# 14/14 - 0s - loss: 1.9037e-05 - 57ms/epoch - 4ms/step
# Epoch 2624/5000
# 14/14 - 0s - loss: 2.7253e-05 - 68ms/epoch - 5ms/step
# Epoch 2625/5000
# 14/14 - 0s - loss: 3.0257e-05 - 62ms/epoch - 4ms/step
# Epoch 2626/5000
# 14/14 - 0s - loss: 2.1889e-05 - 66ms/epoch - 5ms/step
# Epoch 2627/5000
# 14/14 - 0s - loss: 2.0167e-05 - 85ms/epoch - 6ms/step
# Epoch 2628/5000
# 14/14 - 0s - loss: 1.3599e-05 - 69ms/epoch - 5ms/step
# Epoch 2629/5000
# 14/14 - 0s - loss: 1.7155e-05 - 48ms/epoch - 3ms/step
# Epoch 2630/5000
# 14/14 - 0s - loss: 1.9931e-05 - 39ms/epoch - 3ms/step
# Epoch 2631/5000
# 14/14 - 0s - loss: 2.3424e-05 - 46ms/epoch - 3ms/step
# Epoch 2632/5000
# 14/14 - 0s - loss: 2.3182e-05 - 46ms/epoch - 3ms/step
# Epoch 2633/5000
# 14/14 - 0s - loss: 2.1847e-05 - 37ms/epoch - 3ms/step
# Epoch 2634/5000
# 14/14 - 0s - loss: 1.4854e-05 - 45ms/epoch - 3ms/step
# Epoch 2635/5000
# 14/14 - 0s - loss: 1.5088e-05 - 47ms/epoch - 3ms/step
# Epoch 2636/5000
# 14/14 - 0s - loss: 1.6485e-05 - 61ms/epoch - 4ms/step
# Epoch 2637/5000
# 14/14 - 0s - loss: 1.5623e-05 - 51ms/epoch - 4ms/step
# Epoch 2638/5000
# 14/14 - 0s - loss: 1.0782e-05 - 70ms/epoch - 5ms/step
# Epoch 2639/5000
# 14/14 - 0s - loss: 1.4457e-05 - 55ms/epoch - 4ms/step
# Epoch 2640/5000
# 14/14 - 0s - loss: 1.5965e-05 - 51ms/epoch - 4ms/step
# Epoch 2641/5000
# 14/14 - 0s - loss: 2.5239e-05 - 53ms/epoch - 4ms/step
# Epoch 2642/5000
# 14/14 - 0s - loss: 1.5783e-05 - 58ms/epoch - 4ms/step
# Epoch 2643/5000
# 14/14 - 0s - loss: 1.5070e-05 - 48ms/epoch - 3ms/step
# Epoch 2644/5000
# 14/14 - 0s - loss: 1.1996e-05 - 54ms/epoch - 4ms/step
# Epoch 2645/5000
# 14/14 - 0s - loss: 1.2490e-05 - 68ms/epoch - 5ms/step
# Epoch 2646/5000
# 14/14 - 0s - loss: 1.2637e-05 - 68ms/epoch - 5ms/step
# Epoch 2647/5000
# 14/14 - 0s - loss: 1.0123e-05 - 61ms/epoch - 4ms/step
# Epoch 2648/5000
# 14/14 - 0s - loss: 1.3357e-05 - 67ms/epoch - 5ms/step
# Epoch 2649/5000
# 14/14 - 0s - loss: 1.6077e-05 - 41ms/epoch - 3ms/step
# Epoch 2650/5000
# 14/14 - 0s - loss: 2.5569e-05 - 47ms/epoch - 3ms/step
# Epoch 2651/5000
# 14/14 - 0s - loss: 2.7825e-05 - 43ms/epoch - 3ms/step
# Epoch 2652/5000
# 14/14 - 0s - loss: 7.4036e-05 - 45ms/epoch - 3ms/step
# Epoch 2653/5000
# 14/14 - 0s - loss: 6.0283e-05 - 51ms/epoch - 4ms/step
# Epoch 2654/5000
# 14/14 - 0s - loss: 4.8888e-05 - 67ms/epoch - 5ms/step
# Epoch 2655/5000
# 14/14 - 0s - loss: 5.3654e-05 - 50ms/epoch - 4ms/step
# Epoch 2656/5000
# 14/14 - 0s - loss: 1.5086e-04 - 42ms/epoch - 3ms/step
# Epoch 2657/5000
# 14/14 - 0s - loss: 1.5213e-04 - 50ms/epoch - 4ms/step
# Epoch 2658/5000
# 14/14 - 0s - loss: 1.0172e-04 - 71ms/epoch - 5ms/step
# Epoch 2659/5000
# 14/14 - 0s - loss: 8.9229e-05 - 74ms/epoch - 5ms/step
# Epoch 2660/5000
# 14/14 - 0s - loss: 1.6020e-04 - 80ms/epoch - 6ms/step
# Epoch 2661/5000
# 14/14 - 0s - loss: 1.8126e-04 - 52ms/epoch - 4ms/step
# Epoch 2662/5000
# 14/14 - 0s - loss: 1.0873e-04 - 60ms/epoch - 4ms/step
# Epoch 2663/5000
# 14/14 - 0s - loss: 8.9586e-05 - 47ms/epoch - 3ms/step
# Epoch 2664/5000
# 14/14 - 0s - loss: 7.3921e-05 - 45ms/epoch - 3ms/step
# Epoch 2665/5000
# 14/14 - 0s - loss: 4.9843e-05 - 40ms/epoch - 3ms/step
# Epoch 2666/5000
# 14/14 - 0s - loss: 1.1525e-04 - 48ms/epoch - 3ms/step
# Epoch 2667/5000
# 14/14 - 0s - loss: 1.8272e-04 - 51ms/epoch - 4ms/step
# Epoch 2668/5000
# 14/14 - 0s - loss: 4.3516e-04 - 48ms/epoch - 3ms/step
# Epoch 2669/5000
# 14/14 - 0s - loss: 3.3549e-04 - 49ms/epoch - 3ms/step
# Epoch 2670/5000
# 14/14 - 0s - loss: 2.7687e-04 - 51ms/epoch - 4ms/step
# Epoch 2671/5000
# 14/14 - 0s - loss: 1.7592e-04 - 56ms/epoch - 4ms/step
# Epoch 2672/5000
# 14/14 - 0s - loss: 1.3795e-04 - 69ms/epoch - 5ms/step
# Epoch 2673/5000
# 14/14 - 0s - loss: 1.3267e-04 - 70ms/epoch - 5ms/step
# Epoch 2674/5000
# 14/14 - 0s - loss: 1.3712e-04 - 64ms/epoch - 5ms/step
# Epoch 2675/5000
# 14/14 - 0s - loss: 8.1753e-05 - 69ms/epoch - 5ms/step
# Epoch 2676/5000
# 14/14 - 0s - loss: 6.3819e-05 - 67ms/epoch - 5ms/step
# Epoch 2677/5000
# 14/14 - 0s - loss: 6.4605e-05 - 63ms/epoch - 5ms/step
# Epoch 2678/5000
# 14/14 - 0s - loss: 5.7830e-05 - 55ms/epoch - 4ms/step
# Epoch 2679/5000
# 14/14 - 0s - loss: 4.6915e-05 - 52ms/epoch - 4ms/step
# Epoch 2680/5000
# 14/14 - 0s - loss: 3.1252e-05 - 39ms/epoch - 3ms/step
# Epoch 2681/5000
# 14/14 - 0s - loss: 2.8081e-05 - 41ms/epoch - 3ms/step
# Epoch 2682/5000
# 14/14 - 0s - loss: 1.9889e-05 - 35ms/epoch - 2ms/step
# Epoch 2683/5000
# 14/14 - 0s - loss: 2.2529e-05 - 55ms/epoch - 4ms/step
# Epoch 2684/5000
# 14/14 - 0s - loss: 4.7897e-05 - 46ms/epoch - 3ms/step
# Epoch 2685/5000
# 14/14 - 0s - loss: 5.9658e-05 - 43ms/epoch - 3ms/step
# Epoch 2686/5000
# 14/14 - 0s - loss: 2.6716e-05 - 67ms/epoch - 5ms/step
# Epoch 2687/5000
# 14/14 - 0s - loss: 1.5911e-05 - 61ms/epoch - 4ms/step
# Epoch 2688/5000
# 14/14 - 0s - loss: 1.1316e-05 - 64ms/epoch - 5ms/step
# Epoch 2689/5000
# 14/14 - 0s - loss: 7.2692e-06 - 69ms/epoch - 5ms/step
# Epoch 2690/5000
# 14/14 - 0s - loss: 6.1456e-06 - 67ms/epoch - 5ms/step
# Epoch 2691/5000
# 14/14 - 0s - loss: 7.5576e-06 - 44ms/epoch - 3ms/step
# Epoch 2692/5000
# 14/14 - 0s - loss: 1.2611e-05 - 45ms/epoch - 3ms/step
# Epoch 2693/5000
# 14/14 - 0s - loss: 1.0500e-05 - 41ms/epoch - 3ms/step
# Epoch 2694/5000
# 14/14 - 0s - loss: 8.9891e-06 - 48ms/epoch - 3ms/step
# Epoch 2695/5000
# 14/14 - 0s - loss: 1.0016e-05 - 50ms/epoch - 4ms/step
# Epoch 2696/5000
# 14/14 - 0s - loss: 7.4743e-06 - 49ms/epoch - 4ms/step
# Epoch 2697/5000
# 14/14 - 0s - loss: 6.0094e-06 - 51ms/epoch - 4ms/step
# Epoch 2698/5000
# 14/14 - 0s - loss: 7.6623e-06 - 46ms/epoch - 3ms/step
# Epoch 2699/5000
# 14/14 - 0s - loss: 5.6023e-06 - 49ms/epoch - 4ms/step
# Epoch 2700/5000
# 14/14 - 0s - loss: 7.0602e-06 - 44ms/epoch - 3ms/step
# Epoch 2701/5000
# 14/14 - 0s - loss: 5.8497e-06 - 45ms/epoch - 3ms/step
# Epoch 2702/5000
# 14/14 - 0s - loss: 6.8101e-06 - 54ms/epoch - 4ms/step
# Epoch 2703/5000
# 14/14 - 0s - loss: 1.2936e-05 - 47ms/epoch - 3ms/step
# Epoch 2704/5000
# 14/14 - 0s - loss: 1.0267e-05 - 55ms/epoch - 4ms/step
# Epoch 2705/5000
# 14/14 - 0s - loss: 7.2558e-06 - 57ms/epoch - 4ms/step
# Epoch 2706/5000
# 14/14 - 0s - loss: 7.6929e-06 - 53ms/epoch - 4ms/step
# Epoch 2707/5000
# 14/14 - 0s - loss: 5.9270e-06 - 64ms/epoch - 5ms/step
# Epoch 2708/5000
# 14/14 - 0s - loss: 6.0399e-06 - 68ms/epoch - 5ms/step
# Epoch 2709/5000
# 14/14 - 0s - loss: 5.2286e-06 - 60ms/epoch - 4ms/step
# Epoch 2710/5000
# 14/14 - 0s - loss: 6.3730e-06 - 61ms/epoch - 4ms/step
# Epoch 2711/5000
# 14/14 - 0s - loss: 7.9876e-06 - 49ms/epoch - 3ms/step
# Epoch 2712/5000
# 14/14 - 0s - loss: 2.2017e-05 - 72ms/epoch - 5ms/step
# Epoch 2713/5000
# 14/14 - 0s - loss: 2.7420e-05 - 63ms/epoch - 4ms/step
# Epoch 2714/5000
# 14/14 - 0s - loss: 4.8599e-05 - 39ms/epoch - 3ms/step
# Epoch 2715/5000
# 14/14 - 0s - loss: 2.1650e-05 - 40ms/epoch - 3ms/step
# Epoch 2716/5000
# 14/14 - 0s - loss: 2.2111e-05 - 52ms/epoch - 4ms/step
# Epoch 2717/5000
# 14/14 - 0s - loss: 1.4680e-05 - 62ms/epoch - 4ms/step
# Epoch 2718/5000
# 14/14 - 0s - loss: 2.8091e-05 - 56ms/epoch - 4ms/step
# Epoch 2719/5000
# 14/14 - 0s - loss: 2.5915e-05 - 71ms/epoch - 5ms/step
# Epoch 2720/5000
# 14/14 - 0s - loss: 1.7963e-05 - 54ms/epoch - 4ms/step
# Epoch 2721/5000
# 14/14 - 0s - loss: 1.5100e-05 - 53ms/epoch - 4ms/step
# Epoch 2722/5000
# 14/14 - 0s - loss: 1.4184e-05 - 48ms/epoch - 3ms/step
# Epoch 2723/5000
# 14/14 - 0s - loss: 1.8057e-05 - 48ms/epoch - 3ms/step
# Epoch 2724/5000
# 14/14 - 0s - loss: 1.0477e-05 - 40ms/epoch - 3ms/step
# Epoch 2725/5000
# 14/14 - 0s - loss: 7.2401e-06 - 34ms/epoch - 2ms/step
# Epoch 2726/5000
# 14/14 - 0s - loss: 7.0055e-06 - 36ms/epoch - 3ms/step
# Epoch 2727/5000
# 14/14 - 0s - loss: 7.5290e-06 - 37ms/epoch - 3ms/step
# Epoch 2728/5000
# 14/14 - 0s - loss: 8.0992e-06 - 34ms/epoch - 2ms/step
# Epoch 2729/5000
# 14/14 - 0s - loss: 9.1562e-06 - 38ms/epoch - 3ms/step
# Epoch 2730/5000
# 14/14 - 0s - loss: 7.6734e-06 - 34ms/epoch - 2ms/step
# Epoch 2731/5000
# 14/14 - 0s - loss: 7.5120e-06 - 38ms/epoch - 3ms/step
# Epoch 2732/5000
# 14/14 - 0s - loss: 7.8161e-06 - 34ms/epoch - 2ms/step
# Epoch 2733/5000
# 14/14 - 0s - loss: 7.8070e-06 - 35ms/epoch - 3ms/step
# Epoch 2734/5000
# 14/14 - 0s - loss: 4.9837e-06 - 58ms/epoch - 4ms/step
# Epoch 2735/5000
# 14/14 - 0s - loss: 7.5220e-06 - 35ms/epoch - 3ms/step
# Epoch 2736/5000
# 14/14 - 0s - loss: 1.0624e-05 - 31ms/epoch - 2ms/step
# Epoch 2737/5000
# 14/14 - 0s - loss: 1.1403e-05 - 33ms/epoch - 2ms/step
# Epoch 2738/5000
# 14/14 - 0s - loss: 1.0330e-05 - 49ms/epoch - 3ms/step
# Epoch 2739/5000
# 14/14 - 0s - loss: 1.2219e-05 - 48ms/epoch - 3ms/step
# Epoch 2740/5000
# 14/14 - 0s - loss: 2.2962e-05 - 39ms/epoch - 3ms/step
# Epoch 2741/5000
# 14/14 - 0s - loss: 1.9060e-05 - 39ms/epoch - 3ms/step
# Epoch 2742/5000
# 14/14 - 0s - loss: 2.3035e-05 - 43ms/epoch - 3ms/step
# Epoch 2743/5000
# 14/14 - 0s - loss: 1.6470e-05 - 47ms/epoch - 3ms/step
# Epoch 2744/5000
# 14/14 - 0s - loss: 2.2523e-05 - 45ms/epoch - 3ms/step
# Epoch 2745/5000
# 14/14 - 0s - loss: 1.6267e-05 - 46ms/epoch - 3ms/step
# Epoch 2746/5000
# 14/14 - 0s - loss: 2.1583e-05 - 52ms/epoch - 4ms/step
# Epoch 2747/5000
# 14/14 - 0s - loss: 2.7212e-05 - 43ms/epoch - 3ms/step
# Epoch 2748/5000
# 14/14 - 0s - loss: 2.1944e-05 - 42ms/epoch - 3ms/step
# Epoch 2749/5000
# 14/14 - 0s - loss: 2.8942e-05 - 42ms/epoch - 3ms/step
# Epoch 2750/5000
# 14/14 - 0s - loss: 2.4861e-05 - 46ms/epoch - 3ms/step
# Epoch 2751/5000
# 14/14 - 0s - loss: 1.9443e-05 - 47ms/epoch - 3ms/step
# Epoch 2752/5000
# 14/14 - 0s - loss: 2.1332e-05 - 51ms/epoch - 4ms/step
# Epoch 2753/5000
# 14/14 - 0s - loss: 2.6105e-05 - 50ms/epoch - 4ms/step
# Epoch 2754/5000
# 14/14 - 0s - loss: 2.2760e-05 - 49ms/epoch - 3ms/step
# Epoch 2755/5000
# 14/14 - 0s - loss: 2.2438e-05 - 52ms/epoch - 4ms/step
# Epoch 2756/5000
# 14/14 - 0s - loss: 1.6186e-05 - 57ms/epoch - 4ms/step
# Epoch 2757/5000
# 14/14 - 0s - loss: 1.3173e-05 - 58ms/epoch - 4ms/step
# Epoch 2758/5000
# 14/14 - 0s - loss: 2.2329e-05 - 59ms/epoch - 4ms/step
# Epoch 2759/5000
# 14/14 - 0s - loss: 1.3741e-05 - 47ms/epoch - 3ms/step
# Epoch 2760/5000
# 14/14 - 0s - loss: 1.7967e-05 - 43ms/epoch - 3ms/step
# Epoch 2761/5000
# 14/14 - 0s - loss: 2.5512e-05 - 43ms/epoch - 3ms/step
# Epoch 2762/5000
# 14/14 - 0s - loss: 2.6424e-05 - 48ms/epoch - 3ms/step
# Epoch 2763/5000
# 14/14 - 0s - loss: 4.3675e-05 - 40ms/epoch - 3ms/step
# Epoch 2764/5000
# 14/14 - 0s - loss: 6.1732e-05 - 46ms/epoch - 3ms/step
# Epoch 2765/5000
# 14/14 - 0s - loss: 7.3489e-05 - 48ms/epoch - 3ms/step
# Epoch 2766/5000
# 14/14 - 0s - loss: 1.3240e-04 - 41ms/epoch - 3ms/step
# Epoch 2767/5000
# 14/14 - 0s - loss: 2.7138e-04 - 42ms/epoch - 3ms/step
# Epoch 2768/5000
# 14/14 - 0s - loss: 0.0010 - 36ms/epoch - 3ms/step
# Epoch 2769/5000
# 14/14 - 0s - loss: 0.0011 - 39ms/epoch - 3ms/step
# Epoch 2770/5000
# 14/14 - 0s - loss: 0.0016 - 35ms/epoch - 2ms/step
# Epoch 2771/5000
# 14/14 - 0s - loss: 0.0011 - 34ms/epoch - 2ms/step
# Epoch 2772/5000
# 14/14 - 0s - loss: 5.3932e-04 - 36ms/epoch - 3ms/step
# Epoch 2773/5000
# 14/14 - 0s - loss: 4.6697e-04 - 43ms/epoch - 3ms/step
# Epoch 2774/5000
# 14/14 - 0s - loss: 5.0871e-04 - 36ms/epoch - 3ms/step
# Epoch 2775/5000
# 14/14 - 0s - loss: 3.9063e-04 - 38ms/epoch - 3ms/step
# Epoch 2776/5000
# 14/14 - 0s - loss: 2.0995e-04 - 35ms/epoch - 3ms/step
# Epoch 2777/5000
# 14/14 - 0s - loss: 1.6630e-04 - 32ms/epoch - 2ms/step
# Epoch 2778/5000
# 14/14 - 0s - loss: 1.0207e-04 - 33ms/epoch - 2ms/step
# Epoch 2779/5000
# 14/14 - 0s - loss: 1.0336e-04 - 42ms/epoch - 3ms/step
# Epoch 2780/5000
# 14/14 - 0s - loss: 1.0444e-04 - 34ms/epoch - 2ms/step
# Epoch 2781/5000
# 14/14 - 0s - loss: 9.1809e-05 - 36ms/epoch - 3ms/step
# Epoch 2782/5000
# 14/14 - 0s - loss: 5.6406e-05 - 33ms/epoch - 2ms/step
# Epoch 2783/5000
# 14/14 - 0s - loss: 3.6665e-05 - 34ms/epoch - 2ms/step
# Epoch 2784/5000
# 14/14 - 0s - loss: 2.8039e-05 - 33ms/epoch - 2ms/step
# Epoch 2785/5000
# 14/14 - 0s - loss: 2.1682e-05 - 32ms/epoch - 2ms/step
# Epoch 2786/5000
# 14/14 - 0s - loss: 2.1332e-05 - 49ms/epoch - 4ms/step
# Epoch 2787/5000
# 14/14 - 0s - loss: 3.0539e-05 - 48ms/epoch - 3ms/step
# Epoch 2788/5000
# 14/14 - 0s - loss: 2.6404e-05 - 50ms/epoch - 4ms/step
# Epoch 2789/5000
# 14/14 - 0s - loss: 3.2623e-05 - 42ms/epoch - 3ms/step
# Epoch 2790/5000
# 14/14 - 0s - loss: 2.2574e-05 - 44ms/epoch - 3ms/step
# Epoch 2791/5000
# 14/14 - 0s - loss: 2.2615e-05 - 45ms/epoch - 3ms/step
# Epoch 2792/5000
# 14/14 - 0s - loss: 1.5949e-05 - 45ms/epoch - 3ms/step
# Epoch 2793/5000
# 14/14 - 0s - loss: 1.2363e-05 - 44ms/epoch - 3ms/step
# Epoch 2794/5000
# 14/14 - 0s - loss: 1.1302e-05 - 47ms/epoch - 3ms/step
# Epoch 2795/5000
# 14/14 - 0s - loss: 8.7217e-06 - 46ms/epoch - 3ms/step
# Epoch 2796/5000
# 14/14 - 0s - loss: 7.0305e-06 - 56ms/epoch - 4ms/step
# Epoch 2797/5000
# 14/14 - 0s - loss: 7.2627e-06 - 52ms/epoch - 4ms/step
# Epoch 2798/5000
# 14/14 - 0s - loss: 8.0494e-06 - 46ms/epoch - 3ms/step
# Epoch 2799/5000
# 14/14 - 0s - loss: 7.8900e-06 - 40ms/epoch - 3ms/step
# Epoch 2800/5000
# 14/14 - 0s - loss: 9.1735e-06 - 44ms/epoch - 3ms/step
# Epoch 2801/5000
# 14/14 - 0s - loss: 7.1077e-06 - 42ms/epoch - 3ms/step
# Epoch 2802/5000
# 14/14 - 0s - loss: 7.9749e-06 - 60ms/epoch - 4ms/step
# Epoch 2803/5000
# 14/14 - 0s - loss: 1.0956e-05 - 54ms/epoch - 4ms/step
# Epoch 2804/5000
# 14/14 - 0s - loss: 9.7971e-06 - 62ms/epoch - 4ms/step
# Epoch 2805/5000
# 14/14 - 0s - loss: 7.3322e-06 - 74ms/epoch - 5ms/step
# Epoch 2806/5000
# 14/14 - 0s - loss: 7.6879e-06 - 47ms/epoch - 3ms/step
# Epoch 2807/5000
# 14/14 - 0s - loss: 6.6311e-06 - 55ms/epoch - 4ms/step
# Epoch 2808/5000
# 14/14 - 0s - loss: 1.1119e-05 - 56ms/epoch - 4ms/step
# Epoch 2809/5000
# 14/14 - 0s - loss: 1.0478e-05 - 48ms/epoch - 3ms/step
# Epoch 2810/5000
# 14/14 - 0s - loss: 9.0396e-06 - 38ms/epoch - 3ms/step
# Epoch 2811/5000
# 14/14 - 0s - loss: 7.8161e-06 - 32ms/epoch - 2ms/step
# Epoch 2812/5000
# 14/14 - 0s - loss: 7.6412e-06 - 37ms/epoch - 3ms/step
# Epoch 2813/5000
# 14/14 - 0s - loss: 6.9847e-06 - 35ms/epoch - 3ms/step
# Epoch 2814/5000
# 14/14 - 0s - loss: 7.2703e-06 - 36ms/epoch - 3ms/step
# Epoch 2815/5000
# 14/14 - 0s - loss: 5.6380e-06 - 40ms/epoch - 3ms/step
# Epoch 2816/5000
# 14/14 - 0s - loss: 7.0375e-06 - 37ms/epoch - 3ms/step
# Epoch 2817/5000
# 14/14 - 0s - loss: 4.9334e-06 - 51ms/epoch - 4ms/step
# Epoch 2818/5000
# 14/14 - 0s - loss: 6.4343e-06 - 35ms/epoch - 3ms/step
# Epoch 2819/5000
# 14/14 - 0s - loss: 5.8057e-06 - 38ms/epoch - 3ms/step
# Epoch 2820/5000
# 14/14 - 0s - loss: 5.9383e-06 - 37ms/epoch - 3ms/step
# Epoch 2821/5000
# 14/14 - 0s - loss: 7.2234e-06 - 39ms/epoch - 3ms/step
# Epoch 2822/5000
# 14/14 - 0s - loss: 5.9643e-06 - 44ms/epoch - 3ms/step
# Epoch 2823/5000
# 14/14 - 0s - loss: 5.6816e-06 - 40ms/epoch - 3ms/step
# Epoch 2824/5000
# 14/14 - 0s - loss: 5.0047e-06 - 38ms/epoch - 3ms/step
# Epoch 2825/5000
# 14/14 - 0s - loss: 5.0125e-06 - 56ms/epoch - 4ms/step
# Epoch 2826/5000
# 14/14 - 0s - loss: 6.1746e-06 - 58ms/epoch - 4ms/step
# Epoch 2827/5000
# 14/14 - 0s - loss: 6.8055e-06 - 53ms/epoch - 4ms/step
# Epoch 2828/5000
# 14/14 - 0s - loss: 6.4302e-06 - 44ms/epoch - 3ms/step
# Epoch 2829/5000
# 14/14 - 0s - loss: 6.8825e-06 - 49ms/epoch - 3ms/step
# Epoch 2830/5000
# 14/14 - 0s - loss: 8.7312e-06 - 58ms/epoch - 4ms/step
# Epoch 2831/5000
# 14/14 - 0s - loss: 1.3336e-05 - 50ms/epoch - 4ms/step
# Epoch 2832/5000
# 14/14 - 0s - loss: 1.2506e-05 - 47ms/epoch - 3ms/step
# Epoch 2833/5000
# 14/14 - 0s - loss: 1.8132e-05 - 59ms/epoch - 4ms/step
# Epoch 2834/5000
# 14/14 - 0s - loss: 1.0660e-05 - 85ms/epoch - 6ms/step
# Epoch 2835/5000
# 14/14 - 0s - loss: 8.6779e-06 - 78ms/epoch - 6ms/step
# Epoch 2836/5000
# 14/14 - 0s - loss: 1.4306e-05 - 78ms/epoch - 6ms/step
# Epoch 2837/5000
# 14/14 - 0s - loss: 1.6503e-05 - 75ms/epoch - 5ms/step
# Epoch 2838/5000
# 14/14 - 0s - loss: 1.6017e-05 - 77ms/epoch - 5ms/step
# Epoch 2839/5000
# 14/14 - 0s - loss: 1.4775e-05 - 37ms/epoch - 3ms/step
# Epoch 2840/5000
# 14/14 - 0s - loss: 1.1623e-05 - 66ms/epoch - 5ms/step
# Epoch 2841/5000
# 14/14 - 0s - loss: 7.6462e-06 - 60ms/epoch - 4ms/step
# Epoch 2842/5000
# 14/14 - 0s - loss: 7.8242e-06 - 49ms/epoch - 3ms/step
# Epoch 2843/5000
# 14/14 - 0s - loss: 9.6085e-06 - 50ms/epoch - 4ms/step
# Epoch 2844/5000
# 14/14 - 0s - loss: 1.6504e-05 - 48ms/epoch - 3ms/step
# Epoch 2845/5000
# 14/14 - 0s - loss: 1.1654e-05 - 47ms/epoch - 3ms/step
# Epoch 2846/5000
# 14/14 - 0s - loss: 1.6092e-05 - 36ms/epoch - 3ms/step
# Epoch 2847/5000
# 14/14 - 0s - loss: 1.2180e-05 - 36ms/epoch - 3ms/step
# Epoch 2848/5000
# 14/14 - 0s - loss: 1.9667e-05 - 38ms/epoch - 3ms/step
# Epoch 2849/5000
# 14/14 - 0s - loss: 2.0344e-05 - 36ms/epoch - 3ms/step
# Epoch 2850/5000
# 14/14 - 0s - loss: 2.1824e-05 - 34ms/epoch - 2ms/step
# Epoch 2851/5000
# 14/14 - 0s - loss: 3.0655e-05 - 39ms/epoch - 3ms/step
# Epoch 2852/5000
# 14/14 - 0s - loss: 4.3615e-05 - 37ms/epoch - 3ms/step
# Epoch 2853/5000
# 14/14 - 0s - loss: 2.6058e-05 - 40ms/epoch - 3ms/step
# Epoch 2854/5000
# 14/14 - 0s - loss: 2.5016e-05 - 36ms/epoch - 3ms/step
# Epoch 2855/5000
# 14/14 - 0s - loss: 2.2439e-05 - 37ms/epoch - 3ms/step
# Epoch 2856/5000
# 14/14 - 0s - loss: 1.9065e-05 - 38ms/epoch - 3ms/step
# Epoch 2857/5000
# 14/14 - 0s - loss: 1.2835e-05 - 38ms/epoch - 3ms/step
# Epoch 2858/5000
# 14/14 - 0s - loss: 1.2885e-05 - 37ms/epoch - 3ms/step
# Epoch 2859/5000
# 14/14 - 0s - loss: 1.2076e-05 - 40ms/epoch - 3ms/step
# Epoch 2860/5000
# 14/14 - 0s - loss: 2.5659e-05 - 41ms/epoch - 3ms/step
# Epoch 2861/5000
# 14/14 - 0s - loss: 1.7201e-05 - 43ms/epoch - 3ms/step
# Epoch 2862/5000
# 14/14 - 0s - loss: 3.6252e-05 - 40ms/epoch - 3ms/step
# Epoch 2863/5000
# 14/14 - 0s - loss: 2.4227e-05 - 47ms/epoch - 3ms/step
# Epoch 2864/5000
# 14/14 - 0s - loss: 2.8362e-05 - 66ms/epoch - 5ms/step
# Epoch 2865/5000
# 14/14 - 0s - loss: 2.7455e-05 - 61ms/epoch - 4ms/step
# Epoch 2866/5000
# 14/14 - 0s - loss: 5.0120e-05 - 65ms/epoch - 5ms/step
# Epoch 2867/5000
# 14/14 - 0s - loss: 5.2871e-05 - 70ms/epoch - 5ms/step
# Epoch 2868/5000
# 14/14 - 0s - loss: 3.8511e-05 - 65ms/epoch - 5ms/step
# Epoch 2869/5000
# 14/14 - 0s - loss: 3.1520e-05 - 61ms/epoch - 4ms/step
# Epoch 2870/5000
# 14/14 - 0s - loss: 3.1899e-05 - 59ms/epoch - 4ms/step
# Epoch 2871/5000
# 14/14 - 0s - loss: 2.6406e-05 - 36ms/epoch - 3ms/step
# Epoch 2872/5000
# 14/14 - 0s - loss: 4.0862e-05 - 38ms/epoch - 3ms/step
# Epoch 2873/5000
# 14/14 - 0s - loss: 2.3666e-05 - 34ms/epoch - 2ms/step
# Epoch 2874/5000
# 14/14 - 0s - loss: 2.0804e-05 - 37ms/epoch - 3ms/step
# Epoch 2875/5000
# 14/14 - 0s - loss: 2.0229e-05 - 48ms/epoch - 3ms/step
# Epoch 2876/5000
# 14/14 - 0s - loss: 2.1820e-05 - 35ms/epoch - 2ms/step
# Epoch 2877/5000
# 14/14 - 0s - loss: 1.9562e-05 - 37ms/epoch - 3ms/step
# Epoch 2878/5000
# 14/14 - 0s - loss: 3.0967e-05 - 38ms/epoch - 3ms/step
# Epoch 2879/5000
# 14/14 - 0s - loss: 2.7380e-05 - 36ms/epoch - 3ms/step
# Epoch 2880/5000
# 14/14 - 0s - loss: 2.3456e-05 - 37ms/epoch - 3ms/step
# Epoch 2881/5000
# 14/14 - 0s - loss: 2.2016e-05 - 51ms/epoch - 4ms/step
# Epoch 2882/5000
# 14/14 - 0s - loss: 3.9243e-05 - 84ms/epoch - 6ms/step
# Epoch 2883/5000
# 14/14 - 0s - loss: 7.1357e-05 - 82ms/epoch - 6ms/step
# Epoch 2884/5000
# 14/14 - 0s - loss: 7.8117e-05 - 74ms/epoch - 5ms/step
# Epoch 2885/5000
# 14/14 - 0s - loss: 7.2042e-05 - 76ms/epoch - 5ms/step
# Epoch 2886/5000
# 14/14 - 0s - loss: 8.2418e-05 - 78ms/epoch - 6ms/step
# Epoch 2887/5000
# 14/14 - 0s - loss: 7.0661e-05 - 65ms/epoch - 5ms/step
# Epoch 2888/5000
# 14/14 - 0s - loss: 9.0230e-05 - 83ms/epoch - 6ms/step
# Epoch 2889/5000
# 14/14 - 0s - loss: 1.1482e-04 - 70ms/epoch - 5ms/step
# Epoch 2890/5000
# 14/14 - 0s - loss: 6.5689e-05 - 63ms/epoch - 4ms/step
# Epoch 2891/5000
# 14/14 - 0s - loss: 5.8555e-05 - 63ms/epoch - 5ms/step
# Epoch 2892/5000
# 14/14 - 0s - loss: 3.9565e-05 - 39ms/epoch - 3ms/step
# Epoch 2893/5000
# 14/14 - 0s - loss: 3.4526e-05 - 42ms/epoch - 3ms/step
# Epoch 2894/5000
# 14/14 - 0s - loss: 2.7888e-05 - 54ms/epoch - 4ms/step
# Epoch 2895/5000
# 14/14 - 0s - loss: 3.6820e-05 - 62ms/epoch - 4ms/step
# Epoch 2896/5000
# 14/14 - 0s - loss: 2.6196e-05 - 66ms/epoch - 5ms/step
# Epoch 2897/5000
# 14/14 - 0s - loss: 2.6143e-05 - 64ms/epoch - 5ms/step
# Epoch 2898/5000
# 14/14 - 0s - loss: 2.1900e-05 - 53ms/epoch - 4ms/step
# Epoch 2899/5000
# 14/14 - 0s - loss: 1.7303e-05 - 49ms/epoch - 4ms/step
# Epoch 2900/5000
# 14/14 - 0s - loss: 4.2104e-05 - 56ms/epoch - 4ms/step
# Epoch 2901/5000
# 14/14 - 0s - loss: 4.8754e-05 - 50ms/epoch - 4ms/step
# Epoch 2902/5000
# 14/14 - 0s - loss: 6.0223e-05 - 52ms/epoch - 4ms/step
# Epoch 2903/5000
# 14/14 - 0s - loss: 5.2802e-05 - 42ms/epoch - 3ms/step
# Epoch 2904/5000
# 14/14 - 0s - loss: 5.5518e-05 - 43ms/epoch - 3ms/step
# Epoch 2905/5000
# 14/14 - 0s - loss: 3.2477e-05 - 55ms/epoch - 4ms/step
# Epoch 2906/5000
# 14/14 - 0s - loss: 3.0249e-05 - 54ms/epoch - 4ms/step
# Epoch 2907/5000
# 14/14 - 0s - loss: 3.7813e-05 - 40ms/epoch - 3ms/step
# Epoch 2908/5000
# 14/14 - 0s - loss: 4.0294e-05 - 44ms/epoch - 3ms/step
# Epoch 2909/5000
# 14/14 - 0s - loss: 5.1942e-05 - 44ms/epoch - 3ms/step
# Epoch 2910/5000
# 14/14 - 0s - loss: 5.8763e-05 - 45ms/epoch - 3ms/step
# Epoch 2911/5000
# 14/14 - 0s - loss: 4.6304e-05 - 44ms/epoch - 3ms/step
# Epoch 2912/5000
# 14/14 - 0s - loss: 5.8422e-05 - 49ms/epoch - 3ms/step
# Epoch 2913/5000
# 14/14 - 0s - loss: 1.2137e-04 - 40ms/epoch - 3ms/step
# Epoch 2914/5000
# 14/14 - 0s - loss: 1.0400e-04 - 62ms/epoch - 4ms/step
# Epoch 2915/5000
# 14/14 - 0s - loss: 7.5098e-05 - 71ms/epoch - 5ms/step
# Epoch 2916/5000
# 14/14 - 0s - loss: 4.6500e-05 - 60ms/epoch - 4ms/step
# Epoch 2917/5000
# 14/14 - 0s - loss: 4.0626e-05 - 73ms/epoch - 5ms/step
# Epoch 2918/5000
# 14/14 - 0s - loss: 3.8588e-05 - 67ms/epoch - 5ms/step
# Epoch 2919/5000
# 14/14 - 0s - loss: 4.8447e-05 - 70ms/epoch - 5ms/step
# Epoch 2920/5000
# 14/14 - 0s - loss: 3.9120e-05 - 76ms/epoch - 5ms/step
# Epoch 2921/5000
# 14/14 - 0s - loss: 3.8840e-05 - 65ms/epoch - 5ms/step
# Epoch 2922/5000
# 14/14 - 0s - loss: 3.6451e-05 - 46ms/epoch - 3ms/step
# Epoch 2923/5000
# 14/14 - 0s - loss: 5.0865e-05 - 46ms/epoch - 3ms/step
# Epoch 2924/5000
# 14/14 - 0s - loss: 3.0361e-05 - 54ms/epoch - 4ms/step
# Epoch 2925/5000
# 14/14 - 0s - loss: 3.2722e-05 - 38ms/epoch - 3ms/step
# Epoch 2926/5000
# 14/14 - 0s - loss: 4.5329e-05 - 42ms/epoch - 3ms/step
# Epoch 2927/5000
# 14/14 - 0s - loss: 2.9494e-05 - 39ms/epoch - 3ms/step
# Epoch 2928/5000
# 14/14 - 0s - loss: 1.5162e-05 - 40ms/epoch - 3ms/step
# Epoch 2929/5000
# 14/14 - 0s - loss: 1.1219e-05 - 39ms/epoch - 3ms/step
# Epoch 2930/5000
# 14/14 - 0s - loss: 1.2642e-05 - 56ms/epoch - 4ms/step
# Epoch 2931/5000
# 14/14 - 0s - loss: 1.5242e-05 - 61ms/epoch - 4ms/step
# Epoch 2932/5000
# 14/14 - 0s - loss: 1.0285e-05 - 68ms/epoch - 5ms/step
# Epoch 2933/5000
# 14/14 - 0s - loss: 1.1520e-05 - 63ms/epoch - 5ms/step
# Epoch 2934/5000
# 14/14 - 0s - loss: 1.2785e-05 - 60ms/epoch - 4ms/step
# Epoch 2935/5000
# 14/14 - 0s - loss: 1.0474e-05 - 53ms/epoch - 4ms/step
# Epoch 2936/5000
# 14/14 - 0s - loss: 1.0133e-05 - 39ms/epoch - 3ms/step
# Epoch 2937/5000
# 14/14 - 0s - loss: 1.7261e-05 - 41ms/epoch - 3ms/step
# Epoch 2938/5000
# 14/14 - 0s - loss: 2.8071e-05 - 37ms/epoch - 3ms/step
# Epoch 2939/5000
# 14/14 - 0s - loss: 4.0530e-05 - 42ms/epoch - 3ms/step
# Epoch 2940/5000
# 14/14 - 0s - loss: 3.2110e-05 - 41ms/epoch - 3ms/step
# Epoch 2941/5000
# 14/14 - 0s - loss: 4.7962e-05 - 43ms/epoch - 3ms/step
# Epoch 2942/5000
# 14/14 - 0s - loss: 6.1828e-05 - 37ms/epoch - 3ms/step
# Epoch 2943/5000
# 14/14 - 0s - loss: 6.5444e-05 - 39ms/epoch - 3ms/step
# Epoch 2944/5000
# 14/14 - 0s - loss: 1.0016e-04 - 42ms/epoch - 3ms/step
# Epoch 2945/5000
# 14/14 - 0s - loss: 4.7304e-05 - 42ms/epoch - 3ms/step
# Epoch 2946/5000
# 14/14 - 0s - loss: 7.2554e-05 - 43ms/epoch - 3ms/step
# Epoch 2947/5000
# 14/14 - 0s - loss: 7.2102e-05 - 48ms/epoch - 3ms/step
# Epoch 2948/5000
# 14/14 - 0s - loss: 8.2247e-05 - 40ms/epoch - 3ms/step
# Epoch 2949/5000
# 14/14 - 0s - loss: 1.3897e-04 - 43ms/epoch - 3ms/step
# Epoch 2950/5000
# 14/14 - 0s - loss: 1.4068e-04 - 68ms/epoch - 5ms/step
# Epoch 2951/5000
# 14/14 - 0s - loss: 7.6458e-05 - 68ms/epoch - 5ms/step
# Epoch 2952/5000
# 14/14 - 0s - loss: 5.7531e-05 - 65ms/epoch - 5ms/step
# Epoch 2953/5000
# 14/14 - 0s - loss: 5.3864e-05 - 74ms/epoch - 5ms/step
# Epoch 2954/5000
# 14/14 - 0s - loss: 2.8054e-05 - 55ms/epoch - 4ms/step
# Epoch 2955/5000
# 14/14 - 0s - loss: 1.8456e-05 - 52ms/epoch - 4ms/step
# Epoch 2956/5000
# 14/14 - 0s - loss: 1.2566e-05 - 49ms/epoch - 4ms/step
# Epoch 2957/5000
# 14/14 - 0s - loss: 1.5969e-05 - 49ms/epoch - 4ms/step
# Epoch 2958/5000
# 14/14 - 0s - loss: 3.0071e-05 - 48ms/epoch - 3ms/step
# Epoch 2959/5000
# 14/14 - 0s - loss: 3.2155e-05 - 46ms/epoch - 3ms/step
# Epoch 2960/5000
# 14/14 - 0s - loss: 2.9442e-05 - 37ms/epoch - 3ms/step
# Epoch 2961/5000
# 14/14 - 0s - loss: 2.9748e-05 - 54ms/epoch - 4ms/step
# Epoch 2962/5000
# 14/14 - 0s - loss: 2.1790e-05 - 47ms/epoch - 3ms/step
# Epoch 2963/5000
# 14/14 - 0s - loss: 2.0195e-05 - 57ms/epoch - 4ms/step
# Epoch 2964/5000
# 14/14 - 0s - loss: 1.9732e-05 - 46ms/epoch - 3ms/step
# Epoch 2965/5000
# 14/14 - 0s - loss: 2.4446e-05 - 45ms/epoch - 3ms/step
# Epoch 2966/5000
# 14/14 - 0s - loss: 2.9562e-05 - 53ms/epoch - 4ms/step
# Epoch 2967/5000
# 14/14 - 0s - loss: 1.6945e-05 - 53ms/epoch - 4ms/step
# Epoch 2968/5000
# 14/14 - 0s - loss: 1.3504e-05 - 75ms/epoch - 5ms/step
# Epoch 2969/5000
# 14/14 - 0s - loss: 2.0185e-05 - 60ms/epoch - 4ms/step
# Epoch 2970/5000
# 14/14 - 0s - loss: 2.3126e-05 - 53ms/epoch - 4ms/step
# Epoch 2971/5000
# 14/14 - 0s - loss: 2.3912e-05 - 54ms/epoch - 4ms/step
# Epoch 2972/5000
# 14/14 - 0s - loss: 3.6852e-05 - 41ms/epoch - 3ms/step
# Epoch 2973/5000
# 14/14 - 0s - loss: 3.3704e-05 - 47ms/epoch - 3ms/step
# Epoch 2974/5000
# 14/14 - 0s - loss: 1.7859e-05 - 47ms/epoch - 3ms/step
# Epoch 2975/5000
# 14/14 - 0s - loss: 9.3124e-06 - 50ms/epoch - 4ms/step
# Epoch 2976/5000
# 14/14 - 0s - loss: 9.2742e-06 - 59ms/epoch - 4ms/step
# Epoch 2977/5000
# 14/14 - 0s - loss: 8.5981e-06 - 51ms/epoch - 4ms/step
# Epoch 2978/5000
# 14/14 - 0s - loss: 1.7580e-05 - 45ms/epoch - 3ms/step
# Epoch 2979/5000
# 14/14 - 0s - loss: 2.0856e-05 - 61ms/epoch - 4ms/step
# Epoch 2980/5000
# 14/14 - 0s - loss: 2.7315e-05 - 56ms/epoch - 4ms/step
# Epoch 2981/5000
# 14/14 - 0s - loss: 2.9691e-05 - 59ms/epoch - 4ms/step
# Epoch 2982/5000
# 14/14 - 0s - loss: 1.5902e-05 - 41ms/epoch - 3ms/step
# Epoch 2983/5000
# 14/14 - 0s - loss: 2.5179e-05 - 43ms/epoch - 3ms/step
# Epoch 2984/5000
# 14/14 - 0s - loss: 3.2360e-05 - 57ms/epoch - 4ms/step
# Epoch 2985/5000
# 14/14 - 0s - loss: 3.3765e-05 - 42ms/epoch - 3ms/step
# Epoch 2986/5000
# 14/14 - 0s - loss: 2.2688e-05 - 68ms/epoch - 5ms/step
# Epoch 2987/5000
# 14/14 - 0s - loss: 2.3724e-05 - 44ms/epoch - 3ms/step
# Epoch 2988/5000
# 14/14 - 0s - loss: 1.6298e-05 - 38ms/epoch - 3ms/step
# Epoch 2989/5000
# 14/14 - 0s - loss: 1.2049e-05 - 40ms/epoch - 3ms/step
# Epoch 2990/5000
# 14/14 - 0s - loss: 1.7850e-05 - 31ms/epoch - 2ms/step
# Epoch 2991/5000
# 14/14 - 0s - loss: 1.6589e-05 - 35ms/epoch - 2ms/step
# Epoch 2992/5000
# 14/14 - 0s - loss: 8.4845e-06 - 33ms/epoch - 2ms/step
# Epoch 2993/5000
# 14/14 - 0s - loss: 2.7261e-05 - 34ms/epoch - 2ms/step
# Epoch 2994/5000
# 14/14 - 0s - loss: 2.4382e-05 - 36ms/epoch - 3ms/step
# Epoch 2995/5000
# 14/14 - 0s - loss: 2.5955e-05 - 36ms/epoch - 3ms/step
# Epoch 2996/5000
# 14/14 - 0s - loss: 1.8064e-05 - 32ms/epoch - 2ms/step
# Epoch 2997/5000
# 14/14 - 0s - loss: 1.6409e-05 - 33ms/epoch - 2ms/step
# Epoch 2998/5000
# 14/14 - 0s - loss: 2.8384e-05 - 43ms/epoch - 3ms/step
# Epoch 2999/5000
# 14/14 - 0s - loss: 3.4107e-05 - 35ms/epoch - 3ms/step
# Epoch 3000/5000
# 14/14 - 0s - loss: 4.0691e-05 - 33ms/epoch - 2ms/step
# Epoch 3001/5000
# 14/14 - 0s - loss: 3.0982e-05 - 36ms/epoch - 3ms/step
# Epoch 3002/5000
# 14/14 - 0s - loss: 3.3965e-05 - 35ms/epoch - 3ms/step
# Epoch 3003/5000
# 14/14 - 0s - loss: 2.9124e-05 - 35ms/epoch - 2ms/step
# Epoch 3004/5000
# 14/14 - 0s - loss: 5.4566e-05 - 37ms/epoch - 3ms/step
# Epoch 3005/5000
# 14/14 - 0s - loss: 4.2859e-05 - 33ms/epoch - 2ms/step
# Epoch 3006/5000
# 14/14 - 0s - loss: 1.2925e-04 - 36ms/epoch - 3ms/step
# Epoch 3007/5000
# 14/14 - 0s - loss: 1.0156e-04 - 44ms/epoch - 3ms/step
# Epoch 3008/5000
# 14/14 - 0s - loss: 1.9058e-04 - 49ms/epoch - 3ms/step
# Epoch 3009/5000
# 14/14 - 0s - loss: 1.3925e-04 - 64ms/epoch - 5ms/step
# Epoch 3010/5000
# 14/14 - 0s - loss: 2.0188e-04 - 44ms/epoch - 3ms/step
# Epoch 3011/5000
# 14/14 - 0s - loss: 3.9476e-04 - 40ms/epoch - 3ms/step
# Epoch 3012/5000
# 14/14 - 0s - loss: 2.1218e-04 - 51ms/epoch - 4ms/step
# Epoch 3013/5000
# 14/14 - 0s - loss: 2.3585e-04 - 41ms/epoch - 3ms/step
# Epoch 3014/5000
# 14/14 - 0s - loss: 1.7384e-04 - 40ms/epoch - 3ms/step
# Epoch 3015/5000
# 14/14 - 0s - loss: 4.6830e-04 - 42ms/epoch - 3ms/step
# Epoch 3016/5000
# 14/14 - 0s - loss: 6.0928e-04 - 45ms/epoch - 3ms/step
# Epoch 3017/5000
# 14/14 - 0s - loss: 8.0912e-04 - 42ms/epoch - 3ms/step
# Epoch 3018/5000
# 14/14 - 0s - loss: 6.5006e-04 - 47ms/epoch - 3ms/step
# Epoch 3019/5000
# 14/14 - 0s - loss: 2.6380e-04 - 47ms/epoch - 3ms/step
# Epoch 3020/5000
# 14/14 - 0s - loss: 2.3449e-04 - 43ms/epoch - 3ms/step
# Epoch 3021/5000
# 14/14 - 0s - loss: 2.5207e-04 - 38ms/epoch - 3ms/step
# Epoch 3022/5000
# 14/14 - 0s - loss: 1.1447e-04 - 45ms/epoch - 3ms/step
# Epoch 3023/5000
# 14/14 - 0s - loss: 6.3753e-05 - 54ms/epoch - 4ms/step
# Epoch 3024/5000
# 14/14 - 0s - loss: 4.2057e-05 - 43ms/epoch - 3ms/step
# Epoch 3025/5000
# 14/14 - 0s - loss: 2.7048e-05 - 53ms/epoch - 4ms/step
# Epoch 3026/5000
# 14/14 - 0s - loss: 2.4990e-05 - 48ms/epoch - 3ms/step
# Epoch 3027/5000
# 14/14 - 0s - loss: 1.5695e-05 - 50ms/epoch - 4ms/step
# Epoch 3028/5000
# 14/14 - 0s - loss: 2.5073e-05 - 52ms/epoch - 4ms/step
# Epoch 3029/5000
# 14/14 - 0s - loss: 2.0169e-05 - 58ms/epoch - 4ms/step
# Epoch 3030/5000
# 14/14 - 0s - loss: 1.4815e-05 - 69ms/epoch - 5ms/step
# Epoch 3031/5000
# 14/14 - 0s - loss: 3.2197e-05 - 40ms/epoch - 3ms/step
# Epoch 3032/5000
# 14/14 - 0s - loss: 2.6920e-05 - 44ms/epoch - 3ms/step
# Epoch 3033/5000
# 14/14 - 0s - loss: 2.2694e-05 - 40ms/epoch - 3ms/step
# Epoch 3034/5000
# 14/14 - 0s - loss: 2.3795e-05 - 36ms/epoch - 3ms/step
# Epoch 3035/5000
# 14/14 - 0s - loss: 1.6734e-05 - 35ms/epoch - 3ms/step
# Epoch 3036/5000
# 14/14 - 0s - loss: 1.8347e-05 - 36ms/epoch - 3ms/step
# Epoch 3037/5000
# 14/14 - 0s - loss: 1.3741e-05 - 35ms/epoch - 3ms/step
# Epoch 3038/5000
# 14/14 - 0s - loss: 1.3484e-05 - 43ms/epoch - 3ms/step
# Epoch 3039/5000
# 14/14 - 0s - loss: 1.1725e-05 - 33ms/epoch - 2ms/step
# Epoch 3040/5000
# 14/14 - 0s - loss: 1.4220e-05 - 33ms/epoch - 2ms/step
# Epoch 3041/5000
# 14/14 - 0s - loss: 1.1744e-05 - 32ms/epoch - 2ms/step
# Epoch 3042/5000
# 14/14 - 0s - loss: 7.5537e-06 - 31ms/epoch - 2ms/step
# Epoch 3043/5000
# 14/14 - 0s - loss: 6.8352e-06 - 38ms/epoch - 3ms/step
# Epoch 3044/5000
# 14/14 - 0s - loss: 7.4944e-06 - 33ms/epoch - 2ms/step
# Epoch 3045/5000
# 14/14 - 0s - loss: 8.3299e-06 - 32ms/epoch - 2ms/step
# Epoch 3046/5000
# 14/14 - 0s - loss: 5.6741e-06 - 36ms/epoch - 3ms/step
# Epoch 3047/5000
# 14/14 - 0s - loss: 5.3606e-06 - 36ms/epoch - 3ms/step
# Epoch 3048/5000
# 14/14 - 0s - loss: 1.5742e-05 - 35ms/epoch - 2ms/step
# Epoch 3049/5000
# 14/14 - 0s - loss: 1.4951e-05 - 43ms/epoch - 3ms/step
# Epoch 3050/5000
# 14/14 - 0s - loss: 9.2217e-06 - 42ms/epoch - 3ms/step
# Epoch 3051/5000
# 14/14 - 0s - loss: 8.2771e-06 - 39ms/epoch - 3ms/step
# Epoch 3052/5000
# 14/14 - 0s - loss: 6.2516e-06 - 45ms/epoch - 3ms/step
# Epoch 3053/5000
# 14/14 - 0s - loss: 7.6895e-06 - 51ms/epoch - 4ms/step
# Epoch 3054/5000
# 14/14 - 0s - loss: 6.3932e-06 - 43ms/epoch - 3ms/step
# Epoch 3055/5000
# 14/14 - 0s - loss: 7.8975e-06 - 44ms/epoch - 3ms/step
# Epoch 3056/5000
# 14/14 - 0s - loss: 7.7154e-06 - 46ms/epoch - 3ms/step
# Epoch 3057/5000
# 14/14 - 0s - loss: 6.4059e-06 - 41ms/epoch - 3ms/step
# Epoch 3058/5000
# 14/14 - 0s - loss: 5.3301e-06 - 44ms/epoch - 3ms/step
# Epoch 3059/5000
# 14/14 - 0s - loss: 6.0830e-06 - 42ms/epoch - 3ms/step
# Epoch 3060/5000
# 14/14 - 0s - loss: 5.5326e-06 - 41ms/epoch - 3ms/step
# Epoch 3061/5000
# 14/14 - 0s - loss: 6.0051e-06 - 62ms/epoch - 4ms/step
# Epoch 3062/5000
# 14/14 - 0s - loss: 4.4120e-06 - 46ms/epoch - 3ms/step
# Epoch 3063/5000
# 14/14 - 0s - loss: 4.4021e-06 - 41ms/epoch - 3ms/step
# Epoch 3064/5000
# 14/14 - 0s - loss: 4.0717e-06 - 38ms/epoch - 3ms/step
# Epoch 3065/5000
# 14/14 - 0s - loss: 6.4289e-06 - 41ms/epoch - 3ms/step
# Epoch 3066/5000
# 14/14 - 0s - loss: 5.8032e-06 - 40ms/epoch - 3ms/step
# Epoch 3067/5000
# 14/14 - 0s - loss: 1.1989e-05 - 47ms/epoch - 3ms/step
# Epoch 3068/5000
# 14/14 - 0s - loss: 9.5592e-06 - 46ms/epoch - 3ms/step
# Epoch 3069/5000
# 14/14 - 0s - loss: 6.3236e-06 - 46ms/epoch - 3ms/step
# Epoch 3070/5000
# 14/14 - 0s - loss: 9.8608e-06 - 52ms/epoch - 4ms/step
# Epoch 3071/5000
# 14/14 - 0s - loss: 8.3517e-06 - 35ms/epoch - 3ms/step
# Epoch 3072/5000
# 14/14 - 0s - loss: 1.1238e-05 - 45ms/epoch - 3ms/step
# Epoch 3073/5000
# 14/14 - 0s - loss: 1.2468e-05 - 52ms/epoch - 4ms/step
# Epoch 3074/5000
# 14/14 - 0s - loss: 1.0941e-05 - 41ms/epoch - 3ms/step
# Epoch 3075/5000
# 14/14 - 0s - loss: 9.6928e-06 - 38ms/epoch - 3ms/step
# Epoch 3076/5000
# 14/14 - 0s - loss: 6.9336e-06 - 39ms/epoch - 3ms/step
# Epoch 3077/5000
# 14/14 - 0s - loss: 5.6376e-06 - 49ms/epoch - 4ms/step
# Epoch 3078/5000
# 14/14 - 0s - loss: 7.6468e-06 - 37ms/epoch - 3ms/step
# Epoch 3079/5000
# 14/14 - 0s - loss: 8.8808e-06 - 37ms/epoch - 3ms/step
# Epoch 3080/5000
# 14/14 - 0s - loss: 6.1624e-06 - 37ms/epoch - 3ms/step
# Epoch 3081/5000
# 14/14 - 0s - loss: 5.5611e-06 - 36ms/epoch - 3ms/step
# Epoch 3082/5000
# 14/14 - 0s - loss: 6.0555e-06 - 34ms/epoch - 2ms/step
# Epoch 3083/5000
# 14/14 - 0s - loss: 5.6115e-06 - 33ms/epoch - 2ms/step
# Epoch 3084/5000
# 14/14 - 0s - loss: 7.5095e-06 - 37ms/epoch - 3ms/step
# Epoch 3085/5000
# 14/14 - 0s - loss: 6.3613e-06 - 45ms/epoch - 3ms/step
# Epoch 3086/5000
# 14/14 - 0s - loss: 4.5099e-06 - 38ms/epoch - 3ms/step
# Epoch 3087/5000
# 14/14 - 0s - loss: 4.6621e-06 - 35ms/epoch - 2ms/step
# Epoch 3088/5000
# 14/14 - 0s - loss: 4.1873e-06 - 32ms/epoch - 2ms/step
# Epoch 3089/5000
# 14/14 - 0s - loss: 2.7690e-06 - 32ms/epoch - 2ms/step
# Epoch 3090/5000
# 14/14 - 0s - loss: 2.9861e-06 - 32ms/epoch - 2ms/step
# Epoch 3091/5000
# 14/14 - 0s - loss: 3.2011e-06 - 34ms/epoch - 2ms/step
# Epoch 3092/5000
# 14/14 - 0s - loss: 4.1566e-06 - 34ms/epoch - 2ms/step
# Epoch 3093/5000
# 14/14 - 0s - loss: 3.4915e-06 - 34ms/epoch - 2ms/step
# Epoch 3094/5000
# 14/14 - 0s - loss: 3.3456e-06 - 38ms/epoch - 3ms/step
# Epoch 3095/5000
# 14/14 - 0s - loss: 2.7237e-06 - 46ms/epoch - 3ms/step
# Epoch 3096/5000
# 14/14 - 0s - loss: 3.8249e-06 - 40ms/epoch - 3ms/step
# Epoch 3097/5000
# 14/14 - 0s - loss: 5.0051e-06 - 52ms/epoch - 4ms/step
# Epoch 3098/5000
# 14/14 - 0s - loss: 1.3312e-05 - 45ms/epoch - 3ms/step
# Epoch 3099/5000
# 14/14 - 0s - loss: 4.1884e-05 - 36ms/epoch - 3ms/step
# Epoch 3100/5000
# 14/14 - 0s - loss: 3.1638e-05 - 50ms/epoch - 4ms/step
# Epoch 3101/5000
# 14/14 - 0s - loss: 5.4542e-05 - 60ms/epoch - 4ms/step
# Epoch 3102/5000
# 14/14 - 0s - loss: 1.0671e-04 - 53ms/epoch - 4ms/step
# Epoch 3103/5000
# 14/14 - 0s - loss: 9.4132e-05 - 49ms/epoch - 3ms/step
# Epoch 3104/5000
# 14/14 - 0s - loss: 6.7901e-05 - 49ms/epoch - 4ms/step
# Epoch 3105/5000
# 14/14 - 0s - loss: 6.9331e-05 - 41ms/epoch - 3ms/step
# Epoch 3106/5000
# 14/14 - 0s - loss: 4.9257e-05 - 42ms/epoch - 3ms/step
# Epoch 3107/5000
# 14/14 - 0s - loss: 6.8288e-05 - 37ms/epoch - 3ms/step
# Epoch 3108/5000
# 14/14 - 0s - loss: 1.4402e-04 - 41ms/epoch - 3ms/step
# Epoch 3109/5000
# 14/14 - 0s - loss: 1.4919e-04 - 42ms/epoch - 3ms/step
# Epoch 3110/5000
# 14/14 - 0s - loss: 1.1727e-04 - 44ms/epoch - 3ms/step
# Epoch 3111/5000
# 14/14 - 0s - loss: 1.7204e-04 - 43ms/epoch - 3ms/step
# Epoch 3112/5000
# 14/14 - 0s - loss: 1.3691e-04 - 45ms/epoch - 3ms/step
# Epoch 3113/5000
# 14/14 - 0s - loss: 1.4189e-04 - 38ms/epoch - 3ms/step
# Epoch 3114/5000
# 14/14 - 0s - loss: 2.8800e-04 - 54ms/epoch - 4ms/step
# Epoch 3115/5000
# 14/14 - 0s - loss: 2.2245e-04 - 52ms/epoch - 4ms/step
# Epoch 3116/5000
# 14/14 - 0s - loss: 1.5458e-04 - 45ms/epoch - 3ms/step
# Epoch 3117/5000
# 14/14 - 0s - loss: 9.3189e-05 - 53ms/epoch - 4ms/step
# Epoch 3118/5000
# 14/14 - 0s - loss: 6.0444e-05 - 55ms/epoch - 4ms/step
# Epoch 3119/5000
# 14/14 - 0s - loss: 4.1657e-05 - 40ms/epoch - 3ms/step
# Epoch 3120/5000
# 14/14 - 0s - loss: 2.7608e-05 - 42ms/epoch - 3ms/step
# Epoch 3121/5000
# 14/14 - 0s - loss: 1.2727e-05 - 32ms/epoch - 2ms/step
# Epoch 3122/5000
# 14/14 - 0s - loss: 1.1622e-05 - 36ms/epoch - 3ms/step
# Epoch 3123/5000
# 14/14 - 0s - loss: 1.7191e-05 - 34ms/epoch - 2ms/step
# Epoch 3124/5000
# 14/14 - 0s - loss: 1.4965e-05 - 47ms/epoch - 3ms/step
# Epoch 3125/5000
# 14/14 - 0s - loss: 1.7602e-05 - 37ms/epoch - 3ms/step
# Epoch 3126/5000
# 14/14 - 0s - loss: 1.9470e-05 - 38ms/epoch - 3ms/step
# Epoch 3127/5000
# 14/14 - 0s - loss: 1.1355e-05 - 34ms/epoch - 2ms/step
# Epoch 3128/5000
# 14/14 - 0s - loss: 1.1253e-05 - 32ms/epoch - 2ms/step
# Epoch 3129/5000
# 14/14 - 0s - loss: 9.2672e-06 - 36ms/epoch - 3ms/step
# Epoch 3130/5000
# 14/14 - 0s - loss: 5.8976e-06 - 40ms/epoch - 3ms/step
# Epoch 3131/5000
# 14/14 - 0s - loss: 7.3687e-06 - 38ms/epoch - 3ms/step
# Epoch 3132/5000
# 14/14 - 0s - loss: 7.6853e-06 - 38ms/epoch - 3ms/step
# Epoch 3133/5000
# 14/14 - 0s - loss: 4.3906e-06 - 35ms/epoch - 2ms/step
# Epoch 3134/5000
# 14/14 - 0s - loss: 3.7812e-06 - 39ms/epoch - 3ms/step
# Epoch 3135/5000
# 14/14 - 0s - loss: 5.0574e-06 - 47ms/epoch - 3ms/step
# Epoch 3136/5000
# 14/14 - 0s - loss: 3.3125e-06 - 38ms/epoch - 3ms/step
# Epoch 3137/5000
# 14/14 - 0s - loss: 2.6099e-06 - 47ms/epoch - 3ms/step
# Epoch 3138/5000
# 14/14 - 0s - loss: 3.0023e-06 - 42ms/epoch - 3ms/step
# Epoch 3139/5000
# 14/14 - 0s - loss: 3.1745e-06 - 42ms/epoch - 3ms/step
# Epoch 3140/5000
# 14/14 - 0s - loss: 3.1117e-06 - 46ms/epoch - 3ms/step
# Epoch 3141/5000
# 14/14 - 0s - loss: 3.5179e-06 - 43ms/epoch - 3ms/step
# Epoch 3142/5000
# 14/14 - 0s - loss: 2.4239e-06 - 47ms/epoch - 3ms/step
# Epoch 3143/5000
# 14/14 - 0s - loss: 2.3434e-06 - 41ms/epoch - 3ms/step
# Epoch 3144/5000
# 14/14 - 0s - loss: 3.1373e-06 - 40ms/epoch - 3ms/step
# Epoch 3145/5000
# 14/14 - 0s - loss: 2.6932e-06 - 41ms/epoch - 3ms/step
# Epoch 3146/5000
# 14/14 - 0s - loss: 6.1009e-06 - 35ms/epoch - 2ms/step
# Epoch 3147/5000
# 14/14 - 0s - loss: 1.0206e-05 - 34ms/epoch - 2ms/step
# Epoch 3148/5000
# 14/14 - 0s - loss: 1.3619e-05 - 38ms/epoch - 3ms/step
# Epoch 3149/5000
# 14/14 - 0s - loss: 2.4535e-05 - 42ms/epoch - 3ms/step
# Epoch 3150/5000
# 14/14 - 0s - loss: 3.1238e-05 - 41ms/epoch - 3ms/step
# Epoch 3151/5000
# 14/14 - 0s - loss: 2.9251e-05 - 44ms/epoch - 3ms/step
# Epoch 3152/5000
# 14/14 - 0s - loss: 2.2778e-05 - 43ms/epoch - 3ms/step
# Epoch 3153/5000
# 14/14 - 0s - loss: 1.6782e-05 - 45ms/epoch - 3ms/step
# Epoch 3154/5000
# 14/14 - 0s - loss: 1.3358e-05 - 48ms/epoch - 3ms/step
# Epoch 3155/5000
# 14/14 - 0s - loss: 8.4725e-06 - 44ms/epoch - 3ms/step
# Epoch 3156/5000
# 14/14 - 0s - loss: 7.2225e-06 - 45ms/epoch - 3ms/step
# Epoch 3157/5000
# 14/14 - 0s - loss: 5.9785e-06 - 53ms/epoch - 4ms/step
# Epoch 3158/5000
# 14/14 - 0s - loss: 7.9971e-06 - 46ms/epoch - 3ms/step
# Epoch 3159/5000
# 14/14 - 0s - loss: 4.0391e-06 - 48ms/epoch - 3ms/step
# Epoch 3160/5000
# 14/14 - 0s - loss: 7.1301e-06 - 42ms/epoch - 3ms/step
# Epoch 3161/5000
# 14/14 - 0s - loss: 1.0221e-05 - 37ms/epoch - 3ms/step
# Epoch 3162/5000
# 14/14 - 0s - loss: 1.2651e-05 - 39ms/epoch - 3ms/step
# Epoch 3163/5000
# 14/14 - 0s - loss: 1.0544e-05 - 38ms/epoch - 3ms/step
# Epoch 3164/5000
# 14/14 - 0s - loss: 1.3509e-05 - 39ms/epoch - 3ms/step
# Epoch 3165/5000
# 14/14 - 0s - loss: 1.0655e-05 - 39ms/epoch - 3ms/step
# Epoch 3166/5000
# 14/14 - 0s - loss: 2.0565e-05 - 46ms/epoch - 3ms/step
# Epoch 3167/5000
# 14/14 - 0s - loss: 2.2624e-05 - 39ms/epoch - 3ms/step
# Epoch 3168/5000
# 14/14 - 0s - loss: 1.9478e-05 - 44ms/epoch - 3ms/step
# Epoch 3169/5000
# 14/14 - 0s - loss: 1.1069e-05 - 33ms/epoch - 2ms/step
# Epoch 3170/5000
# 14/14 - 0s - loss: 9.5904e-06 - 40ms/epoch - 3ms/step
# Epoch 3171/5000
# 14/14 - 0s - loss: 8.0737e-06 - 34ms/epoch - 2ms/step
# Epoch 3172/5000
# 14/14 - 0s - loss: 9.0543e-06 - 42ms/epoch - 3ms/step
# Epoch 3173/5000
# 14/14 - 0s - loss: 6.1737e-06 - 46ms/epoch - 3ms/step
# Epoch 3174/5000
# 14/14 - 0s - loss: 6.9446e-06 - 34ms/epoch - 2ms/step
# Epoch 3175/5000
# 14/14 - 0s - loss: 7.2929e-06 - 35ms/epoch - 3ms/step
# Epoch 3176/5000
# 14/14 - 0s - loss: 7.2964e-06 - 34ms/epoch - 2ms/step
# Epoch 3177/5000
# 14/14 - 0s - loss: 8.8694e-06 - 37ms/epoch - 3ms/step
# Epoch 3178/5000
# 14/14 - 0s - loss: 1.0577e-05 - 34ms/epoch - 2ms/step
# Epoch 3179/5000
# 14/14 - 0s - loss: 1.4609e-05 - 33ms/epoch - 2ms/step
# Epoch 3180/5000
# 14/14 - 0s - loss: 1.3260e-05 - 34ms/epoch - 2ms/step
# Epoch 3181/5000
# 14/14 - 0s - loss: 2.1728e-05 - 34ms/epoch - 2ms/step
# Epoch 3182/5000
# 14/14 - 0s - loss: 2.4916e-05 - 35ms/epoch - 3ms/step
# Epoch 3183/5000
# 14/14 - 0s - loss: 2.3871e-05 - 39ms/epoch - 3ms/step
# Epoch 3184/5000
# 14/14 - 0s - loss: 2.8912e-05 - 35ms/epoch - 3ms/step
# Epoch 3185/5000
# 14/14 - 0s - loss: 2.3438e-05 - 39ms/epoch - 3ms/step
# Epoch 3186/5000
# 14/14 - 0s - loss: 3.2010e-05 - 35ms/epoch - 2ms/step
# Epoch 3187/5000
# 14/14 - 0s - loss: 4.2878e-05 - 39ms/epoch - 3ms/step
# Epoch 3188/5000
# 14/14 - 0s - loss: 1.3302e-04 - 39ms/epoch - 3ms/step
# ...
# Epoch 4775/5000
# 14/14 - 0s - loss: 1.1788e-04 - 36ms/epoch - 3ms/step
# Epoch 4776/5000
# 14/14 - 0s - loss: 5.6834e-05 - 36ms/epoch - 3ms/step
# Epoch 4777/5000
# 14/14 - 0s - loss: 3.9350e-05 - 37ms/epoch - 3ms/step
# Epoch 4778/5000
# 14/14 - 0s - loss: 3.8696e-05 - 48ms/epoch - 3ms/step
# Epoch 4779/5000
# 14/14 - 0s - loss: 2.2069e-05 - 38ms/epoch - 3ms/step
# Epoch 4780/5000
# 14/14 - 0s - loss: 1.3860e-05 - 42ms/epoch - 3ms/step
# Epoch 4781/5000
# 14/14 - 0s - loss: 1.0334e-05 - 43ms/epoch - 3ms/step
# Epoch 4782/5000
# 14/14 - 0s - loss: 1.3584e-05 - 53ms/epoch - 4ms/step
# Epoch 4783/5000
# 14/14 - 0s - loss: 1.0991e-05 - 68ms/epoch - 5ms/step
# Epoch 4784/5000
# 14/14 - 0s - loss: 6.5752e-06 - 55ms/epoch - 4ms/step
# Epoch 4785/5000
# 14/14 - 0s - loss: 1.1055e-05 - 45ms/epoch - 3ms/step
# Epoch 4786/5000
# 14/14 - 0s - loss: 1.5505e-05 - 58ms/epoch - 4ms/step
# Epoch 4787/5000
# 14/14 - 0s - loss: 2.1002e-05 - 45ms/epoch - 3ms/step
# Epoch 4788/5000
# 14/14 - 0s - loss: 1.9458e-05 - 45ms/epoch - 3ms/step
# Epoch 4789/5000
# 14/14 - 0s - loss: 6.1559e-05 - 45ms/epoch - 3ms/step
# Epoch 4790/5000
# 14/14 - 0s - loss: 2.6138e-05 - 42ms/epoch - 3ms/step
# Epoch 4791/5000
# 14/14 - 0s - loss: 2.6413e-05 - 46ms/epoch - 3ms/step
# Epoch 4792/5000
# 14/14 - 0s - loss: 9.8793e-06 - 40ms/epoch - 3ms/step
# Epoch 4793/5000
# 14/14 - 0s - loss: 9.0745e-06 - 44ms/epoch - 3ms/step
# Epoch 4794/5000
# 14/14 - 0s - loss: 1.3332e-05 - 54ms/epoch - 4ms/step
# Epoch 4795/5000
# 14/14 - 0s - loss: 1.0986e-05 - 49ms/epoch - 3ms/step
# Epoch 4796/5000
# 14/14 - 0s - loss: 1.3398e-05 - 40ms/epoch - 3ms/step
# Epoch 4797/5000
# 14/14 - 0s - loss: 1.6640e-05 - 34ms/epoch - 2ms/step
# Epoch 4798/5000
# 14/14 - 0s - loss: 1.3626e-05 - 36ms/epoch - 3ms/step
# Epoch 4799/5000
# 14/14 - 0s - loss: 1.6669e-05 - 57ms/epoch - 4ms/step
# Epoch 4800/5000
# 14/14 - 0s - loss: 2.1839e-05 - 55ms/epoch - 4ms/step
# Epoch 4801/5000
# 14/14 - 0s - loss: 1.1700e-05 - 54ms/epoch - 4ms/step
# Epoch 4802/5000
# 14/14 - 0s - loss: 1.0406e-05 - 50ms/epoch - 4ms/step
# Epoch 4803/5000
# 14/14 - 0s - loss: 8.6970e-06 - 46ms/epoch - 3ms/step
# Epoch 4804/5000
# 14/14 - 0s - loss: 6.2361e-06 - 39ms/epoch - 3ms/step
# Epoch 4805/5000
# 14/14 - 0s - loss: 2.3801e-06 - 33ms/epoch - 2ms/step
# Epoch 4806/5000
# 14/14 - 0s - loss: 1.8022e-06 - 36ms/epoch - 3ms/step
# Epoch 4807/5000
# 14/14 - 0s - loss: 2.1285e-06 - 33ms/epoch - 2ms/step
# Epoch 4808/5000
# 14/14 - 0s - loss: 4.4180e-06 - 33ms/epoch - 2ms/step
# Epoch 4809/5000
# 14/14 - 0s - loss: 5.7025e-06 - 36ms/epoch - 3ms/step
# Epoch 4810/5000
# 14/14 - 0s - loss: 4.7621e-06 - 38ms/epoch - 3ms/step
# Epoch 4811/5000
# 14/14 - 0s - loss: 3.7218e-06 - 37ms/epoch - 3ms/step
# Epoch 4812/5000
# 14/14 - 0s - loss: 2.5875e-06 - 37ms/epoch - 3ms/step
# Epoch 4813/5000
# 14/14 - 0s - loss: 5.7053e-06 - 36ms/epoch - 3ms/step
# Epoch 4814/5000
# 14/14 - 0s - loss: 5.6423e-06 - 36ms/epoch - 3ms/step
# Epoch 4815/5000
# 14/14 - 0s - loss: 8.9518e-06 - 36ms/epoch - 3ms/step
# Epoch 4816/5000
# 14/14 - 0s - loss: 1.3571e-05 - 38ms/epoch - 3ms/step
# Epoch 4817/5000
# 14/14 - 0s - loss: 9.4274e-06 - 48ms/epoch - 3ms/step
# Epoch 4818/5000
# 14/14 - 0s - loss: 1.3046e-05 - 37ms/epoch - 3ms/step
# Epoch 4819/5000
# 14/14 - 0s - loss: 1.1244e-05 - 34ms/epoch - 2ms/step
# Epoch 4820/5000
# 14/14 - 0s - loss: 1.5542e-05 - 35ms/epoch - 2ms/step
# Epoch 4821/5000
# 14/14 - 0s - loss: 2.8845e-05 - 37ms/epoch - 3ms/step
# Epoch 4822/5000
# 14/14 - 0s - loss: 1.3327e-05 - 35ms/epoch - 2ms/step
# Epoch 4823/5000
# 14/14 - 0s - loss: 8.5194e-06 - 50ms/epoch - 4ms/step
# Epoch 4824/5000
# 14/14 - 0s - loss: 7.0762e-06 - 54ms/epoch - 4ms/step
# Epoch 4825/5000
# 14/14 - 0s - loss: 5.5424e-06 - 45ms/epoch - 3ms/step
# Epoch 4826/5000
# 14/14 - 0s - loss: 4.6215e-06 - 41ms/epoch - 3ms/step
# Epoch 4827/5000
# 14/14 - 0s - loss: 3.9536e-06 - 41ms/epoch - 3ms/step
# Epoch 4828/5000
# 14/14 - 0s - loss: 6.5324e-06 - 49ms/epoch - 4ms/step
# Epoch 4829/5000
# 14/14 - 0s - loss: 8.6258e-06 - 45ms/epoch - 3ms/step
# Epoch 4830/5000
# 14/14 - 0s - loss: 7.2051e-06 - 48ms/epoch - 3ms/step
# Epoch 4831/5000
# 14/14 - 0s - loss: 3.9628e-06 - 47ms/epoch - 3ms/step
# Epoch 4832/5000
# 14/14 - 0s - loss: 7.5108e-06 - 46ms/epoch - 3ms/step
# Epoch 4833/5000
# 14/14 - 0s - loss: 7.5609e-06 - 61ms/epoch - 4ms/step
# Epoch 4834/5000
# 14/14 - 0s - loss: 9.0344e-06 - 48ms/epoch - 3ms/step
# Epoch 4835/5000
# 14/14 - 0s - loss: 9.6205e-06 - 43ms/epoch - 3ms/step
# Epoch 4836/5000
# 14/14 - 0s - loss: 9.2796e-06 - 46ms/epoch - 3ms/step
# Epoch 4837/5000
# 14/14 - 0s - loss: 1.0911e-05 - 41ms/epoch - 3ms/step
# Epoch 4838/5000
# 14/14 - 0s - loss: 8.2921e-06 - 40ms/epoch - 3ms/step
# Epoch 4839/5000
# 14/14 - 0s - loss: 8.4691e-06 - 44ms/epoch - 3ms/step
# Epoch 4840/5000
# 14/14 - 0s - loss: 8.4595e-06 - 45ms/epoch - 3ms/step
# Epoch 4841/5000
# 14/14 - 0s - loss: 5.0032e-06 - 34ms/epoch - 2ms/step
# Epoch 4842/5000
# 14/14 - 0s - loss: 4.5375e-06 - 39ms/epoch - 3ms/step
# Epoch 4843/5000
# 14/14 - 0s - loss: 4.1240e-06 - 36ms/epoch - 3ms/step
# Epoch 4844/5000
# 14/14 - 0s - loss: 3.5989e-06 - 33ms/epoch - 2ms/step
# Epoch 4845/5000
# 14/14 - 0s - loss: 4.6435e-06 - 34ms/epoch - 2ms/step
# Epoch 4846/5000
# 14/14 - 0s - loss: 3.4444e-06 - 44ms/epoch - 3ms/step
# Epoch 4847/5000
# 14/14 - 0s - loss: 3.5154e-06 - 41ms/epoch - 3ms/step
# Epoch 4848/5000
# 14/14 - 0s - loss: 3.7351e-06 - 38ms/epoch - 3ms/step
# Epoch 4849/5000
# 14/14 - 0s - loss: 4.3485e-06 - 38ms/epoch - 3ms/step
# Epoch 4850/5000
# 14/14 - 0s - loss: 5.3366e-06 - 34ms/epoch - 2ms/step
# Epoch 4851/5000
# 14/14 - 0s - loss: 9.1080e-06 - 35ms/epoch - 2ms/step
# Epoch 4852/5000
# 14/14 - 0s - loss: 1.2355e-05 - 34ms/epoch - 2ms/step
# Epoch 4853/5000
# 14/14 - 0s - loss: 9.8095e-06 - 37ms/epoch - 3ms/step
# Epoch 4854/5000
# 14/14 - 0s - loss: 1.0973e-05 - 55ms/epoch - 4ms/step
# Epoch 4855/5000
# 14/14 - 0s - loss: 7.5116e-06 - 40ms/epoch - 3ms/step
# Epoch 4856/5000
# 14/14 - 0s - loss: 6.7377e-06 - 53ms/epoch - 4ms/step
# Epoch 4857/5000
# 14/14 - 0s - loss: 4.6943e-06 - 45ms/epoch - 3ms/step
# Epoch 4858/5000
# 14/14 - 0s - loss: 5.7402e-06 - 47ms/epoch - 3ms/step
# Epoch 4859/5000
# 14/14 - 0s - loss: 1.7384e-05 - 39ms/epoch - 3ms/step
# Epoch 4860/5000
# 14/14 - 0s - loss: 1.8447e-05 - 45ms/epoch - 3ms/step
# Epoch 4861/5000
# 14/14 - 0s - loss: 3.5493e-05 - 53ms/epoch - 4ms/step
# Epoch 4862/5000
# 14/14 - 0s - loss: 2.3367e-05 - 56ms/epoch - 4ms/step
# Epoch 4863/5000
# 14/14 - 0s - loss: 2.3268e-05 - 60ms/epoch - 4ms/step
# Epoch 4864/5000
# 14/14 - 0s - loss: 2.3486e-05 - 57ms/epoch - 4ms/step
# Epoch 4865/5000
# 14/14 - 0s - loss: 3.0559e-05 - 58ms/epoch - 4ms/step
# Epoch 4866/5000
# 14/14 - 0s - loss: 4.8920e-05 - 66ms/epoch - 5ms/step
# Epoch 4867/5000
# 14/14 - 0s - loss: 3.1339e-05 - 62ms/epoch - 4ms/step
# Epoch 4868/5000
# 14/14 - 0s - loss: 5.3977e-05 - 77ms/epoch - 5ms/step
# Epoch 4869/5000
# 14/14 - 0s - loss: 4.4869e-05 - 62ms/epoch - 4ms/step
# Epoch 4870/5000
# 14/14 - 0s - loss: 6.2613e-05 - 71ms/epoch - 5ms/step
# Epoch 4871/5000
# 14/14 - 0s - loss: 2.3041e-04 - 65ms/epoch - 5ms/step
# Epoch 4872/5000
# 14/14 - 0s - loss: 5.6968e-04 - 77ms/epoch - 6ms/step
# Epoch 4873/5000
# 14/14 - 0s - loss: 9.0479e-04 - 66ms/epoch - 5ms/step
# Epoch 4874/5000
# 14/14 - 0s - loss: 4.0163e-04 - 61ms/epoch - 4ms/step
# Epoch 4875/5000
# 14/14 - 0s - loss: 5.3397e-04 - 61ms/epoch - 4ms/step
# Epoch 4876/5000
# 14/14 - 0s - loss: 5.9111e-04 - 46ms/epoch - 3ms/step
# Epoch 4877/5000
# 14/14 - 0s - loss: 3.5519e-04 - 44ms/epoch - 3ms/step
# Epoch 4878/5000
# 14/14 - 0s - loss: 1.9927e-04 - 41ms/epoch - 3ms/step
# Epoch 4879/5000
# 14/14 - 0s - loss: 7.2751e-05 - 39ms/epoch - 3ms/step
# Epoch 4880/5000
# 14/14 - 0s - loss: 6.8211e-05 - 72ms/epoch - 5ms/step
# Epoch 4881/5000
# 14/14 - 0s - loss: 3.4130e-05 - 58ms/epoch - 4ms/step
# Epoch 4882/5000
# 14/14 - 0s - loss: 1.9477e-05 - 65ms/epoch - 5ms/step
# Epoch 4883/5000
# 14/14 - 0s - loss: 1.4111e-05 - 73ms/epoch - 5ms/step
# Epoch 4884/5000
# 14/14 - 0s - loss: 1.3586e-05 - 59ms/epoch - 4ms/step
# Epoch 4885/5000
# 14/14 - 0s - loss: 8.3698e-06 - 57ms/epoch - 4ms/step
# Epoch 4886/5000
# 14/14 - 0s - loss: 7.7969e-06 - 46ms/epoch - 3ms/step
# Epoch 4887/5000
# 14/14 - 0s - loss: 9.5407e-06 - 46ms/epoch - 3ms/step
# Epoch 4888/5000
# 14/14 - 0s - loss: 1.1049e-05 - 56ms/epoch - 4ms/step
# Epoch 4889/5000
# 14/14 - 0s - loss: 6.9083e-06 - 50ms/epoch - 4ms/step
# Epoch 4890/5000
# 14/14 - 0s - loss: 8.8133e-06 - 35ms/epoch - 2ms/step
# Epoch 4891/5000
# 14/14 - 0s - loss: 7.2929e-06 - 32ms/epoch - 2ms/step
# Epoch 4892/5000
# 14/14 - 0s - loss: 7.5811e-06 - 34ms/epoch - 2ms/step
# Epoch 4893/5000
# 14/14 - 0s - loss: 4.9774e-06 - 33ms/epoch - 2ms/step
# Epoch 4894/5000
# 14/14 - 0s - loss: 5.8402e-06 - 35ms/epoch - 3ms/step
# Epoch 4895/5000
# 14/14 - 0s - loss: 3.8898e-06 - 38ms/epoch - 3ms/step
# Epoch 4896/5000
# 14/14 - 0s - loss: 3.5769e-06 - 37ms/epoch - 3ms/step
# Epoch 4897/5000
# 14/14 - 0s - loss: 3.6846e-06 - 36ms/epoch - 3ms/step
# Epoch 4898/5000
# 14/14 - 0s - loss: 6.7022e-06 - 33ms/epoch - 2ms/step
# Epoch 4899/5000
# 14/14 - 0s - loss: 6.6227e-06 - 47ms/epoch - 3ms/step
# Epoch 4900/5000
# 14/14 - 0s - loss: 5.2345e-06 - 41ms/epoch - 3ms/step
# Epoch 4901/5000
# 14/14 - 0s - loss: 4.0741e-06 - 64ms/epoch - 5ms/step
# Epoch 4902/5000
# 14/14 - 0s - loss: 3.5570e-06 - 71ms/epoch - 5ms/step
# Epoch 4903/5000
# 14/14 - 0s - loss: 3.8427e-06 - 65ms/epoch - 5ms/step
# Epoch 4904/5000
# 14/14 - 0s - loss: 2.9886e-06 - 67ms/epoch - 5ms/step
# Epoch 4905/5000
# 14/14 - 0s - loss: 3.1599e-06 - 69ms/epoch - 5ms/step
# Epoch 4906/5000
# 14/14 - 0s - loss: 3.4860e-06 - 66ms/epoch - 5ms/step
# Epoch 4907/5000
# 14/14 - 0s - loss: 2.6398e-06 - 72ms/epoch - 5ms/step
# Epoch 4908/5000
# 14/14 - 0s - loss: 5.3906e-06 - 70ms/epoch - 5ms/step
# Epoch 4909/5000
# 14/14 - 0s - loss: 5.0750e-06 - 49ms/epoch - 4ms/step
# Epoch 4910/5000
# 14/14 - 0s - loss: 4.2319e-06 - 49ms/epoch - 3ms/step
# Epoch 4911/5000
# 14/14 - 0s - loss: 3.4410e-06 - 45ms/epoch - 3ms/step
# Epoch 4912/5000
# 14/14 - 0s - loss: 4.7510e-06 - 59ms/epoch - 4ms/step
# Epoch 4913/5000
# 14/14 - 0s - loss: 2.5560e-06 - 49ms/epoch - 4ms/step
# Epoch 4914/5000
# 14/14 - 0s - loss: 2.7295e-06 - 50ms/epoch - 4ms/step
# Epoch 4915/5000
# 14/14 - 0s - loss: 2.9818e-06 - 46ms/epoch - 3ms/step
# Epoch 4916/5000
# 14/14 - 0s - loss: 2.2566e-06 - 44ms/epoch - 3ms/step
# Epoch 4917/5000
# 14/14 - 0s - loss: 2.6923e-06 - 80ms/epoch - 6ms/step
# Epoch 4918/5000
# 14/14 - 0s - loss: 2.4980e-06 - 59ms/epoch - 4ms/step
# Epoch 4919/5000
# 14/14 - 0s - loss: 2.7384e-06 - 75ms/epoch - 5ms/step
# Epoch 4920/5000
# 14/14 - 0s - loss: 5.0536e-06 - 48ms/epoch - 3ms/step
# Epoch 4921/5000
# 14/14 - 0s - loss: 3.6882e-06 - 48ms/epoch - 3ms/step
# Epoch 4922/5000
# 14/14 - 0s - loss: 4.7100e-06 - 66ms/epoch - 5ms/step
# Epoch 4923/5000
# 14/14 - 0s - loss: 3.6370e-06 - 68ms/epoch - 5ms/step
# Epoch 4924/5000
# 14/14 - 0s - loss: 2.2857e-06 - 52ms/epoch - 4ms/step
# Epoch 4925/5000
# 14/14 - 0s - loss: 2.5286e-06 - 50ms/epoch - 4ms/step
# Epoch 4926/5000
# 14/14 - 0s - loss: 3.6821e-06 - 56ms/epoch - 4ms/step
# Epoch 4927/5000
# 14/14 - 0s - loss: 3.4461e-06 - 47ms/epoch - 3ms/step
# Epoch 4928/5000
# 14/14 - 0s - loss: 1.8311e-06 - 40ms/epoch - 3ms/step
# Epoch 4929/5000
# 14/14 - 0s - loss: 1.9675e-06 - 43ms/epoch - 3ms/step
# Epoch 4930/5000
# 14/14 - 0s - loss: 1.5330e-06 - 45ms/epoch - 3ms/step
# Epoch 4931/5000
# 14/14 - 0s - loss: 1.1246e-06 - 42ms/epoch - 3ms/step
# Epoch 4932/5000
# 14/14 - 0s - loss: 1.2362e-06 - 45ms/epoch - 3ms/step
# Epoch 4933/5000
# 14/14 - 0s - loss: 1.9585e-06 - 39ms/epoch - 3ms/step
# Epoch 4934/5000
# 14/14 - 0s - loss: 1.4348e-06 - 37ms/epoch - 3ms/step
# Epoch 4935/5000
# 14/14 - 0s - loss: 1.5817e-06 - 70ms/epoch - 5ms/step
# Epoch 4936/5000
# 14/14 - 0s - loss: 1.3803e-06 - 60ms/epoch - 4ms/step
# Epoch 4937/5000
# 14/14 - 0s - loss: 1.2046e-06 - 80ms/epoch - 6ms/step
# Epoch 4938/5000
# 14/14 - 0s - loss: 1.5631e-06 - 81ms/epoch - 6ms/step
# Epoch 4939/5000
# 14/14 - 0s - loss: 2.1144e-06 - 73ms/epoch - 5ms/step
# Epoch 4940/5000
# 14/14 - 0s - loss: 2.2682e-06 - 77ms/epoch - 6ms/step
# Epoch 4941/5000
# 14/14 - 0s - loss: 2.7505e-06 - 71ms/epoch - 5ms/step
# Epoch 4942/5000
# 14/14 - 0s - loss: 3.1053e-06 - 65ms/epoch - 5ms/step
# Epoch 4943/5000
# 14/14 - 0s - loss: 2.2908e-06 - 43ms/epoch - 3ms/step
# Epoch 4944/5000
# 14/14 - 0s - loss: 2.3480e-06 - 58ms/epoch - 4ms/step
# Epoch 4945/5000
# 14/14 - 0s - loss: 2.3534e-06 - 51ms/epoch - 4ms/step
# Epoch 4946/5000
# 14/14 - 0s - loss: 3.3387e-06 - 51ms/epoch - 4ms/step
# Epoch 4947/5000
# 14/14 - 0s - loss: 2.6978e-06 - 45ms/epoch - 3ms/step
# Epoch 4948/5000
# 14/14 - 0s - loss: 2.2145e-06 - 56ms/epoch - 4ms/step
# Epoch 4949/5000
# 14/14 - 0s - loss: 2.2554e-06 - 64ms/epoch - 5ms/step
# Epoch 4950/5000
# 14/14 - 0s - loss: 2.2791e-06 - 60ms/epoch - 4ms/step
# Epoch 4951/5000
# 14/14 - 0s - loss: 2.2844e-06 - 66ms/epoch - 5ms/step
# Epoch 4952/5000
# 14/14 - 0s - loss: 2.1433e-06 - 50ms/epoch - 4ms/step
# Epoch 4953/5000
# 14/14 - 0s - loss: 1.8173e-06 - 40ms/epoch - 3ms/step
# Epoch 4954/5000
# 14/14 - 0s - loss: 2.0143e-06 - 36ms/epoch - 3ms/step
# Epoch 4955/5000
# 14/14 - 0s - loss: 1.5648e-06 - 31ms/epoch - 2ms/step
# Epoch 4956/5000
# 14/14 - 0s - loss: 1.4337e-06 - 33ms/epoch - 2ms/step
# Epoch 4957/5000
# 14/14 - 0s - loss: 1.3328e-06 - 34ms/epoch - 2ms/step
# Epoch 4958/5000
# 14/14 - 0s - loss: 1.8286e-06 - 35ms/epoch - 2ms/step
# Epoch 4959/5000
# 14/14 - 0s - loss: 2.2108e-06 - 33ms/epoch - 2ms/step
# Epoch 4960/5000
# 14/14 - 0s - loss: 2.9029e-06 - 37ms/epoch - 3ms/step
# Epoch 4961/5000
# 14/14 - 0s - loss: 4.6324e-06 - 32ms/epoch - 2ms/step
# Epoch 4962/5000
# 14/14 - 0s - loss: 5.4062e-06 - 33ms/epoch - 2ms/step
# Epoch 4963/5000
# 14/14 - 0s - loss: 5.9296e-06 - 48ms/epoch - 3ms/step
# Epoch 4964/5000
# 14/14 - 0s - loss: 3.7019e-06 - 37ms/epoch - 3ms/step
# Epoch 4965/5000
# 14/14 - 0s - loss: 4.0958e-06 - 41ms/epoch - 3ms/step
# Epoch 4966/5000
# 14/14 - 0s - loss: 2.5082e-06 - 37ms/epoch - 3ms/step
# Epoch 4967/5000
# 14/14 - 0s - loss: 2.0776e-06 - 32ms/epoch - 2ms/step
# Epoch 4968/5000
# 14/14 - 0s - loss: 2.4100e-06 - 58ms/epoch - 4ms/step
# Epoch 4969/5000
# 14/14 - 0s - loss: 2.7912e-06 - 46ms/epoch - 3ms/step
# Epoch 4970/5000
# 14/14 - 0s - loss: 3.7405e-06 - 68ms/epoch - 5ms/step
# Epoch 4971/5000
# 14/14 - 0s - loss: 3.6109e-06 - 66ms/epoch - 5ms/step
# Epoch 4972/5000
# 14/14 - 0s - loss: 3.1605e-06 - 59ms/epoch - 4ms/step
# Epoch 4973/5000
# 14/14 - 0s - loss: 3.3906e-06 - 67ms/epoch - 5ms/step
# Epoch 4974/5000
# 14/14 - 0s - loss: 2.4088e-06 - 65ms/epoch - 5ms/step
# Epoch 4975/5000
# 14/14 - 0s - loss: 2.2909e-06 - 62ms/epoch - 4ms/step
# Epoch 4976/5000
# 14/14 - 0s - loss: 2.5793e-06 - 58ms/epoch - 4ms/step
# Epoch 4977/5000
# 14/14 - 0s - loss: 2.2366e-06 - 60ms/epoch - 4ms/step
# Epoch 4978/5000
# 14/14 - 0s - loss: 1.5683e-06 - 47ms/epoch - 3ms/step
# Epoch 4979/5000
# 14/14 - 0s - loss: 1.6230e-06 - 42ms/epoch - 3ms/step
# Epoch 4980/5000
# 14/14 - 0s - loss: 1.8124e-06 - 46ms/epoch - 3ms/step
# Epoch 4981/5000
# 14/14 - 0s - loss: 1.3376e-06 - 48ms/epoch - 3ms/step
# Epoch 4982/5000
# 14/14 - 0s - loss: 1.6832e-06 - 53ms/epoch - 4ms/step
# Epoch 4983/5000
# 14/14 - 0s - loss: 2.0286e-06 - 67ms/epoch - 5ms/step
# Epoch 4984/5000
# 14/14 - 0s - loss: 3.5044e-06 - 52ms/epoch - 4ms/step
# Epoch 4985/5000
# 14/14 - 0s - loss: 6.2313e-06 - 62ms/epoch - 4ms/step
# Epoch 4986/5000
# 14/14 - 0s - loss: 1.2004e-05 - 63ms/epoch - 4ms/step
# Epoch 4987/5000
# 14/14 - 0s - loss: 1.7448e-05 - 54ms/epoch - 4ms/step
# Epoch 4988/5000
# 14/14 - 0s - loss: 1.5835e-05 - 44ms/epoch - 3ms/step
# Epoch 4989/5000
# 14/14 - 0s - loss: 1.4228e-05 - 44ms/epoch - 3ms/step
# Epoch 4990/5000
# 14/14 - 0s - loss: 2.6642e-05 - 43ms/epoch - 3ms/step
# Epoch 4991/5000
# 14/14 - 0s - loss: 4.3507e-05 - 40ms/epoch - 3ms/step
# Epoch 4992/5000
# 14/14 - 0s - loss: 4.1474e-05 - 44ms/epoch - 3ms/step
# Epoch 4993/5000
# 14/14 - 0s - loss: 2.9399e-05 - 48ms/epoch - 3ms/step
# Epoch 4994/5000
# 14/14 - 0s - loss: 3.4013e-05 - 45ms/epoch - 3ms/step
# Epoch 4995/5000
# 14/14 - 0s - loss: 5.2271e-05 - 53ms/epoch - 4ms/step
# Epoch 4996/5000
# 14/14 - 0s - loss: 2.1298e-05 - 36ms/epoch - 3ms/step
# Epoch 4997/5000
# 14/14 - 0s - loss: 2.2648e-05 - 39ms/epoch - 3ms/step
# Epoch 4998/5000
# 14/14 - 0s - loss: 4.8172e-05 - 31ms/epoch - 2ms/step
# Epoch 4999/5000
# 14/14 - 0s - loss: 7.5087e-05 - 37ms/epoch - 3ms/step
# Epoch 5000/5000
# 14/14 - 0s - loss: 1.0135e-04 - 31ms/epoch - 2ms/step
# 2/2 [==============================] - 0s 7ms/step
# Test RMSE: 2720.30
# Test MAE: 1677.53
# Test R^2: 0.96
# Test MAPE: 0.06
# Test Adjusted R^2: 0.95
# Training Time: 271.25 seconds

# %%
#Với Dropout để tránh overfitting

import pandas as pd
import numpy as np
import time
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_absolute_error, r2_score, mean_absolute_percentage_error
from keras.models import Sequential
from keras.layers import Dense, Dropout

# Đọc dữ liệu từ tệp CSV
df = pd.read_csv('Dataa_Service.csv')

# Chọn các cột đầu vào và đầu ra
X = df[['Month', 'Year', 'CPI', 'GDP', 'Temperature', 'USD/VND']]
y = df['Service']

# Chuẩn hóa dữ liệu
scaler_X = MinMaxScaler()
scaler_y = MinMaxScaler()
X_scaled = scaler_X.fit_transform(X)
y_scaled = scaler_y.fit_transform(y.values.reshape(-1, 1))

# Chia dữ liệu thành tập huấn luyện và kiểm tra
X_train, X_test, y_train, y_test = train_test_split(X_scaled, y_scaled, test_size=0.2, random_state=42)

# Xây dựng mô hình mạng nơron với Dropout
model2 = Sequential()
model2.add(Dense(128, input_dim=X_train.shape[1], activation='relu'))
model2.add(Dropout(0.5))
model2.add(Dense(64, activation='relu'))
model2.add(Dropout(0.5))
model2.add(Dense(32, activation='relu'))
model2.add(Dense(1))

# Biên dịch mô hình
model2.compile(loss='mean_squared_error', optimizer='adam')

# Đo thời gian bắt đầu huấn luyện
start_time = time.time()

# Huấn luyện mô hình
model2.fit(X_train, y_train, epochs=100, batch_size=10, verbose=2)

# Đo thời gian kết thúc huấn luyện
end_time = time.time()

# Dự báo trên tập kiểm tra
y_pred2_scaled = model2.predict(X_test)

# Chuyển đổi lại dữ liệu về dạng ban đầu
y_pred2 = scaler_y.inverse_transform(y_pred2_scaled)
y_test_inverse = scaler_y.inverse_transform(y_test)

# Tính toán các chỉ số đánh giá
mse2 = np.mean((y_pred2 - y_test_inverse) ** 2)
rmse2 = np.sqrt(mse2)
mae2 = mean_absolute_error(y_test_inverse, y_pred2)
r22 = r2_score(y_test_inverse, y_pred2)
mape2 = mean_absolute_percentage_error(y_test_inverse, y_pred2)
adjusted_r22 = 1 - (1 - r22) * ((len(y_test_inverse) - 1) / (len(y_test_inverse) - X_test.shape[1] - 1))

# In các chỉ số đánh giá
print(f'Model 2 - Test RMSE: {rmse2:.2f}')
print(f'Model 2 - Test MAE: {mae2:.2f}')
print(f'Model 2 - Test R^2: {r22:.2f}')
print(f'Model 2 - Test MAPE: {mape2:.2f}')
print(f'Model 2 - Test Adjusted R^2: {adjusted_r22:.2f}')
print(f'Model 2 - Training Time: {end_time - start_time:.2f} seconds')
# Out:
# Epoch 1/100
# 14/14 - 1s - loss: 0.1004 - 878ms/epoch - 63ms/step
# Epoch 2/100
# 14/14 - 0s - loss: 0.0646 - 25ms/epoch - 2ms/step
# Epoch 3/100
# 14/14 - 0s - loss: 0.0523 - 29ms/epoch - 2ms/step
# Epoch 4/100
# 14/14 - 0s - loss: 0.0429 - 24ms/epoch - 2ms/step
# Epoch 5/100
# 14/14 - 0s - loss: 0.0451 - 26ms/epoch - 2ms/step
# Epoch 6/100
# 14/14 - 0s - loss: 0.0351 - 26ms/epoch - 2ms/step
# Epoch 7/100
# 14/14 - 0s - loss: 0.0309 - 32ms/epoch - 2ms/step
# Epoch 8/100
# 14/14 - 0s - loss: 0.0281 - 31ms/epoch - 2ms/step
# Epoch 9/100
# 14/14 - 0s - loss: 0.0317 - 26ms/epoch - 2ms/step
# Epoch 10/100
# 14/14 - 0s - loss: 0.0256 - 26ms/epoch - 2ms/step
# Epoch 11/100
# 14/14 - 0s - loss: 0.0209 - 25ms/epoch - 2ms/step
# Epoch 12/100
# 14/14 - 0s - loss: 0.0274 - 27ms/epoch - 2ms/step
# Epoch 13/100
# 14/14 - 0s - loss: 0.0235 - 25ms/epoch - 2ms/step
# Epoch 14/100
# 14/14 - 0s - loss: 0.0267 - 26ms/epoch - 2ms/step
# Epoch 15/100
# 14/14 - 0s - loss: 0.0266 - 29ms/epoch - 2ms/step
# Epoch 16/100
# 14/14 - 0s - loss: 0.0231 - 25ms/epoch - 2ms/step
# Epoch 17/100
# 14/14 - 0s - loss: 0.0231 - 27ms/epoch - 2ms/step
# Epoch 18/100
# 14/14 - 0s - loss: 0.0216 - 27ms/epoch - 2ms/step
# Epoch 19/100
# 14/14 - 0s - loss: 0.0179 - 26ms/epoch - 2ms/step
# Epoch 20/100
# 14/14 - 0s - loss: 0.0209 - 29ms/epoch - 2ms/step
# Epoch 21/100
# 14/14 - 0s - loss: 0.0226 - 28ms/epoch - 2ms/step
# Epoch 22/100
# 14/14 - 0s - loss: 0.0162 - 29ms/epoch - 2ms/step
# Epoch 23/100
# 14/14 - 0s - loss: 0.0192 - 27ms/epoch - 2ms/step
# Epoch 24/100
# 14/14 - 0s - loss: 0.0233 - 26ms/epoch - 2ms/step
# Epoch 25/100
# 14/14 - 0s - loss: 0.0236 - 27ms/epoch - 2ms/step
# Epoch 26/100
# 14/14 - 0s - loss: 0.0218 - 42ms/epoch - 3ms/step
# Epoch 27/100
# 14/14 - 0s - loss: 0.0179 - 26ms/epoch - 2ms/step
# Epoch 28/100
# 14/14 - 0s - loss: 0.0211 - 31ms/epoch - 2ms/step
# Epoch 29/100
# 14/14 - 0s - loss: 0.0186 - 24ms/epoch - 2ms/step
# Epoch 30/100
# 14/14 - 0s - loss: 0.0139 - 25ms/epoch - 2ms/step
# Epoch 31/100
# 14/14 - 0s - loss: 0.0200 - 27ms/epoch - 2ms/step
# Epoch 32/100
# 14/14 - 0s - loss: 0.0179 - 26ms/epoch - 2ms/step
# Epoch 33/100
# 14/14 - 0s - loss: 0.0156 - 26ms/epoch - 2ms/step
# Epoch 34/100
# 14/14 - 0s - loss: 0.0145 - 29ms/epoch - 2ms/step
# Epoch 35/100
# 14/14 - 0s - loss: 0.0139 - 24ms/epoch - 2ms/step
# Epoch 36/100
# 14/14 - 0s - loss: 0.0196 - 27ms/epoch - 2ms/step
# Epoch 37/100
# 14/14 - 0s - loss: 0.0168 - 25ms/epoch - 2ms/step
# Epoch 38/100
# 14/14 - 0s - loss: 0.0140 - 26ms/epoch - 2ms/step
# Epoch 39/100
# 14/14 - 0s - loss: 0.0116 - 26ms/epoch - 2ms/step
# Epoch 40/100
# 14/14 - 0s - loss: 0.0150 - 35ms/epoch - 2ms/step
# Epoch 41/100
# 14/14 - 0s - loss: 0.0129 - 35ms/epoch - 2ms/step
# Epoch 42/100
# 14/14 - 0s - loss: 0.0143 - 33ms/epoch - 2ms/step
# Epoch 43/100
# 14/14 - 0s - loss: 0.0139 - 36ms/epoch - 3ms/step
# Epoch 44/100
# 14/14 - 0s - loss: 0.0126 - 32ms/epoch - 2ms/step
# Epoch 45/100
# 14/14 - 0s - loss: 0.0140 - 35ms/epoch - 2ms/step
# Epoch 46/100
# 14/14 - 0s - loss: 0.0125 - 41ms/epoch - 3ms/step
# Epoch 47/100
# 14/14 - 0s - loss: 0.0152 - 32ms/epoch - 2ms/step
# Epoch 48/100
# 14/14 - 0s - loss: 0.0114 - 34ms/epoch - 2ms/step
# Epoch 49/100
# 14/14 - 0s - loss: 0.0126 - 31ms/epoch - 2ms/step
# Epoch 50/100
# 14/14 - 0s - loss: 0.0143 - 36ms/epoch - 3ms/step
# Epoch 51/100
# 14/14 - 0s - loss: 0.0160 - 33ms/epoch - 2ms/step
# Epoch 52/100
# 14/14 - 0s - loss: 0.0137 - 27ms/epoch - 2ms/step
# Epoch 53/100
# 14/14 - 0s - loss: 0.0155 - 28ms/epoch - 2ms/step
# Epoch 54/100
# 14/14 - 0s - loss: 0.0137 - 26ms/epoch - 2ms/step
# Epoch 55/100
# 14/14 - 0s - loss: 0.0135 - 28ms/epoch - 2ms/step
# Epoch 56/100
# 14/14 - 0s - loss: 0.0131 - 27ms/epoch - 2ms/step
# Epoch 57/100
# 14/14 - 0s - loss: 0.0121 - 45ms/epoch - 3ms/step
# Epoch 58/100
# 14/14 - 0s - loss: 0.0137 - 29ms/epoch - 2ms/step
# Epoch 59/100
# 14/14 - 0s - loss: 0.0100 - 26ms/epoch - 2ms/step
# Epoch 60/100
# 14/14 - 0s - loss: 0.0137 - 26ms/epoch - 2ms/step
# Epoch 61/100
# 14/14 - 0s - loss: 0.0127 - 27ms/epoch - 2ms/step
# Epoch 62/100
# 14/14 - 0s - loss: 0.0120 - 30ms/epoch - 2ms/step
# Epoch 63/100
# 14/14 - 0s - loss: 0.0132 - 26ms/epoch - 2ms/step
# Epoch 64/100
# 14/14 - 0s - loss: 0.0133 - 27ms/epoch - 2ms/step
# Epoch 65/100
# 14/14 - 0s - loss: 0.0120 - 29ms/epoch - 2ms/step
# Epoch 66/100
# 14/14 - 0s - loss: 0.0109 - 27ms/epoch - 2ms/step
# Epoch 67/100
# 14/14 - 0s - loss: 0.0127 - 26ms/epoch - 2ms/step
# Epoch 68/100
# 14/14 - 0s - loss: 0.0119 - 28ms/epoch - 2ms/step
# Epoch 69/100
# 14/14 - 0s - loss: 0.0130 - 33ms/epoch - 2ms/step
# Epoch 70/100
# 14/14 - 0s - loss: 0.0114 - 38ms/epoch - 3ms/step
# Epoch 71/100
# 14/14 - 0s - loss: 0.0118 - 33ms/epoch - 2ms/step
# Epoch 72/100
# 14/14 - 0s - loss: 0.0130 - 33ms/epoch - 2ms/step
# Epoch 73/100
# 14/14 - 0s - loss: 0.0130 - 32ms/epoch - 2ms/step
# Epoch 74/100
# 14/14 - 0s - loss: 0.0133 - 34ms/epoch - 2ms/step
# Epoch 75/100
# 14/14 - 0s - loss: 0.0114 - 32ms/epoch - 2ms/step
# Epoch 76/100
# 14/14 - 0s - loss: 0.0125 - 27ms/epoch - 2ms/step
# Epoch 77/100
# 14/14 - 0s - loss: 0.0135 - 30ms/epoch - 2ms/step
# Epoch 78/100
# 14/14 - 0s - loss: 0.0113 - 29ms/epoch - 2ms/step
# Epoch 79/100
# 14/14 - 0s - loss: 0.0118 - 25ms/epoch - 2ms/step
# Epoch 80/100
# 14/14 - 0s - loss: 0.0110 - 29ms/epoch - 2ms/step
# Epoch 81/100
# 14/14 - 0s - loss: 0.0102 - 28ms/epoch - 2ms/step
# Epoch 82/100
# 14/14 - 0s - loss: 0.0112 - 26ms/epoch - 2ms/step
# Epoch 83/100
# 14/14 - 0s - loss: 0.0107 - 27ms/epoch - 2ms/step
# Epoch 84/100
# 14/14 - 0s - loss: 0.0105 - 28ms/epoch - 2ms/step
# Epoch 85/100
# 14/14 - 0s - loss: 0.0117 - 29ms/epoch - 2ms/step
# Epoch 86/100
# 14/14 - 0s - loss: 0.0119 - 27ms/epoch - 2ms/step
# Epoch 87/100
# 14/14 - 0s - loss: 0.0111 - 26ms/epoch - 2ms/step
# Epoch 88/100
# 14/14 - 0s - loss: 0.0118 - 29ms/epoch - 2ms/step
# Epoch 89/100
# 14/14 - 0s - loss: 0.0098 - 30ms/epoch - 2ms/step
# Epoch 90/100
# 14/14 - 0s - loss: 0.0089 - 33ms/epoch - 2ms/step
# Epoch 91/100
# 14/14 - 0s - loss: 0.0104 - 26ms/epoch - 2ms/step
# Epoch 92/100
# 14/14 - 0s - loss: 0.0100 - 27ms/epoch - 2ms/step
# Epoch 93/100
# 14/14 - 0s - loss: 0.0105 - 26ms/epoch - 2ms/step
# Epoch 94/100
# 14/14 - 0s - loss: 0.0112 - 31ms/epoch - 2ms/step
# Epoch 95/100
# 14/14 - 0s - loss: 0.0100 - 25ms/epoch - 2ms/step
# Epoch 96/100
# 14/14 - 0s - loss: 0.0097 - 28ms/epoch - 2ms/step
# Epoch 97/100
# 14/14 - 0s - loss: 0.0082 - 25ms/epoch - 2ms/step
# Epoch 98/100
# 14/14 - 0s - loss: 0.0088 - 26ms/epoch - 2ms/step
# Epoch 99/100
# 14/14 - 0s - loss: 0.0079 - 26ms/epoch - 2ms/step
# Epoch 100/100
# 14/14 - 0s - loss: 0.0092 - 44ms/epoch - 3ms/step
# 2/2 [==============================] - 0s 5ms/step
# Model 2 - Test RMSE: 5589.01
# Model 2 - Test MAE: 3739.30
# Model 2 - Test R^2: 0.82
# Model 2 - Test MAPE: 0.12
# Model 2 - Test Adjusted R^2: 0.78
# Model 2 - Training Time: 4.15 seconds

# %%
#Mô hình với Batch Normalization
import pandas as pd
import numpy as np
import time
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_absolute_error, r2_score, mean_absolute_percentage_error
from keras.models import Sequential
from keras.layers import Dense, BatchNormalization

# Đọc dữ liệu từ tệp CSV
df = pd.read_csv('Dataa_Service.csv')

# Chọn các cột đầu vào và đầu ra
X = df[['Month', 'Year', 'CPI', 'GDP', 'Temperature', 'USD/VND']]
y = df['Service']

# Chuẩn hóa dữ liệu
scaler_X = MinMaxScaler()
scaler_y = MinMaxScaler()
X_scaled = scaler_X.fit_transform(X)
y_scaled = scaler_y.fit_transform(y.values.reshape(-1, 1))

# Chia dữ liệu thành tập huấn luyện và kiểm tra
X_train, X_test, y_train, y_test = train_test_split(X_scaled, y_scaled, test_size=0.2, random_state=42)

# Xây dựng mô hình mạng nơron với Batch Normalization
model5 = Sequential()
model5.add(Dense(128, input_dim=X_train.shape[1], activation='relu'))
model5.add(BatchNormalization())
model5.add(Dense(64, activation='relu'))
model5.add(BatchNormalization())
model5.add(Dense(32, activation='relu'))
model5.add(BatchNormalization())
model5.add(Dense(1))

# Biên dịch mô hình
model5.compile(loss='mean_squared_error', optimizer='adam')

# Đo thời gian bắt đầu huấn luyện
start_time = time.time()

# Huấn luyện mô hình
model5.fit(X_train, y_train, epochs=100, batch_size=10, verbose=2)

# Đo thời gian kết thúc huấn luyện
end_time = time.time()

# Dự báo trên tập kiểm tra
y_pred5_scaled = model5.predict(X_test)

# Chuyển đổi lại dữ liệu về dạng ban đầu
y_pred5 = scaler_y.inverse_transform(y_pred5_scaled)
y_test_inverse = scaler_y.inverse_transform(y_test)

# Tính toán các chỉ số đánh giá
mse5 = np.mean((y_pred5 - y_test_inverse) ** 2)
rmse5 = np.sqrt(mse5)
mae5 = mean_absolute_error(y_test_inverse, y_pred5)
r25 = r2_score(y_test_inverse, y_pred5)
mape5 = mean_absolute_percentage_error(y_test_inverse, y_pred5)
adjusted_r25 = 1 - (1 - r25) * ((len(y_test_inverse) - 1) / (len(y_test_inverse) - X_test.shape[1] - 1))

# In các chỉ số đánh giá
print(f'Model 5 - Test RMSE: {rmse5:.2f}')
print(f'Model 5 - Test MAE: {mae5:.2f}')
print(f'Model 5 - Test R^2: {r25:.2f}')
print(f'Model 5 - Test MAPE: {mape5:.2f}')
print(f'Model 5 - Test Adjusted R^2: {adjusted_r25:.2f}')
print(f'Model 5 - Training Time: {end_time - start_time:.2f} seconds')
# Out:
# Epoch 1/100
# 14/14 - 2s - loss: 1.3700 - 2s/epoch - 123ms/step
# Epoch 2/100
# 14/14 - 0s - loss: 0.5726 - 40ms/epoch - 3ms/step
# Epoch 3/100
# 14/14 - 0s - loss: 0.4103 - 49ms/epoch - 4ms/step
# Epoch 4/100
# 14/14 - 0s - loss: 0.3488 - 48ms/epoch - 3ms/step
# Epoch 5/100
# 14/14 - 0s - loss: 0.2392 - 42ms/epoch - 3ms/step
# Epoch 6/100
# 14/14 - 0s - loss: 0.2852 - 36ms/epoch - 3ms/step
# Epoch 7/100
# 14/14 - 0s - loss: 0.1709 - 36ms/epoch - 3ms/step
# Epoch 8/100
# 14/14 - 0s - loss: 0.1464 - 42ms/epoch - 3ms/step
# Epoch 9/100
# 14/14 - 0s - loss: 0.1406 - 35ms/epoch - 2ms/step
# Epoch 10/100
# 14/14 - 0s - loss: 0.1484 - 38ms/epoch - 3ms/step
# Epoch 11/100
# 14/14 - 0s - loss: 0.1274 - 38ms/epoch - 3ms/step
# Epoch 12/100
# 14/14 - 0s - loss: 0.1214 - 41ms/epoch - 3ms/step
# Epoch 13/100
# 14/14 - 0s - loss: 0.1015 - 36ms/epoch - 3ms/step
# Epoch 14/100
# 14/14 - 0s - loss: 0.0993 - 41ms/epoch - 3ms/step
# Epoch 15/100
# 14/14 - 0s - loss: 0.0946 - 35ms/epoch - 2ms/step
# Epoch 16/100
# 14/14 - 0s - loss: 0.0941 - 39ms/epoch - 3ms/step
# Epoch 17/100
# 14/14 - 0s - loss: 0.0881 - 35ms/epoch - 3ms/step
# Epoch 18/100
# 14/14 - 0s - loss: 0.0710 - 37ms/epoch - 3ms/step
# Epoch 19/100
# 14/14 - 0s - loss: 0.0830 - 39ms/epoch - 3ms/step
# Epoch 20/100
# 14/14 - 0s - loss: 0.0669 - 39ms/epoch - 3ms/step
# Epoch 21/100
# 14/14 - 0s - loss: 0.0832 - 43ms/epoch - 3ms/step
# Epoch 22/100
# 14/14 - 0s - loss: 0.0791 - 49ms/epoch - 4ms/step
# Epoch 23/100
# 14/14 - 0s - loss: 0.0702 - 43ms/epoch - 3ms/step
# Epoch 24/100
# 14/14 - 0s - loss: 0.0557 - 35ms/epoch - 2ms/step
# Epoch 25/100
# 14/14 - 0s - loss: 0.0593 - 36ms/epoch - 3ms/step
# Epoch 26/100
# 14/14 - 0s - loss: 0.0636 - 37ms/epoch - 3ms/step
# Epoch 27/100
# 14/14 - 0s - loss: 0.0481 - 34ms/epoch - 2ms/step
# Epoch 28/100
# 14/14 - 0s - loss: 0.0614 - 38ms/epoch - 3ms/step
# Epoch 29/100
# 14/14 - 0s - loss: 0.0655 - 37ms/epoch - 3ms/step
# Epoch 30/100
# 14/14 - 0s - loss: 0.0488 - 34ms/epoch - 2ms/step
# Epoch 31/100
# 14/14 - 0s - loss: 0.0513 - 35ms/epoch - 2ms/step
# Epoch 32/100
# 14/14 - 0s - loss: 0.0379 - 34ms/epoch - 2ms/step
# Epoch 33/100
# 14/14 - 0s - loss: 0.0361 - 40ms/epoch - 3ms/step
# Epoch 34/100
# 14/14 - 0s - loss: 0.0382 - 39ms/epoch - 3ms/step
# Epoch 35/100
# 14/14 - 0s - loss: 0.0406 - 43ms/epoch - 3ms/step
# Epoch 36/100
# 14/14 - 0s - loss: 0.0452 - 38ms/epoch - 3ms/step
# Epoch 37/100
# 14/14 - 0s - loss: 0.0460 - 42ms/epoch - 3ms/step
# Epoch 38/100
# 14/14 - 0s - loss: 0.0450 - 37ms/epoch - 3ms/step
# Epoch 39/100
# 14/14 - 0s - loss: 0.0435 - 36ms/epoch - 3ms/step
# Epoch 40/100
# 14/14 - 0s - loss: 0.0348 - 39ms/epoch - 3ms/step
# Epoch 41/100
# 14/14 - 0s - loss: 0.0376 - 39ms/epoch - 3ms/step
# Epoch 42/100
# 14/14 - 0s - loss: 0.0340 - 38ms/epoch - 3ms/step
# Epoch 43/100
# 14/14 - 0s - loss: 0.0377 - 37ms/epoch - 3ms/step
# Epoch 44/100
# 14/14 - 0s - loss: 0.0318 - 38ms/epoch - 3ms/step
# Epoch 45/100
# 14/14 - 0s - loss: 0.0522 - 38ms/epoch - 3ms/step
# Epoch 46/100
# 14/14 - 0s - loss: 0.0306 - 40ms/epoch - 3ms/step
# Epoch 47/100
# 14/14 - 0s - loss: 0.0328 - 39ms/epoch - 3ms/step
# Epoch 48/100
# 14/14 - 0s - loss: 0.0293 - 45ms/epoch - 3ms/step
# Epoch 49/100
# 14/14 - 0s - loss: 0.0286 - 33ms/epoch - 2ms/step
# Epoch 50/100
# 14/14 - 0s - loss: 0.0270 - 35ms/epoch - 3ms/step
# Epoch 51/100
# 14/14 - 0s - loss: 0.0339 - 35ms/epoch - 3ms/step
# Epoch 52/100
# 14/14 - 0s - loss: 0.0450 - 40ms/epoch - 3ms/step
# Epoch 53/100
# 14/14 - 0s - loss: 0.0260 - 39ms/epoch - 3ms/step
# Epoch 54/100
# 14/14 - 0s - loss: 0.0288 - 35ms/epoch - 2ms/step
# Epoch 55/100
# 14/14 - 0s - loss: 0.0258 - 36ms/epoch - 3ms/step
# Epoch 56/100
# 14/14 - 0s - loss: 0.0275 - 33ms/epoch - 2ms/step
# Epoch 57/100
# 14/14 - 0s - loss: 0.0268 - 34ms/epoch - 2ms/step
# Epoch 58/100
# 14/14 - 0s - loss: 0.0284 - 35ms/epoch - 3ms/step
# Epoch 59/100
# 14/14 - 0s - loss: 0.0269 - 43ms/epoch - 3ms/step
# Epoch 60/100
# 14/14 - 0s - loss: 0.0175 - 34ms/epoch - 2ms/step
# Epoch 61/100
# 14/14 - 0s - loss: 0.0271 - 33ms/epoch - 2ms/step
# Epoch 62/100
# 14/14 - 0s - loss: 0.0304 - 34ms/epoch - 2ms/step
# Epoch 63/100
# 14/14 - 0s - loss: 0.0254 - 36ms/epoch - 3ms/step
# Epoch 64/100
# 14/14 - 0s - loss: 0.0227 - 34ms/epoch - 2ms/step
# Epoch 65/100
# 14/14 - 0s - loss: 0.0274 - 36ms/epoch - 3ms/step
# Epoch 66/100
# 14/14 - 0s - loss: 0.0195 - 34ms/epoch - 2ms/step
# Epoch 67/100
# 14/14 - 0s - loss: 0.0276 - 36ms/epoch - 3ms/step
# Epoch 68/100
# 14/14 - 0s - loss: 0.0199 - 33ms/epoch - 2ms/step
# Epoch 69/100
# 14/14 - 0s - loss: 0.0290 - 39ms/epoch - 3ms/step
# Epoch 70/100
# 14/14 - 0s - loss: 0.0232 - 40ms/epoch - 3ms/step
# Epoch 71/100
# 14/14 - 0s - loss: 0.0206 - 35ms/epoch - 2ms/step
# Epoch 72/100
# 14/14 - 0s - loss: 0.0181 - 34ms/epoch - 2ms/step
# Epoch 73/100
# 14/14 - 0s - loss: 0.0252 - 44ms/epoch - 3ms/step
# Epoch 74/100
# 14/14 - 0s - loss: 0.0262 - 52ms/epoch - 4ms/step
# Epoch 75/100
# 14/14 - 0s - loss: 0.0171 - 39ms/epoch - 3ms/step
# Epoch 76/100
# 14/14 - 0s - loss: 0.0127 - 36ms/epoch - 3ms/step
# Epoch 77/100
# 14/14 - 0s - loss: 0.0207 - 37ms/epoch - 3ms/step
# Epoch 78/100
# 14/14 - 0s - loss: 0.0270 - 37ms/epoch - 3ms/step
# Epoch 79/100
# 14/14 - 0s - loss: 0.0258 - 35ms/epoch - 3ms/step
# Epoch 80/100
# 14/14 - 0s - loss: 0.0206 - 37ms/epoch - 3ms/step
# Epoch 81/100
# 14/14 - 0s - loss: 0.0131 - 36ms/epoch - 3ms/step
# Epoch 82/100
# 14/14 - 0s - loss: 0.0165 - 35ms/epoch - 2ms/step
# Epoch 83/100
# 14/14 - 0s - loss: 0.0237 - 38ms/epoch - 3ms/step
# Epoch 84/100
# 14/14 - 0s - loss: 0.0217 - 39ms/epoch - 3ms/step
# Epoch 85/100
# 14/14 - 0s - loss: 0.0152 - 37ms/epoch - 3ms/step
# Epoch 86/100
# 14/14 - 0s - loss: 0.0213 - 35ms/epoch - 3ms/step
# Epoch 87/100
# 14/14 - 0s - loss: 0.0200 - 41ms/epoch - 3ms/step
# Epoch 88/100
# 14/14 - 0s - loss: 0.0179 - 36ms/epoch - 3ms/step
# Epoch 89/100
# 14/14 - 0s - loss: 0.0187 - 43ms/epoch - 3ms/step
# Epoch 90/100
# 14/14 - 0s - loss: 0.0176 - 38ms/epoch - 3ms/step
# Epoch 91/100
# 14/14 - 0s - loss: 0.0180 - 38ms/epoch - 3ms/step
# Epoch 92/100
# 14/14 - 0s - loss: 0.0209 - 36ms/epoch - 3ms/step
# Epoch 93/100
# 14/14 - 0s - loss: 0.0172 - 35ms/epoch - 2ms/step
# Epoch 94/100
# 14/14 - 0s - loss: 0.0266 - 39ms/epoch - 3ms/step
# Epoch 95/100
# 14/14 - 0s - loss: 0.0228 - 38ms/epoch - 3ms/step
# Epoch 96/100
# 14/14 - 0s - loss: 0.0184 - 36ms/epoch - 3ms/step
# Epoch 97/100
# 14/14 - 0s - loss: 0.0161 - 35ms/epoch - 3ms/step
# Epoch 98/100
# 14/14 - 0s - loss: 0.0218 - 34ms/epoch - 2ms/step
# Epoch 99/100
# 14/14 - 0s - loss: 0.0177 - 49ms/epoch - 4ms/step
# Epoch 100/100
# 14/14 - 0s - loss: 0.0195 - 35ms/epoch - 2ms/step
# 2/2 [==============================] - 0s 5ms/step
# Model 5 - Test RMSE: 6786.20
# Model 5 - Test MAE: 5058.14
# Model 5 - Test R^2: 0.73
# Model 5 - Test MAPE: 0.20
# Model 5 - Test Adjusted R^2: 0.67
# Model 5 - Training Time: 6.85 seconds

# %%
### Mô hình SVM Model 5 6 7
import pandas as pd
import time
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_absolute_error, r2_score, mean_absolute_percentage_error
from sklearn.svm import SVR

# Đọc dữ liệu từ tệp CSV
df = pd.read_csv('Dataa_Service.csv')

# Chọn các cột đầu vào và đầu ra
X = df[['Month', 'Year', 'CPI', 'GDP', 'Temperature', 'USD/VND']]
y = df['Service']

# Chuẩn hóa dữ liệu
scaler_X = MinMaxScaler()
scaler_y = MinMaxScaler()
X_scaled = scaler_X.fit_transform(X)
y_scaled = scaler_y.fit_transform(y.values.reshape(-1, 1))

# Chia dữ liệu thành tập huấn luyện và tập kiểm tra
X_train, X_test, y_train, y_test = train_test_split(X_scaled, y_scaled, test_size=0.2, random_state=42)

# Xây dựng mô hình SVM với kernel RBF
svm_model = SVR(kernel='rbf')

# Đo thời gian bắt đầu huấn luyện
start_time = time.time()

# Huấn luyện mô hình
svm_model.fit(X_train, y_train.ravel())

# Đo thời gian kết thúc huấn luyện
end_time = time.time()

# Dự đoán trên tập kiểm tra
y_pred = svm_model.predict(X_test)

# Chuyển đổi lại dữ liệu về dạng ban đầu
y_pred = scaler_y.inverse_transform(y_pred.reshape(-1, 1))
y_test_inverse = scaler_y.inverse_transform(y_test)

# Tính toán các chỉ số đánh giá
mse = np.mean((y_pred - y_test_inverse) ** 2)
rmse = np.sqrt(mse)
mae = mean_absolute_error(y_test_inverse, y_pred)
r2 = r2_score(y_test_inverse, y_pred)
mape = mean_absolute_percentage_error(y_test_inverse, y_pred)
adjusted_r2 = 1 - (1 - r2) * ((len(y_test_inverse) - 1) / (len(y_test_inverse) - X_test.shape[1] - 1))

# Xây dựng mô hình SVM với kernel đa thức
svr_poly = SVR(kernel='poly', degree=3)

# Đo thời gian bắt đầu huấn luyện
start_time_poly = time.time()

# Huấn luyện mô hình
svr_poly.fit(X_train, y_train.ravel())

# Đo thời gian kết thúc huấn luyện
end_time_poly = time.time()

# Dự báo trên tập kiểm tra
y_pred_poly = svr_poly.predict(X_test)

# Chuyển đổi lại dữ liệu về dạng ban đầu
y_pred_poly = scaler_y.inverse_transform(y_pred_poly.reshape(-1, 1))
y_test_inverse = scaler_y.inverse_transform(y_test)

# Tính toán các chỉ số đánh giá
mse_poly = np.mean((y_pred_poly - y_test_inverse) ** 2)
rmse_poly = np.sqrt(mse_poly)
mae_poly = mean_absolute_error(y_test_inverse, y_pred_poly)
r2_poly = r2_score(y_test_inverse, y_pred_poly)
mape_poly = mean_absolute_percentage_error(y_test_inverse, y_pred_poly)
adjusted_r2_poly = 1 - (1 - r2_poly) * ((len(y_test_inverse) - 1) / (len(y_test_inverse) - X_test.shape[1] - 1))

# Xây dựng mô hình SVM với kernel tuyến tính (linear)
svr_linear = SVR(kernel='linear')

# Đo thời gian bắt đầu huấn luyện
start_time_linear = time.time()

# Huấn luyện mô hình
svr_linear.fit(X_train, y_train.ravel())

# Đo thời gian kết thúc huấn luyện
end_time_linear = time.time()

# Dự báo trên tập kiểm tra
y_pred_linear = svr_linear.predict(X_test)

# Chuyển đổi lại dữ liệu về dạng ban đầu
y_pred_linear = scaler_y.inverse_transform(y_pred_linear.reshape(-1, 1))
y_test_inverse = scaler_y.inverse_transform(y_test)

# Tính toán các chỉ số đánh giá
mse_linear = np.mean((y_pred_linear - y_test_inverse) ** 2)
rmse_linear = np.sqrt(mse_linear)
mae_linear = mean_absolute_error(y_test_inverse, y_pred_linear)
r2_linear = r2_score(y_test_inverse, y_pred_linear)
mape_linear = mean_absolute_percentage_error(y_test_inverse, y_pred_linear)
adjusted_r2_linear = 1 - (1 - r2_linear) * ((len(y_test_inverse) - 1) / (len(y_test_inverse) - X_test.shape[1] - 1))

# In các chỉ số đánh giá
print("Model with RBF kernel")
print("Training time:", end_time - start_time)
print("RMSE:", rmse)
print("MAE:", mae)
print("R2:", r2)
print("Adjusted R2:", adjusted_r2)
print("MAPE:", mape)

print("\nModel with Polynomial kernel")
print("Training time:", end_time_poly - start_time_poly)
print("RMSE:", rmse_poly)
print("MAE:", mae_poly)
print("R2:", r2_poly)
print("Adjusted R2:", adjusted_r2_poly)
print("MAPE:", mape_poly)

print("\nModel with Linear kernel")
print("Training time:", end_time_linear - start_time_linear)
print("RMSE:", rmse_linear)
print("MAE:", mae_linear)
print("R2:", r2_linear)
print("Adjusted R2:", adjusted_r2_linear)
print("MAPE:", mape_linear)
# Out:
# Model with RBF kernel
# Training time: 0.002736330032348633
# RMSE: 4641.65454130658
# MAE: 3402.715573909871
# R2: 0.8731258268107525
# Adjusted R2: 0.8459385039844851
# MAPE: 0.14279487316427172
#
# Model with Polynomial kernel
# Training time: 0.016038179397583008
# RMSE: 4322.9239463923695
# MAE: 3290.3553430598913
# R2: 0.889951839927325
# Adjusted R2: 0.8663700913403232
# MAPE: 0.13337649269268945
#
# Model with Linear kernel
# Training time: 0.0013918876647949219
# RMSE: 6367.077066689655
# MAE: 4022.8102624198254
# R2: 0.7612695542437602
# Adjusted R2: 0.7101130301531374
# MAPE: 0.16346613359307047
